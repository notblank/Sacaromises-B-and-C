# %%
import cobra
import matplotlib.pylab as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ### Base model:

# %%
cerevisiae = cobra.io.load_json_model('./modelos COBRA/iMM904.json')
cerevisiae
# Out:
# <Model iMM904 at 0x9a7efb8b00>

# %% [markdown]
# ### Extra metabolites model 1:

# %%
# 3hbcoa_c	(R)-3-Hydroxybutyryl-CoA	C25H38N7O18P3S	c
T3hbcoa_c = cobra.Metabolite(
        '3hbcoa_c',
        formula = 'C25H38N7O18P3S',
        name = '(R)-3-Hydroxybutyryl-CoA',
        compartment = 'cytosol')

# b2coa_c	Crotonoyl-CoA	C25H36N7O17P3S	c
b2coa_c = cobra.Metabolite(
        'b2coa_c',
        formula = 'C25H36N7O17P3S',
        name = 'Crotonoyl-CoA',
        compartment = 'cytosol')

# btcoa_c	Butanoyl-CoA	C25H38N7O17P3S	c
btcoa_c = cobra.Metabolite(
        'btcoa_c',
        formula = 'C25H38N7O17P3S',
        name = 'Butanoyl-CoA',
        compartment = 'cytosol')

# but_c	Butyrate (n-C4:0)	C4H7O2	c
but_c = cobra.Metabolite(
        'but_c',
        formula = 'C4H7O2',
        name = 'Butyrate (n-C4:0)',
        compartment = 'cytosol')


cerevisiae.add_metabolites(T3hbcoa_c)
cerevisiae.add_metabolites(b2coa_c)
cerevisiae.add_metabolites(btcoa_c)
cerevisiae.add_metabolites(but_c)

# %%
len(cerevisiae.genes)
# Out:
# 905

# %%
# 2.0 accoa_c <=> aacoa_c + coa_c
reaction = cobra.Reaction('ACACT1b')
reaction.name = 'acetyl-CoA C-acetyltransferase'
reaction.subsystem = 'Butyrate_production'

reaction.lower_bound = -1000.  # This is the default
reaction.upper_bound = 1000.  # This is the default  

reaction.gene_reaction_rule = 'phaA'
reaction.genes

cerevisiae.add_reactions([reaction])

ng = len(cerevisiae.genes) - 1
cerevisiae.genes[ng].name = 'phaA'
cerevisiae.genes[ng]

nr = len(cerevisiae.reactions) - 1
cerevisiae.reactions[nr].reaction = '2.0 accoa_c <=> aacoa_c + coa_c'

# %%
# aacoa_c + h_c + nadph_c <=> nadp_c + 3hbcoa_c
reaction = cobra.Reaction('AACOARb')
reaction.name = 'acetoacetyl-CoA reductase [EC:1.1.1.36]'
reaction.subsystem = 'Butyrate_production'

reaction.lower_bound = -1000.  # This is the default
reaction.upper_bound = 1000.  # This is the default  

reaction.gene_reaction_rule = 'phaB'
reaction.genes

cerevisiae.add_reactions([reaction])

ng = len(cerevisiae.genes) - 1
cerevisiae.genes[ng].name = 'phaB'
cerevisiae.genes[ng]

nr = len(cerevisiae.reactions) - 1
cerevisiae.reactions[nr].reaction = 'aacoa_c + h_c + nadph_c <=> nadp_c + 3hbcoa_c'

# %%
# 3hbcoa_c <=> b2coa_c + h2o_c
reaction = cobra.Reaction('HBCOAhydb')
reaction.name = '(R)-specific enoyl-CoA hydratase (EC 4.2.1.119)'
reaction.subsystem = 'Butyrate_production'

reaction.lower_bound = -1000.  # This is the default
reaction.upper_bound = 1000.  # This is the default  

reaction.gene_reaction_rule = 'phaJ'
reaction.genes

cerevisiae.add_reactions([reaction])

ng = len(cerevisiae.genes) - 1
cerevisiae.genes[ng].name = 'phaJ'
cerevisiae.genes[ng]

nr = len(cerevisiae.reactions) - 1
cerevisiae.reactions[nr].reaction = '3hbcoa_c <=> b2coa_c + h2o_c'

# %%
# b2coa_c + h_c + nadh_c <=> btcoa_c + nad_c
reaction = cobra.Reaction('ACOAD1b')
reaction.name = ' trans-2-enoyl-CoA reductase (NAD+) (EC1.3.1.44)'
reaction.subsystem = 'Butyrate_production'

reaction.lower_bound = -1000.  # This is the default
reaction.upper_bound = 1000.  # This is the default  

reaction.gene_reaction_rule = 'Ter'
reaction.genes

cerevisiae.add_reactions([reaction])

ng = len(cerevisiae.genes) - 1
cerevisiae.genes[ng].name = 'Ter'
cerevisiae.genes[ng]

nr = len(cerevisiae.reactions) - 1
cerevisiae.reactions[nr].reaction = 'b2coa_c + h_c + nadh_c <=> btcoa_c + nad_c'

# %%
# btcoa_c + h2o_c <=> but_c + coa_c + h_c
reaction = cobra.Reaction('BCOAhydb')
reaction.name = ' acyl-CoA hydrolase (EC 3.1.2.20)'
reaction.subsystem = 'Butyrate_production'

reaction.lower_bound = -1000.  # This is the default
reaction.upper_bound = 1000.  # This is the default  

reaction.gene_reaction_rule = 'TesB'
reaction.genes

cerevisiae.add_reactions([reaction])

ng = len(cerevisiae.genes) - 1
cerevisiae.genes[ng].name = 'TesB'
cerevisiae.genes[ng]

nr = len(cerevisiae.reactions) - 1
cerevisiae.reactions[nr].reaction = 'btcoa_c + h2o_c <=> but_c + coa_c + h_c'

# %%
cerevisiae.reactions[nr].metabolites
# Out:
# {<Metabolite btcoa_c at 0x9a7ed91c50>: -1,
#  <Metabolite but_c at 0x9a7ed91dd8>: 1,
#  <Metabolite coa_c at 0x9a7f0012e8>: 1,
#  <Metabolite h2o_c at 0x9a7f02aa58>: -1,
#  <Metabolite h_c at 0x9a7f02ac88>: 1}

# %% [markdown]
# ### Writing model 1

# %%
cobra.io.save_json_model(cerevisiae, 'cerevisiaeMod1.json')
cobra.io.write_sbml_model(cerevisiae, "cerevisiaeMod1.xml")

# %% [markdown]
# ### Checking model 1

# %%
print("Reactions")
print("---------")
for x in cerevisiae.reactions:
    print("%s : %s \n lower: %s, upper: %s" % (x.id, x.reaction, x.lower_bound, x.upper_bound))
# Out:
# Reactions
# ---------
# 13BGH : 13BDglcn_c + h2o_c --> glc__D_c
#  lower: 0.0, upper: 999999.0
# 13BGHe : 13BDglcn_e + h2o_e --> glc__D_e
#  lower: 0.0, upper: 999999.0
# 13GS : udpg_c --> 13BDglcn_c + h_c + udp_c
#  lower: 0.0, upper: 999999.0
# 16GS : udpg_c --> 16BDglcn_c + h_c + udp_c
#  lower: 0.0, upper: 999999.0
# 23CAPPD : 23camp_c + h2o_c + h_c --> amp2p_c
#  lower: 0.0, upper: 999999.0
# 2DDA7Ptm : 2dda7p_c <=> 2dda7p_m
#  lower: -999999.0, upper: 999999.0
# 2DHPtm : 2dhp_c <=> 2dhp_m
#  lower: -999999.0, upper: 999999.0
# 2DOXG6PP : 2doxg6p_c + h2o_c --> 2dglc_c + pi_c
#  lower: 0.0, upper: 999999.0
# 2HBO : 2hb_c + nad_c <=> 2obut_c + h_c + nadh_c
#  lower: -999999.0, upper: 999999.0
# 2HBt2 : 2hb_e + h_e <=> 2hb_c + h_c
#  lower: -999999.0, upper: 999999.0
# 2HMHMBQMTm : 2hpmhmbq_m + amet_m --> ahcys_m + h_m + q6_m
#  lower: 0.0, upper: 999999.0
# 2HP6MPMOm : 2hp6mp_m + o2_m --> 2hp6mbq_m + h2o_m
#  lower: 0.0, upper: 999999.0
# 2HPMBQMTm : 2hp6mbq_m + amet_m --> 2hpmmbq_m + ahcys_m + h_m
#  lower: 0.0, upper: 999999.0
# 2HPMMBQMOm : 2hpmmbq_m + 0.5 o2_m --> 2hpmhmbq_m
#  lower: 0.0, upper: 999999.0
# 2MBACt : 2mbac_c --> 2mbac_e
#  lower: 0.0, upper: 999999.0
# 2MBALDt : 2mbald_c <=> 2mbald_e
#  lower: -999999.0, upper: 999999.0
# 2MBALDtm : 2mbald_c <=> 2mbald_m
#  lower: -999999.0, upper: 999999.0
# 2MBTOHt : 2mbtoh_c <=> 2mbtoh_e
#  lower: -999999.0, upper: 999999.0
# 2MBTOHtm : 2mbtoh_c <=> 2mbtoh_m
#  lower: -999999.0, upper: 999999.0
# 2MPPALt : 2mppal_c <=> 2mppal_e
#  lower: -999999.0, upper: 999999.0
# 2MPPALtm : 2mppal_c <=> 2mppal_m
#  lower: -999999.0, upper: 999999.0
# 2OBUTtm : 2obut_c <=> 2obut_m
#  lower: -999999.0, upper: 999999.0
# 2OXOADPtim : 2oxoadp_m --> 2oxoadp_c
#  lower: 0.0, upper: 999999.0
# 2PHETOHt : 2phetoh_e <=> 2phetoh_c
#  lower: -999999.0, upper: 999999.0
# 2PHETOHtm : 2phetoh_m <=> 2phetoh_c
#  lower: -999999.0, upper: 999999.0
# 34HPLFM : 34hpp_m + h_m + nadh_m --> 34hpl_m + nad_m
#  lower: 0.0, upper: 999999.0
# 34HPPOR : 34hpp_c + o2_c --> co2_c + hgentis_c
#  lower: 0.0, upper: 999999.0
# 34HPPt2m : 34hpp_c + h_c <=> 34hpp_m + h_m
#  lower: -999999.0, upper: 999999.0
# 34HPPt2p : 34hpp_c + h_c <=> 34hpp_x + h_x
#  lower: -999999.0, upper: 999999.0
# 3C3HMPt : 3c3hmp_c <=> 3c3hmp_e
#  lower: -999999.0, upper: 999999.0
# 3C3HMPtm : 3c3hmp_c <=> 3c3hmp_m
#  lower: -999999.0, upper: 999999.0
# 3C4MOPtm : 3c4mop_c <=> 3c4mop_m
#  lower: -999999.0, upper: 999999.0
# 3DH5HPBMTm : 3dh5hpb_m + amet_m --> 3hph5mb_m + ahcys_m + h_m
#  lower: 0.0, upper: 999999.0
# 3DH5HPBtm : 3dh5hpb_c <=> 3dh5hpb_m
#  lower: -999999.0, upper: 999999.0
# 3DSPHR : 3dsphgn_c + h_c + nadph_c --> nadp_c + sphgn_c
#  lower: 0.0, upper: 999999.0
# 3HAO : 3hanthrn_c + o2_c --> cmusa_c + h_c
#  lower: 0.0, upper: 999999.0
# 3HPH5MBDCm : 3hph5mb_m --> 2hp6mp_m + co2_m
#  lower: 0.0, upper: 999999.0
# 3IPM3MT : 3c2hmp_c + amet_c --> 3ipmmest_c + ahcys_c
#  lower: 0.0, upper: 999999.0
# 3MBALDt : 3mbald_c <=> 3mbald_e
#  lower: -999999.0, upper: 999999.0
# 3MBALDtm : 3mbald_c <=> 3mbald_m
#  lower: -999999.0, upper: 999999.0
# 3MOBDC : 3mob_c + h_c --> 2mppal_c + co2_c
#  lower: 0.0, upper: 999999.0
# 3MOBtm : 3mob_c <=> 3mob_m
#  lower: -999999.0, upper: 999999.0
# 3MOPDC : 3mop_c + h_c --> 2mbald_c + co2_c
#  lower: 0.0, upper: 999999.0
# 3MOPt : 3mop_e <=> 3mop_c
#  lower: -999999.0, upper: 999999.0
# 3MOPtm : 3mop_c <=> 3mop_m
#  lower: -999999.0, upper: 999999.0
# 3OPHB5Hm : 3ophb_5_c + 0.5 o2_c --> 3dh5hpb_c
#  lower: 0.0, upper: 999999.0
# 3OPHB_5tm : 3ophb_5_c <=> 3ophb_5_m
#  lower: -999999.0, upper: 999999.0
# 4ABUTNtm : 4abutn_c <=> 4abutn_m
#  lower: -999999.0, upper: 999999.0
# 4ABUTtm : 4abut_c <=> 4abut_m
#  lower: -999999.0, upper: 999999.0
# 4ABZt : 4abz_c <=> 4abz_e
#  lower: -999999.0, upper: 999999.0
# 4ABZtm : 4abz_c <=> 4abz_m
#  lower: -999999.0, upper: 999999.0
# 4H2OGLTtm : 4h2oglt_c <=> 4h2oglt_m
#  lower: -999999.0, upper: 999999.0
# 4H2OGLTtp : 4h2oglt_c <=> 4h2oglt_x
#  lower: -999999.0, upper: 999999.0
# 4HBZCOAFm : coa_m + coucoa_m + h2o_m + nad_m --> 4hbzcoa_m + accoa_m + h_m + nadh_m
#  lower: 0.0, upper: 999999.0
# 4HBZFm : 4hbzcoa_m + h2o_m --> 4hbz_m + coa_m + h_m
#  lower: 0.0, upper: 999999.0
# 4HBZtm : 4hbz_c <=> 4hbz_m
#  lower: -999999.0, upper: 999999.0
# 4HGLSDm : 4hglusa_m + h2o_m + nad_m <=> e4hglu_m + 2.0 h_m + nadh_m
#  lower: -999999.0, upper: 999999.0
# 4HPRO_LTtm : 4hpro_LT_c <=> 4hpro_LT_m
#  lower: -999999.0, upper: 999999.0
# 4HTHRS : h2o_c + phthr_c --> 4hthr_c + pi_c
#  lower: 0.0, upper: 999999.0
# 4MOPDC : 4mop_c + h_c --> 3mbald_c + co2_c
#  lower: 0.0, upper: 999999.0
# 5AOPt2 : 5aop_e + h_e --> 5aop_c + h_c
#  lower: 0.0, upper: 999999.0
# 5AOPtm : 5aop_c <=> 5aop_m
#  lower: -999999.0, upper: 999999.0
# 6PGLter : 6pgl_c <=> 6pgl_r
#  lower: -999999.0, upper: 999999.0
# 8AONNt2 : 8aonn_e + h_e <=> 8aonn_c + h_c
#  lower: -999999.0, upper: 999999.0
# AABTN : 4aabutn_c + h2o_c --> 4abut_c + ac_c
#  lower: 0.0, upper: 999999.0
# AACTOOR : aact_c + h2o_c + o2_c --> h2o2_c + mthgxl_c + nh4_c
#  lower: 0.0, upper: 999999.0
# AASAD1 : L2aadp_c + atp_c + h_c + nadph_c --> L2aadp6sa_c + amp_c + nadp_c + ppi_c
#  lower: 0.0, upper: 999999.0
# AASAD2 : L2aadp_c + atp_c + h_c + nadh_c --> L2aadp6sa_c + amp_c + nad_c + ppi_c
#  lower: 0.0, upper: 999999.0
# AATA : 2oxoadp_c + glu__L_c <=> L2aadp_c + akg_c
#  lower: -999999.0, upper: 999999.0
# ABTA : 4abut_c + akg_c --> glu__L_c + sucsal_c
#  lower: 0.0, upper: 999999.0
# ABTt : abt_e <=> abt_c
#  lower: -999999.0, upper: 999999.0
# ABUTDm : 4abutn_m + h2o_m + nad_m --> 4abut_m + 2.0 h_m + nadh_m
#  lower: 0.0, upper: 999999.0
# ABUTt2r : 4abut_e + h_e <=> 4abut_c + h_c
#  lower: -999999.0, upper: 999999.0
# ACACT1r : 2.0 accoa_c --> aacoa_c + coa_c
#  lower: 0.0, upper: 999999.0
# ACACT1m : 2.0 accoa_m --> aacoa_m + coa_m
#  lower: 0.0, upper: 999999.0
# ACACT4p : 3odcoa_x + coa_x --> accoa_x + occoa_x
#  lower: 0.0, upper: 999999.0
# ACACT5p : 3oddcoa_x + coa_x --> accoa_x + dcacoa_x
#  lower: 0.0, upper: 999999.0
# ACACT6p : 3otdcoa_x + coa_x --> accoa_x + ddcacoa_x
#  lower: 0.0, upper: 999999.0
# ACACT7p : 3ohdcoa_x + coa_x --> accoa_x + tdcoa_x
#  lower: 0.0, upper: 999999.0
# ACACT8p : 3ohodcoa_x + coa_x --> accoa_x + pmtcoa_x
#  lower: 0.0, upper: 999999.0
# ACACT9p : 3ohxccoa_x + coa_x --> accoa_x + ttccoa_x
#  lower: 0.0, upper: 999999.0
# ACALDCD : 2.0 acald_c --> actn__R_c
#  lower: 0.0, upper: 999999.0
# ACALDt : acald_e <=> acald_c
#  lower: -999999.0, upper: 999999.0
# ACALDtm : acald_m <=> acald_c
#  lower: -999999.0, upper: 999999.0
# ACCOAC : accoa_c + atp_c + hco3_c <=> adp_c + h_c + malcoa_c + pi_c
#  lower: -999999.0, upper: 999999.0
# ACCOACrm : accoa_m + atp_m + hco3_m <=> adp_m + h_m + malcoa_m + pi_m
#  lower: -999999.0, upper: 999999.0
# ACCOAtn : accoa_c <=> accoa_n
#  lower: -999999.0, upper: 999999.0
# ACESt : aces_c --> aces_e
#  lower: 0.0, upper: 999999.0
# ACGAM6PS : accoa_c + gam6p_c <=> acgam6p_c + coa_c + h_c
#  lower: -999999.0, upper: 999999.0
# ACGAMPM : acgam6p_c <=> acgam1p_c
#  lower: -999999.0, upper: 999999.0
# ACGKm : acglu_m + atp_m --> acg5p_m + adp_m
#  lower: 0.0, upper: 999999.0
# ACGSm : accoa_m + glu__L_m --> acglu_m + coa_m + h_m
#  lower: 0.0, upper: 999999.0
# ACHBSm : 2obut_m + h_m + pyr_m --> 2ahbut_m + co2_m
#  lower: 0.0, upper: 999999.0
# ACHLE1 : h2o_c + iamac_c --> ac_c + h_c + iamoh_c
#  lower: 0.0, upper: 999999.0
# ACHLE2 : h2o_c + ibutac_c --> ac_c + h_c + ibutoh_c
#  lower: 0.0, upper: 999999.0
# ACHLE3 : aces_c + h2o_c --> ac_c + etoh_c + h_c
#  lower: 0.0, upper: 999999.0
# ACLSm : h_m + 2.0 pyr_m --> alac__S_m + co2_m
#  lower: 0.0, upper: 999999.0
# ACOAHim : accoa_m + h2o_m --> ac_m + coa_m + h_m
#  lower: 0.0, upper: 999999.0
# ACOAO4p : dcacoa_x + o2_x --> dc2coa_x + h2o2_x
#  lower: 0.0, upper: 999999.0
# ACOAO5p : ddcacoa_x + o2_x --> dd2coa_x + h2o2_x
#  lower: 0.0, upper: 999999.0
# ACOAO6p : o2_x + tdcoa_x --> h2o2_x + td2coa_x
#  lower: 0.0, upper: 999999.0
# ACOAO7p : o2_x + pmtcoa_x --> h2o2_x + hdd2coa_x
#  lower: 0.0, upper: 999999.0
# ACOAO8p : o2_x + stcoa_x --> h2o2_x + od2coa_x
#  lower: 0.0, upper: 999999.0
# ACOAO9p : hexccoa_x + o2_x --> h2o2_x + hxc2coa_x
#  lower: 0.0, upper: 999999.0
# ACOATA : ACP_c + accoa_c <=> acACP_c + coa_c
#  lower: -999999.0, upper: 999999.0
# ACOATAm : ACP_m + accoa_m <=> acACP_m + coa_m
#  lower: -999999.0, upper: 999999.0
# ACON3MT : acon_T_c + amet_c --> acon5m_c + ahcys_c
#  lower: 0.0, upper: 999999.0
# ACONT : cit_c <=> icit_c
#  lower: -999999.0, upper: 999999.0
# ACONT3m : 2mcit_m <=> micit_m
#  lower: -999999.0, upper: 999999.0
# ACONTm : cit_m <=> icit_m
#  lower: -999999.0, upper: 999999.0
# ACOTAim : acg5sa_m + glu__L_m --> acorn_m + akg_m
#  lower: 0.0, upper: 999999.0
# ACP1e : fmn_e + h2o_e --> pi_e + ribflv_e
#  lower: 0.0, upper: 999999.0
# ACPSm : coa_m + h2o_m --> 2.0 h_m + pan4p_m + pap_m
#  lower: 0.0, upper: 999999.0
# ACRNtm : acrn_c --> acrn_m
#  lower: 0.0, upper: 999999.0
# ACRNtp : acrn_x --> acrn_c
#  lower: 0.0, upper: 999999.0
# ACS : ac_c + atp_c + coa_c --> accoa_c + amp_c + ppi_c
#  lower: 0.0, upper: 999999.0
# ACSm : ac_m + atp_m + coa_m --> accoa_m + amp_m + ppi_m
#  lower: 0.0, upper: 999999.0
# ACSp : ac_x + atp_x + coa_x --> accoa_x + amp_x + ppi_x
#  lower: 0.0, upper: 999999.0
# ACt2r : ac_e + h_e <=> ac_c + h_c
#  lower: -999999.0, upper: 999999.0
# ACtm : ac_c <=> ac_m
#  lower: -999999.0, upper: 999999.0
# ACtp : ac_c <=> ac_x
#  lower: -999999.0, upper: 999999.0
# ACtr : ac_e <=> ac_c
#  lower: -999999.0, upper: 999999.0
# ADA : adn_c + h2o_c + h_c --> ins_c + nh4_c
#  lower: 0.0, upper: 999999.0
# ADCL : 4adcho_c --> 4abz_c + h_c + pyr_c
#  lower: 0.0, upper: 999999.0
# ADCS : chor_c + gln__L_c --> 4adcho_c + glu__L_c
#  lower: 0.0, upper: 999999.0
# ADD : ade_c + h2o_c + h_c --> hxan_c + nh4_c
#  lower: 0.0, upper: 999999.0
# ADEt2 : ade_e + h_e --> ade_c + h_c
#  lower: 0.0, upper: 999999.0
# ADEtm : ade_c <=> ade_m
#  lower: -999999.0, upper: 999999.0
# ADHAPR_SC : 0.01 1agly3p_SC_c + h_c + nadph_c --> 0.01 1ag3p_SC_c + nadp_c
#  lower: 0.0, upper: 999999.0
# ADK1 : amp_c + atp_c <=> 2.0 adp_c
#  lower: -999999.0, upper: 999999.0
# ADK1m : amp_m + atp_m <=> 2.0 adp_m
#  lower: -999999.0, upper: 999999.0
# ADK3 : amp_c + gtp_c <=> adp_c + gdp_c
#  lower: -999999.0, upper: 999999.0
# ADK3m : amp_m + gtp_m <=> adp_m + gdp_m
#  lower: -999999.0, upper: 999999.0
# ADK4 : amp_c + itp_c <=> adp_c + idp_c
#  lower: -999999.0, upper: 999999.0
# ADK4m : amp_m + itp_m <=> adp_m + idp_m
#  lower: -999999.0, upper: 999999.0
# ADMDC : amet_c + h_c --> ametam_c + co2_c
#  lower: 0.0, upper: 999999.0
# ADNCYC : atp_c --> camp_c + ppi_c
#  lower: 0.0, upper: 999999.0
# ADNK1 : adn_c + atp_c --> adp_c + amp_c + h_c
#  lower: 0.0, upper: 999999.0
# ADNUC : adn_c + h2o_c --> ade_c + rib__D_c
#  lower: 0.0, upper: 999999.0
# ADNt2 : adn_e + h_e --> adn_c + h_c
#  lower: 0.0, upper: 999999.0
# ADPT : ade_c + prpp_c --> amp_c + ppi_c
#  lower: 0.0, upper: 999999.0
# ADSK : aps_c + atp_c --> adp_c + h_c + paps_c
#  lower: 0.0, upper: 999999.0
# ADSL1r : dcamp_c <=> amp_c + fum_c
#  lower: -999999.0, upper: 999999.0
# ADSL2r : 25aics_c <=> aicar_c + fum_c
#  lower: -999999.0, upper: 999999.0
# ADSS : asp__L_c + gtp_c + imp_c --> dcamp_c + gdp_c + 2.0 h_c + pi_c
#  lower: 0.0, upper: 999999.0
# AGAT_SC : 0.01 1ag3p_SC_c + 0.02 dcacoa_c + 0.06 ddcacoa_c + 0.17 hdcoa_c + 0.09 ocdycacoa_c + 0.24 odecoa_c + 0.27 pmtcoa_c + 0.05 stcoa_c + 0.1 tdcoa_c --> coa_c + 0.01 pa_SC_c
#  lower: 0.0, upper: 999999.0
# AGPRim : acg5p_m + h_m + nadph_m --> acg5sa_m + nadp_m + pi_m
#  lower: 0.0, upper: 999999.0
# AGTi : ala__L_c + glx_c --> gly_c + pyr_c
#  lower: 0.0, upper: 999999.0
# AHCYStm : ahcys_c <=> ahcys_m
#  lower: -999999.0, upper: 999999.0
# AHCi : ahcys_c + h2o_c --> adn_c + hcys__L_c
#  lower: 0.0, upper: 999999.0
# AHMMPS : air_c + 2.0 h_c --> 4ahmmp_c + gcald_c + pi_c
#  lower: 0.0, upper: 999999.0
# AHSERL : achms_c + ch4s_c --> ac_c + h_c + met__L_c
#  lower: 0.0, upper: 999999.0
# AHSERL2 : achms_c + h2s_c --> ac_c + h_c + hcys__L_c
#  lower: 0.0, upper: 999999.0
# AICART : 10fthf_c + aicar_c <=> fprica_c + thf_c
#  lower: -999999.0, upper: 999999.0
# AIRCr : air_c + co2_c <=> 5aizc_c + h_c
#  lower: -999999.0, upper: 999999.0
# AKGDam : akg_m + h_m + lpam_m <=> co2_m + sdhlam_m
#  lower: -999999.0, upper: 999999.0
# AKGDbm : coa_m + sdhlam_m --> dhlam_m + succoa_m
#  lower: 0.0, upper: 999999.0
# AKGMAL : akg_c + mal__L_e <=> akg_e + mal__L_c
#  lower: -999999.0, upper: 999999.0
# AKGt2n : akg_c + h_c <=> akg_n + h_n
#  lower: -999999.0, upper: 999999.0
# AKGt2r : akg_e + h_e <=> akg_c + h_c
#  lower: -999999.0, upper: 999999.0
# AKGtp : akg_c <=> akg_x
#  lower: -999999.0, upper: 999999.0
# AKP1 : ahdt_c + 3.0 h2o_c --> dhnpt_c + 2.0 h_c + 3.0 pi_c
#  lower: 0.0, upper: 999999.0
# ALASm : gly_m + h_m + succoa_m --> 5aop_m + co2_m + coa_m
#  lower: 0.0, upper: 999999.0
# ALATA_L : akg_c + ala__L_c <=> glu__L_c + pyr_c
#  lower: -999999.0, upper: 999999.0
# ALATA_Lm : akg_m + ala__L_m <=> glu__L_m + pyr_m
#  lower: -999999.0, upper: 999999.0
# ALATRS : ala__L_c + atp_c + trnaala_c --> alatrna_c + amp_c + ppi_c
#  lower: 0.0, upper: 999999.0
# ALAt2r : ala__L_e + h_e <=> ala__L_c + h_c
#  lower: -999999.0, upper: 999999.0
# ALAtmi : ala__L_m --> ala__L_c
#  lower: 0.0, upper: 999999.0
# ALCD19y : glyald_c + h_c + nadph_c --> glyc_c + nadp_c
#  lower: 0.0, upper: 999999.0
# ALCD22xi : 2mbald_c + h_c + nadh_c --> 2mbtoh_c + nad_c
#  lower: 0.0, upper: 999999.0
# ALCD22xim : 2mbald_m + h_m + nadh_m --> 2mbtoh_m + nad_m
#  lower: 0.0, upper: 999999.0
# ALCD22yi : 2mbald_c + h_c + nadph_c --> 2mbtoh_c + nadp_c
#  lower: 0.0, upper: 999999.0
# ALCD23xi : 2mppal_c + h_c + nadh_c --> ibutoh_c + nad_c
#  lower: 0.0, upper: 999999.0
# ALCD23xim : 2mppal_m + h_m + nadh_m --> ibutoh_m + nad_m
#  lower: 0.0, upper: 999999.0
# ALCD23yi : 2mppal_c + h_c + nadph_c --> ibutoh_c + nadp_c
#  lower: 0.0, upper: 999999.0
# ALCD24xi : 3mbald_c + h_c + nadh_c --> iamoh_c + nad_c
#  lower: 0.0, upper: 999999.0
# ALCD24xim : 3mbald_m + h_m + nadh_m --> iamoh_m + nad_m
#  lower: 0.0, upper: 999999.0
# ALCD24yi : 3mbald_c + h_c + nadph_c --> iamoh_c + nadp_c
#  lower: 0.0, upper: 999999.0
# ALCD25xi : h_c + nadh_c + pacald_c --> 2phetoh_c + nad_c
#  lower: 0.0, upper: 999999.0
# ALCD25xim : h_m + nadh_m + pacald_m --> 2phetoh_m + nad_m
#  lower: 0.0, upper: 999999.0
# ALCD25yi : h_c + nadph_c + pacald_c --> 2phetoh_c + nadp_c
#  lower: 0.0, upper: 999999.0
# ALCD26xi : h_c + id3acald_c + nadh_c --> ind3eth_c + nad_c
#  lower: 0.0, upper: 999999.0
# ALCD26xim : h_m + id3acald_m + nadh_m --> ind3eth_m + nad_m
#  lower: 0.0, upper: 999999.0
# ALCD2x_copy1 : etoh_c + nad_c --> acald_c + h_c + nadh_c
#  lower: 0.0, upper: 999999.0
# ALCD2ir : acald_c + h_c + nadh_c --> etoh_c + nad_c
#  lower: 0.0, upper: 999999.0
# ALCD2irm : acald_m + h_m + nadh_m --> etoh_m + nad_m
#  lower: 0.0, upper: 999999.0
# ALCD2x_copy2 : etoh_c + nad_c <=> acald_c + h_c + nadh_c
#  lower: -999999.0, upper: 999999.0
# ALDD19xr : h2o_c + nad_c + pacald_c --> 2.0 h_c + nadh_c + pac_c
#  lower: 0.0, upper: 999999.0
# ALDD20xm : h2o_m + id3acald_m + nad_m --> 2.0 h_m + ind3ac_m + nadh_m
#  lower: 0.0, upper: 999999.0
# ALDD20y : h2o_c + id3acald_c + nadp_c --> 2.0 h_c + ind3ac_c + nadph_c
#  lower: 0.0, upper: 999999.0
# ALDD20ym : h2o_m + id3acald_m + nadp_m --> 2.0 h_m + ind3ac_m + nadph_m
#  lower: 0.0, upper: 999999.0
# ALDD22x : aproa_c + h2o_c + nad_c --> ala_B_c + 2.0 h_c + nadh_c
#  lower: 0.0, upper: 999999.0
# ALDD2xm : acald_m + h2o_m + nad_m --> ac_m + 2.0 h_m + nadh_m
#  lower: 0.0, upper: 999999.0
# ALDD2y : acald_c + h2o_c + nadp_c --> ac_c + 2.0 h_c + nadph_c
#  lower: 0.0, upper: 999999.0
# ALDD2ym : acald_m + h2o_m + nadp_m --> ac_m + 2.0 h_m + nadph_m
#  lower: 0.0, upper: 999999.0
# ALLTAHr : alltt_c + h2o_c <=> urdglyc_c + urea_c
#  lower: -999999.0, upper: 999999.0
# ALLTN : alltn_c + h2o_c <=> alltt_c + h_c
#  lower: -999999.0, upper: 999999.0
# ALLTNti : alltn_e --> alltn_c
#  lower: 0.0, upper: 999999.0
# ALLTTti : alltt_e --> alltt_c
#  lower: 0.0, upper: 999999.0
# ALPHNH : allphn_c + h2o_c + 3.0 h_c --> 2.0 co2_c + 2.0 nh4_c
#  lower: 0.0, upper: 999999.0
# AMAOTr : 8aonn_c + amet_c <=> amob_c + dann_c
#  lower: -999999.0, upper: 999999.0
# AMETt2 : amet_e + h_e --> amet_c + h_c
#  lower: 0.0, upper: 999999.0
# AMETtm : amet_c <=> amet_m
#  lower: -999999.0, upper: 999999.0
# AMID : 4gudbd_c + h2o_c --> 4gudbutn_c + nh4_c
#  lower: 0.0, upper: 999999.0
# AMID2 : h2o_c + pad_c --> nh4_c + pac_c
#  lower: 0.0, upper: 999999.0
# AMID3 : h2o_c + iad_c --> ind3ac_c + nh4_c
#  lower: 0.0, upper: 999999.0
# AMPDA : amp_c + h2o_c + h_c --> imp_c + nh4_c
#  lower: 0.0, upper: 999999.0
# AMPN : amp_c + h2o_c --> ade_c + r5p_c
#  lower: 0.0, upper: 999999.0
# AMPtn : amp_n <=> amp_c
#  lower: -999999.0, upper: 999999.0
# ANPRT : anth_c + prpp_c --> ppi_c + pran_c
#  lower: 0.0, upper: 999999.0
# ANS : chor_c + gln__L_c --> anth_c + glu__L_c + h_c + pyr_c
#  lower: 0.0, upper: 999999.0
# AOBUTDs : 2aobut_c + h_c --> aact_c + co2_c
#  lower: 0.0, upper: 999999.0
# AP4AH : ap4a_c + h2o_c <=> 2.0 adp_c + 2.0 h_c
#  lower: -999999.0, upper: 999999.0
# APRTO2 : aprut_c + h2o_c + o2_c --> h2o2_c + n4abutn_c + nh4_c
#  lower: 0.0, upper: 999999.0
# ARAB14LO : Dara14lac_c + o2_c <=> ertascb__D_c + h2o2_c
#  lower: -999999.0, upper: 999999.0
# ARAB1D2 : arab__D_c + nadp_c --> Dara14lac_c + h_c + nadph_c
#  lower: 0.0, upper: 999999.0
# ARABR : arab__L_c + h_c + nadph_c --> abt_c + nadp_c
#  lower: 0.0, upper: 999999.0
# ARAB_Dt : arab__D_e <=> arab__D_c
#  lower: -999999.0, upper: 999999.0
# ARAB_Lt : arab__L_e <=> arab__L_c
#  lower: -999999.0, upper: 999999.0
# ARGN : arg__L_c + h2o_c --> orn_c + urea_c
#  lower: 0.0, upper: 999999.0
# ARGSL : argsuc_c <=> arg__L_c + fum_c
#  lower: -999999.0, upper: 999999.0
# ARGSS : asp__L_c + atp_c + citr__L_c <=> amp_c + argsuc_c + h_c + ppi_c
#  lower: -999999.0, upper: 999999.0
# ARGTRS : arg__L_c + atp_c + trnaarg_c --> amp_c + argtrna_c + ppi_c
#  lower: 0.0, upper: 999999.0
# ARGTRSm : arg__L_m + atp_m + trnaarg_m --> amp_m + argtrna_m + ppi_m
#  lower: 0.0, upper: 999999.0
# ARGt2m : arg__L_c + h_c <=> arg__L_m + h_m
#  lower: -999999.0, upper: 999999.0
# ARGt2r : arg__L_e + h_e <=> arg__L_c + h_c
#  lower: -999999.0, upper: 999999.0
# ARGt6 : arg__L_c + h_v --> arg__L_v + h_c
#  lower: 0.0, upper: 999999.0
# ARMT : amet_c + his__L_c --> NPmehis_c + ahcys_c + h_c
#  lower: 0.0, upper: 999999.0
# ASAD : aspsa_c + nadp_c + pi_c <-- 4pasp_c + h_c + nadph_c
#  lower: -999999.0, upper: 0.0
# ASNN : asn__L_c + h2o_c --> asp__L_c + nh4_c
#  lower: 0.0, upper: 999999.0
# ASNNe : asn__L_e + h2o_e --> asp__L_e + nh4_e
#  lower: 0.0, upper: 999999.0
# ASNS1 : asp__L_c + atp_c + gln__L_c + h2o_c --> amp_c + asn__L_c + glu__L_c + h_c + ppi_c
#  lower: 0.0, upper: 999999.0
# ASNTRS : asn__L_c + atp_c + trnaasn_c --> amp_c + asntrna_c + ppi_c
#  lower: 0.0, upper: 999999.0
# ASNTRSm : asn__L_m + atp_m + trnaasn_m --> amp_m + asntrna_m + ppi_m
#  lower: 0.0, upper: 999999.0
# ASNt2m : asn__L_c + h_c <=> asn__L_m + h_m
#  lower: -999999.0, upper: 999999.0
# ASNt2r : asn__L_e + h_e <=> asn__L_c + h_c
#  lower: -999999.0, upper: 999999.0
# ASNt6 : asn__L_c + h_v --> asn__L_v + h_c
#  lower: 0.0, upper: 999999.0
# ASNt7 : asn__L_v + h_v --> asn__L_c + h_c
#  lower: 0.0, upper: 999999.0
# ASPCT : asp__L_c + cbp_c --> cbasp_c + h_c + pi_c
#  lower: 0.0, upper: 999999.0
# ASPGLU2m : asp__L_m + glu__L_c --> asp__L_c + glu__L_m
#  lower: 0.0, upper: 999999.0
# ASPGLUtp : asp__L_c + glu__L_x <=> asp__L_x + glu__L_c
#  lower: -999999.0, upper: 999999.0
# ASPK : asp__L_c + atp_c --> 4pasp_c + adp_c
#  lower: 0.0, upper: 999999.0
# ASPOcm : asp__L_c + fad_m --> fadh2_m + h_c + iasp_c
#  lower: 0.0, upper: 999999.0
# ASPTA : akg_c + asp__L_c <=> glu__L_c + oaa_c
#  lower: -999999.0, upper: 999999.0
# ASPTAm : akg_m + asp__L_m <=> glu__L_m + oaa_m
#  lower: -999999.0, upper: 999999.0
# ASPTAp : akg_x + asp__L_x <=> glu__L_x + oaa_x
#  lower: -999999.0, upper: 999999.0
# ASPTRS : asp__L_c + atp_c + trnaasp_c --> amp_c + asptrna_c + ppi_c
#  lower: 0.0, upper: 999999.0
# ASPTRSm : asp__L_m + atp_m + trnaasp_m --> amp_m + asptrna_m + ppi_m
#  lower: 0.0, upper: 999999.0
# ASPt2m : asp__L_c + h_c <=> asp__L_m + h_m
#  lower: -999999.0, upper: 999999.0
# ASPt2n : asp__L_c + h_c <=> asp__L_n + h_n
#  lower: -999999.0, upper: 999999.0
# ASPt2r : asp__L_e + h_e <=> asp__L_c + h_c
#  lower: -999999.0, upper: 999999.0
# ASPt5n : asp__L_n <=> asp__L_c
#  lower: -999999.0, upper: 999999.0
# ASPt7 : asp__L_v + h_v --> asp__L_c + h_c
#  lower: 0.0, upper: 999999.0
# ATHRDHr : athr__L_c + nadp_c <=> 2aobut_c + h_c + nadph_c
#  lower: -999999.0, upper: 999999.0
# ATP2tp_H : amp_x + atp_c + h_x --> amp_c + atp_x + h_c
#  lower: 0.0, upper: 999999.0
# ATPATF1 : adp_c + atp_c + h_c --> ap4a_c + pi_c
#  lower: 0.0, upper: 999999.0
# ATPATF2 : adp_c + gtp_c + h_c --> ap4g_c + pi_c
#  lower: 0.0, upper: 999999.0
# ATPATF3 : gdp_c + gtp_c + h_c --> gp4g_c + pi_c
#  lower: 0.0, upper: 999999.0
# ATPH1 : atp_c + 2.0 h2o_c --> amp_c + 2.0 h_c + 2.0 pi_c
#  lower: 0.0, upper: 999999.0
# ATPM : atp_c + h2o_c --> adp_c + h_c + pi_c
#  lower: 1.0, upper: 1.0
# ATPPRT : atp_c + prpp_c --> ppi_c + prbatp_c
#  lower: 0.0, upper: 999999.0
# ATPS : atp_c + h2o_c --> adp_c + h_e + pi_c
#  lower: 0.0, upper: 999999.0
# ATPS3g : adp_g + 3.0 h_c + pi_g --> atp_g + h2o_g + 2.0 h_g
#  lower: 0.0, upper: 999999.0
# ATPS3m : adp_m + 3.0 h_c + pi_m --> atp_m + h2o_m + 2.0 h_m
#  lower: 0.0, upper: 999999.0
# ATPS3v : adp_v + 3.0 h_c + pi_v --> atp_v + h2o_v + 2.0 h_v
#  lower: 0.0, upper: 999999.0
# ATPtm_H : adp_c + atp_m + h_c --> adp_m + atp_c + h_m
#  lower: 0.0, upper: 999999.0
# ATPtp_H : adp_x + atp_c + h_x --> adp_c + atp_x + h_c
#  lower: 0.0, upper: 999999.0
# BACCL : atp_c + btn_c + h_c --> btamp_c + ppi_c
#  lower: 0.0, upper: 999999.0
# BPNT : h2o_c + pap_c --> amp_c + pi_c
#  lower: 0.0, upper: 999999.0
# BTDD_RR : btd_RR_c + nad_c <=> actn__R_c + h_c + nadh_c
#  lower: -999999.0, upper: 999999.0
# BTDt_RR : btd_RR_c <=> btd_RR_e
#  lower: -999999.0, upper: 999999.0
# BTNt2i : btn_e + h_e --> btn_c + h_c
#  lower: 0.0, upper: 999999.0
# BTSr : dtbt_c + s_c <=> btn_c + 2.0 h_c
#  lower: -999999.0, upper: 999999.0
# C14STR : 44mctr_c + h_c + nadph_c --> 44mzym_c + nadp_c
#  lower: 0.0, upper: 999999.0
# C22STDS : ergtrol_c + h_c + nadph_c + o2_c --> ergtetrol_c + 2.0 h2o_c + nadp_c
#  lower: 0.0, upper: 999999.0
# C22STDSx : ergtrol_c + h_c + nadh_c + o2_c --> ergtetrol_c + 2.0 h2o_c + nad_c
#  lower: 0.0, upper: 999999.0
# C24STRer : ergtetrol_r + h_r + nadph_r --> ergst_r + nadp_r
#  lower: 0.0, upper: 999999.0
# C3STDH1 : 4mzym_int1_c + nad_c --> 4mzym_int2_c + co2_c + h_c + nadh_c
#  lower: 0.0, upper: 999999.0
# C3STDH2 : nad_c + zym_int1_c --> co2_c + h_c + nadh_c + zym_int2_c
#  lower: 0.0, upper: 999999.0
# C3STKR1 : 4mzym_int2_c + h_c + nadph_c --> 4mzym_c + nadp_c
#  lower: 0.0, upper: 999999.0
# C3STKR2 : h_c + nadph_c + zym_int2_c --> nadp_c + zymst_c
#  lower: 0.0, upper: 999999.0
# C4STMO1 : 44mzym_c + 3.0 h_c + 3.0 nadph_c + 3.0 o2_c --> 4mzym_int1_c + 4.0 h2o_c + 3.0 nadp_c
#  lower: 0.0, upper: 999999.0
# C4STMO2 : 4mzym_c + 3.0 h_c + 3.0 nadph_c + 3.0 o2_c --> 4.0 h2o_c + 3.0 nadp_c + zym_int1_c
#  lower: 0.0, upper: 999999.0
# C5STDS : epist_c + h_c + nadph_c + o2_c --> ergtrol_c + 2.0 h2o_c + nadp_c
#  lower: 0.0, upper: 999999.0
# C8STI : fecost_c --> epist_c
#  lower: 0.0, upper: 999999.0
# CAT : 2.0 h2o2_c --> 2.0 h2o_c + o2_c
#  lower: 0.0, upper: 999999.0
# CATp : 2.0 h2o2_x --> 2.0 h2o_x + o2_x
#  lower: 0.0, upper: 999999.0
# CBASPtn : cbasp_n <=> cbasp_c
#  lower: -999999.0, upper: 999999.0
# CBPS : 2.0 atp_c + gln__L_c + h2o_c + hco3_c --> 2.0 adp_c + cbp_c + glu__L_c + 2.0 h_c + pi_c
#  lower: 0.0, upper: 999999.0
# CBPtn : cbp_c <=> cbp_n
#  lower: -999999.0, upper: 999999.0
# CCP2m : 2.0 focytc_m + h2o2_m --> 2.0 ficytc_m + 2.0 h2o_m
#  lower: 0.0, upper: 999999.0
# CDPDGPm_SC : 0.01 cdpdag_SC_m + glyc3p_m <=> cmp_m + h_m + 0.01 pgp_SC_m
#  lower: -999999.0, upper: 999999.0
# CDPtn : cdp_c <=> cdp_n
#  lower: -999999.0, upper: 999999.0
# CER1_24ter : cer1_24_c <=> cer1_24_r
#  lower: -999999.0, upper: 999999.0
# CER1_26ter : cer1_26_c <=> cer1_26_r
#  lower: -999999.0, upper: 999999.0
# CER2_24ter : cer2_24_c <=> cer2_24_r
#  lower: -999999.0, upper: 999999.0
# CER2_26ter : cer2_26_c <=> cer2_26_r
#  lower: -999999.0, upper: 999999.0
# CERASE124er : cer1_24_r + coa_r + h_r --> sphgn_r + ttccoa_r
#  lower: 0.0, upper: 999999.0
# CERASE126er : cer1_26_r + coa_r + h_r --> hexccoa_r + sphgn_r
#  lower: 0.0, upper: 999999.0
# CERASE224er : cer2_24_r + coa_r + h_r --> psphings_r + ttccoa_r
#  lower: 0.0, upper: 999999.0
# CERASE226er : cer2_26_r + coa_r + h_r --> hexccoa_r + psphings_r
#  lower: 0.0, upper: 999999.0
# CERH124_copy1 : cer1_24_c + h_c + nadph_c + o2_c --> cer2_24_c + h2o_c + nadp_c
#  lower: 0.0, upper: 999999.0
# CERH126_copy1 : cer1_26_c + h_c + nadph_c + o2_c --> cer2_26_c + h2o_c + nadp_c
#  lower: 0.0, upper: 999999.0
# CERS124 : sphgn_c + ttccoa_c --> cer1_24_c + coa_c + h_c
#  lower: 0.0, upper: 999999.0
# CERS124er : sphgn_r + ttccoa_r --> cer1_24_r + coa_r + h_r
#  lower: 0.0, upper: 999999.0
# CERS126 : hexccoa_c + sphgn_c --> cer1_26_c + coa_c + h_c
#  lower: 0.0, upper: 999999.0
# CERS126er : hexccoa_r + sphgn_r --> cer1_26_r + coa_r + h_r
#  lower: 0.0, upper: 999999.0
# CERS224 : psphings_c + ttccoa_c --> cer2_24_c + coa_c + h_c
#  lower: 0.0, upper: 999999.0
# CERS224er : psphings_r + ttccoa_r --> cer2_24_r + coa_r + h_r
#  lower: 0.0, upper: 999999.0
# CERS226 : hexccoa_c + psphings_c --> cer2_26_c + coa_c + h_c
#  lower: 0.0, upper: 999999.0
# CERS226er : hexccoa_r + psphings_r --> cer2_26_r + coa_r + h_r
#  lower: 0.0, upper: 999999.0
# CERH124_copy2 : cer1_24_c + h_c + nadph_c + o2_c --> cer2_24_c + h2o_c + nadp_c
#  lower: 0.0, upper: 999999.0
# CERH126_copy2 : cer1_26_c + h_c + nadph_c + o2_c --> cer2_26_c + h2o_c + nadp_c
#  lower: 0.0, upper: 999999.0
# CERS324 : cer2_24_c + h_c + nadph_c + o2_c --> cer3_24_c + h2o_c + nadp_c
#  lower: 0.0, upper: 999999.0
# CERS326 : cer2_26_c + h_c + nadph_c + o2_c --> cer3_26_c + h2o_c + nadp_c
#  lower: 0.0, upper: 999999.0
# CHLPCTD : cholp_c + ctp_c + h_c --> cdpchol_c + ppi_c
#  lower: 0.0, upper: 999999.0
# CHLSTI : amet_c + o2_c + zymst_c --> ahcys_c + ergtetrol_c + 2.0 h2o_c + h_c
#  lower: 0.0, upper: 999999.0
# CHLt2 : chol_e + h_e --> chol_c + h_c
#  lower: 0.0, upper: 999999.0
# CHOLK : atp_c + chol_c --> adp_c + cholp_c + h_c
#  lower: 0.0, upper: 999999.0
# CHORM : chor_c --> pphn_c
#  lower: 0.0, upper: 999999.0
# CHORS : 3psme_c --> chor_c + pi_c
#  lower: 0.0, upper: 999999.0
# CHRPL : chor_c --> 4hbz_c + pyr_c
#  lower: 0.0, upper: 999999.0
# CHTNDA : chitin_c + h2o_c --> ac_c + chitos_c + h_c
#  lower: 0.0, upper: 999999.0
# CHTNS : udpacgal_c --> chitin_c + h_c + udp_c
#  lower: 0.0, upper: 999999.0
# CITt2r : cit_e + h_e <=> cit_c + h_c
#  lower: -999999.0, upper: 999999.0
# CITtam : cit_c + mal__L_m <=> cit_m + mal__L_c
#  lower: -999999.0, upper: 999999.0
# CITtap : cit_x + mal__L_c <=> cit_c + mal__L_x
#  lower: -999999.0, upper: 999999.0
# CITtbm : cit_c + pep_m <=> cit_m + pep_c
#  lower: -999999.0, upper: 999999.0
# CITtcm : cit_c + icit_m <=> cit_m + icit_c
#  lower: -999999.0, upper: 999999.0
# CITtcp : cit_c + icit_x <=> cit_x + icit_c
#  lower: -999999.0, upper: 999999.0
# CLPNSm_SC : 0.01 cdpdag_SC_m + 0.01 pg_SC_m --> 0.01 clpn_SC_m + cmp_m + h_m
#  lower: 0.0, upper: 999999.0
# CMPN : cmp_c + h2o_c --> csn_c + r5p_c
#  lower: 0.0, upper: 999999.0
# CO2t : co2_e <=> co2_c
#  lower: -999999.0, upper: 999999.0
# CO2tg : co2_c <=> co2_g
#  lower: -999999.0, upper: 999999.0
# CO2tm : co2_c <=> co2_m
#  lower: -999999.0, upper: 999999.0
# CO2tn : co2_n <=> co2_c
#  lower: -999999.0, upper: 999999.0
# CO2tp : co2_c <=> co2_x
#  lower: -999999.0, upper: 999999.0
# CO2tv : co2_c <=> co2_v
#  lower: -999999.0, upper: 999999.0
# COAHLp : coa_x + h2o_x --> 2.0 h_x + pan4p_x + pap_x
#  lower: 0.0, upper: 999999.0
# COAtim : coa_c --> coa_m
#  lower: 0.0, upper: 999999.0
# COAtn : coa_c <=> coa_n
#  lower: -999999.0, upper: 999999.0
# COUCOAFm : T4hcinnm_m + atp_m + coa_m --> amp_m + coucoa_m + ppi_m
#  lower: 0.0, upper: 999999.0
# CPPPGO : cpppg3_c + 2.0 h_c + o2_c --> 2.0 co2_c + 2.0 h2o_c + pppg9_c
#  lower: 0.0, upper: 999999.0
# CRNCARtm : acrn_c + crn_m --> acrn_m + crn_c
#  lower: 0.0, upper: 999999.0
# CRNCARtp : acrn_x + crn_c --> acrn_c + crn_x
#  lower: 0.0, upper: 999999.0
# CRNt : crn_e <=> crn_c
#  lower: -999999.0, upper: 999999.0
# CRNtim : crn_m --> crn_c
#  lower: 0.0, upper: 999999.0
# CRNtp : crn_c --> crn_x
#  lower: 0.0, upper: 999999.0
# CSNATm : acrn_m + coa_m <=> accoa_m + crn_m
#  lower: -999999.0, upper: 999999.0
# CSNATp : accoa_x + crn_x <=> acrn_x + coa_x
#  lower: -999999.0, upper: 999999.0
# CSNATr : accoa_c + crn_c <=> acrn_c + coa_c
#  lower: -999999.0, upper: 999999.0
# CSND : csn_c + h2o_c + h_c --> nh4_c + ura_c
#  lower: 0.0, upper: 999999.0
# CSNt2 : csn_e + h_e --> csn_c + h_c
#  lower: 0.0, upper: 999999.0
# CSm : accoa_m + h2o_m + oaa_m --> cit_m + coa_m + h_m
#  lower: 0.0, upper: 999999.0
# CSp : accoa_x + h2o_x + oaa_x --> cit_x + coa_x + h_x
#  lower: 0.0, upper: 999999.0
# CTPS1 : atp_c + nh4_c + utp_c --> adp_c + ctp_c + 2.0 h_c + pi_c
#  lower: 0.0, upper: 999999.0
# CTPS2 : atp_c + gln__L_c + h2o_c + utp_c --> adp_c + ctp_c + glu__L_c + 2.0 h_c + pi_c
#  lower: 0.0, upper: 999999.0
# CTPtm : cmp_m + ctp_c + 2.0 h_c --> cmp_c + ctp_m + 2.0 h_m
#  lower: 0.0, upper: 999999.0
# CYOOm : 4.0 focytc_m + 6.0 h_m + o2_m --> 4.0 ficytc_m + 2.0 h2o_m + 6.0 h_c
#  lower: 0.0, upper: 999999.0
# CYOR_u6m : 2.0 ficytc_m + 1.5 h_m + q6h2_m --> 2.0 focytc_m + 1.5 h_c + q6_m
#  lower: 0.0, upper: 999999.0
# CYSS : acser_c + h2s_c --> ac_c + cys__L_c + h_c
#  lower: 0.0, upper: 999999.0
# CYSTGL : cyst__L_c + h2o_c --> 2obut_c + cys__L_c + nh4_c
#  lower: 0.0, upper: 999999.0
# CYSTL : cyst__L_c + h2o_c --> hcys__L_c + nh4_c + pyr_c
#  lower: 0.0, upper: 999999.0
# CYSTLp : cyst__L_x + h2o_x --> hcys__L_x + nh4_x + pyr_x
#  lower: 0.0, upper: 999999.0
# CYSTRS : atp_c + cys__L_c + trnacys_c --> amp_c + cystrna_c + ppi_c
#  lower: 0.0, upper: 999999.0
# CYSTS : hcys__L_c + ser__L_c --> cyst__L_c + h2o_c
#  lower: 0.0, upper: 999999.0
# CYSTtp : cyst__L_c <=> cyst__L_x
#  lower: -999999.0, upper: 999999.0
# CYSt2r : cys__L_e + h_e <=> cys__L_c + h_c
#  lower: -999999.0, upper: 999999.0
# CYTD : cytd_c + h2o_c + h_c --> nh4_c + uri_c
#  lower: 0.0, upper: 999999.0
# CYTDK2 : cytd_c + gtp_c --> cmp_c + gdp_c + h_c
#  lower: 0.0, upper: 999999.0
# CYTDt2 : cytd_e + h_e --> cytd_c + h_c
#  lower: 0.0, upper: 999999.0
# CYTK1 : atp_c + cmp_c <=> adp_c + cdp_c
#  lower: -999999.0, upper: 999999.0
# CYTK2 : atp_c + dcmp_c <=> adp_c + dcdp_c
#  lower: -999999.0, upper: 999999.0
# DADA : dad_2_c + h2o_c + h_c --> din_c + nh4_c
#  lower: 0.0, upper: 999999.0
# DADK : atp_c + damp_c <=> adp_c + dadp_c
#  lower: -999999.0, upper: 999999.0
# DADNt2 : dad_2_e + h_e --> dad_2_c + h_c
#  lower: 0.0, upper: 999999.0
# DADPtn : dadp_c <=> dadp_n
#  lower: -999999.0, upper: 999999.0
# DAGCPT_SC : 0.01 12dgr_SC_c + cdpchol_c --> cmp_c + h_c + 0.01 pc_SC_c
#  lower: 0.0, upper: 999999.0
# DAGPYP_SC : h2o_c + 0.01 pa_SC_c --> 0.01 12dgr_SC_c + pi_c
#  lower: 0.0, upper: 999999.0
# DANNt2 : dann_e + h_e <=> dann_c + h_c
#  lower: -999999.0, upper: 999999.0
# DASYN_SC : ctp_c + h_c + 0.01 pa_SC_c <=> 0.01 cdpdag_SC_c + ppi_c
#  lower: -999999.0, upper: 999999.0
# DASYNm_SC : ctp_m + h_m + 0.01 pa_SC_m <=> 0.01 cdpdag_SC_m + ppi_m
#  lower: -999999.0, upper: 999999.0
# DB4PS : ru5p__D_c --> db4p_c + for_c + h_c
#  lower: 0.0, upper: 999999.0
# DBTS : atp_c + co2_c + dann_c <=> adp_c + dtbt_c + 3.0 h_c + pi_c
#  lower: -999999.0, upper: 999999.0
# DCDPtn : dcdp_c <=> dcdp_n
#  lower: -999999.0, upper: 999999.0
# DCMPDA : dcmp_c + h2o_c + h_c <=> dump_c + nh4_c
#  lower: -999999.0, upper: 999999.0
# DCTPD : dctp_c + h2o_c + h_c --> dutp_c + nh4_c
#  lower: 0.0, upper: 999999.0
# DCYTD : dcyt_c + h2o_c + h_c --> duri_c + nh4_c
#  lower: 0.0, upper: 999999.0
# DCYTt2 : dcyt_e + h_e --> dcyt_c + h_c
#  lower: 0.0, upper: 999999.0
# DDPA : e4p_c + h2o_c + pep_c --> 2dda7p_c + pi_c
#  lower: 0.0, upper: 999999.0
# DDPAm : e4p_m + h2o_m + pep_m --> 2dda7p_m + pi_m
#  lower: 0.0, upper: 999999.0
# DESAT14 : h_c + nadph_c + o2_c + tdcoa_c --> 2.0 h2o_c + nadp_c + tdecoa_c
#  lower: 0.0, upper: 999999.0
# DESAT16 : h_c + nadph_c + o2_c + pmtcoa_c --> 2.0 h2o_c + hdcoa_c + nadp_c
#  lower: 0.0, upper: 999999.0
# DESAT18 : h_c + nadph_c + o2_c + stcoa_c --> 2.0 h2o_c + nadp_c + odecoa_c
#  lower: 0.0, upper: 999999.0
# DESAT18_2 : h_c + nadph_c + o2_c + odecoa_c --> 2.0 h2o_c + nadp_c + ocdycacoa_c
#  lower: 0.0, upper: 999999.0
# DGDPtn : dgdp_c <=> dgdp_n
#  lower: -999999.0, upper: 999999.0
# DGGH : 6dg_c + h2o_c --> gal_c + glc__D_c
#  lower: 0.0, upper: 999999.0
# DGK1 : atp_c + dgmp_c <=> adp_c + dgdp_c
#  lower: -999999.0, upper: 999999.0
# DGSNt2 : dgsn_e + h_e --> dgsn_c + h_c
#  lower: 0.0, upper: 999999.0
# DHAD1m : 23dhmb_m --> 3mob_m + h2o_m
#  lower: 0.0, upper: 999999.0
# DHAD2m : 23dhmp_m --> 3mop_m + h2o_m
#  lower: 0.0, upper: 999999.0
# DHAK : atp_c + dha_c --> adp_c + dhap_c + h_c
#  lower: 0.0, upper: 999999.0
# DHAPtm : dhap_m --> dhap_c
#  lower: 0.0, upper: 999999.0
# DHFR : dhf_c + h_c + nadph_c --> nadp_c + thf_c
#  lower: 0.0, upper: 999999.0
# DHFRim : dhf_m + h_m + nadph_m --> nadp_m + thf_m
#  lower: 0.0, upper: 999999.0
# DHFS : atp_c + dhpt_c + glu__L_c --> adp_c + dhf_c + h_c + pi_c
#  lower: 0.0, upper: 999999.0
# DHFtm : dhf_c <=> dhf_m
#  lower: -999999.0, upper: 999999.0
# DHNPAm : dhnpt_m --> 2ahhmp_m + gcald_m + h_m
#  lower: 0.0, upper: 999999.0
# DHNPTtm : dhnpt_c <=> dhnpt_m
#  lower: -999999.0, upper: 999999.0
# DHORD4i : dhor__S_c + q6_m --> orot_c + q6h2_m
#  lower: 0.0, upper: 999999.0
# DHORDfum : dhor__S_c + fum_c --> orot_c + succ_c
#  lower: 0.0, upper: 999999.0
# DHORDi : dhor__S_c + o2_c --> h2o2_c + orot_c
#  lower: 0.0, upper: 999999.0
# DHORTS : dhor__S_c + h2o_c <=> cbasp_c + h_c
#  lower: -999999.0, upper: 999999.0
# DHPSm : 2ahhmp_m + 4abz_m --> dhpt_m + h2o_m
#  lower: 0.0, upper: 999999.0
# DHPTtm : dhpt_c <=> dhpt_m
#  lower: -999999.0, upper: 999999.0
# DHQS : 2dda7p_c --> 3dhq_c + pi_c
#  lower: 0.0, upper: 999999.0
# DHQTi : 3dhq_c --> 3dhsk_c + h2o_c
#  lower: 0.0, upper: 999999.0
# DIAT : accoa_c + sprm_c --> N1sprm_c + coa_c + h_c
#  lower: 0.0, upper: 999999.0
# DINSt2 : din_e + h_e --> din_c + h_c
#  lower: 0.0, upper: 999999.0
# DIPS : amet_c + caphis_c --> ahcys_c + cmaphis_c + h_c
#  lower: 0.0, upper: 999999.0
# DKMPPD2 : dkmpp_c + 3.0 h2o_c --> 2kmb_c + for_c + 6.0 h_c + pi_c
#  lower: 0.0, upper: 999999.0
# DMATT : dmpp_c + ipdp_c --> grdp_c + ppi_c
#  lower: 0.0, upper: 999999.0
# DNMPPA : dhpmp_c + h2o_c --> dhnpt_c + pi_c
#  lower: 0.0, upper: 999999.0
# DNTPPA : ahdt_c + h2o_c --> dhpmp_c + h_c + ppi_c
#  lower: 0.0, upper: 999999.0
# DOLK : ctp_c + dolichol_c --> cdp_c + dolp_c + h_c
#  lower: 0.0, upper: 999999.0
# DOLPMMer : dolmanp_r --> dolp_r + h_r + mannan_r
#  lower: 0.0, upper: 999999.0
# DOLPMTcer : dolp_c + gdpmann_c --> dolmanp_r + gdp_c
#  lower: 0.0, upper: 999999.0
# DOLPt2er : dolp_c + h_c <=> dolp_r + h_r
#  lower: -999999.0, upper: 999999.0
# DPCOAK : atp_c + dpcoa_c --> adp_c + coa_c + h_c
#  lower: 0.0, upper: 999999.0
# DPCOAKm : atp_m + dpcoa_m --> adp_m + coa_m + h_m
#  lower: 0.0, upper: 999999.0
# DPGM : 13dpg_c <=> 23dpg_c + h_c
#  lower: -999999.0, upper: 999999.0
# DPMVD : 5dpmev_c + atp_c --> adp_c + co2_c + ipdp_c + pi_c
#  lower: 0.0, upper: 999999.0
# DPR : 2dhp_c + h_c + nadph_c --> nadp_c + pant__R_c
#  lower: 0.0, upper: 999999.0
# DPRm : 2dhp_m + h_m + nadph_m --> nadp_m + pant__R_m
#  lower: 0.0, upper: 999999.0
# DRBK : atp_c + drib_c --> 2dr5p_c + adp_c + h_c
#  lower: 0.0, upper: 999999.0
# DROPPRy : 25dhpp_c + h_c + nadph_c --> 25dthpp_c + nadp_c
#  lower: 0.0, upper: 999999.0
# DRTPPD : 25dthpp_c + h2o_c + h_c --> 5aprbu_c + nh4_c
#  lower: 0.0, upper: 999999.0
# DTMPK : atp_c + dtmp_c <=> adp_c + dtdp_c
#  lower: -999999.0, upper: 999999.0
# DTTPt : dttp_e <=> dttp_c
#  lower: -999999.0, upper: 999999.0
# DUMPtn : dump_c <=> dump_n
#  lower: -999999.0, upper: 999999.0
# DURIK1 : atp_c + duri_c --> adp_c + dump_c + h_c
#  lower: 0.0, upper: 999999.0
# DURIPP : duri_c + pi_c <=> 2dr1p_c + ura_c
#  lower: -999999.0, upper: 999999.0
# DURIt2 : duri_e + h_e --> duri_c + h_c
#  lower: 0.0, upper: 999999.0
# DUTPDP : dutp_c + h2o_c --> dump_c + h_c + ppi_c
#  lower: 0.0, upper: 999999.0
# DXHPScm : h2o_c + q6_m + spmd_c --> 13dampp_c + 4abutn_c + q6h2_m
#  lower: 0.0, upper: 999999.0
# D_LACDcm : 2.0 ficytc_m + lac__D_c --> 2.0 focytc_m + pyr_c
#  lower: 0.0, upper: 999999.0
# D_LACDm : 2.0 ficytc_m + lac__D_m --> 2.0 focytc_m + pyr_m
#  lower: 0.0, upper: 999999.0
# D_LACt2 : h_e + lac__D_e <=> h_c + lac__D_c
#  lower: -999999.0, upper: 999999.0
# D_LACt2m : lac__D_c + pyr_m <=> lac__D_m + pyr_c
#  lower: -999999.0, upper: 999999.0
# D_LACtm : h_c + lac__D_c <=> h_m + lac__D_m
#  lower: -999999.0, upper: 999999.0
# E4HGLUtm : e4hglu_c <=> e4hglu_m
#  lower: -999999.0, upper: 999999.0
# E4HGLUtp : e4hglu_c <=> e4hglu_x
#  lower: -999999.0, upper: 999999.0
# E4Ptm : e4p_c <=> e4p_m
#  lower: -999999.0, upper: 999999.0
# ECOAH11p : h2o_x + hxc2coa_x <=> 3hxccoa_x
#  lower: -999999.0, upper: 999999.0
# ECOAH4p : 3hdcoa_x <=> dc2coa_x + h2o_x
#  lower: -999999.0, upper: 999999.0
# ECOAH5p : 3hddcoa_x <=> dd2coa_x + h2o_x
#  lower: -999999.0, upper: 999999.0
# ECOAH6p : 3htdcoa_x <=> h2o_x + td2coa_x
#  lower: -999999.0, upper: 999999.0
# ECOAH7p : 3hhdcoa_x <=> h2o_x + hdd2coa_x
#  lower: -999999.0, upper: 999999.0
# ECOAH8p : 3hodcoa_x <=> h2o_x + od2coa_x
#  lower: -999999.0, upper: 999999.0
# EHGLAT : akg_c + e4hglu_c --> 4h2oglt_c + glu__L_c
#  lower: 0.0, upper: 999999.0
# EHGLATm : akg_m + e4hglu_m --> 4h2oglt_m + glu__L_m
#  lower: 0.0, upper: 999999.0
# EHGLATp : akg_x + e4hglu_x --> 4h2oglt_x + glu__L_x
#  lower: 0.0, upper: 999999.0
# ENO : 2pg_c <=> h2o_c + pep_c
#  lower: -999999.0, upper: 999999.0
# EPGALURSe : h2o_e + pectin_e --> galur_e
#  lower: 0.0, upper: 999999.0
# EPISTAT_SC : 0.01 epist_c + 0.655 hdcoa_c + 0.01 hexccoa_c + 0.27 odecoa_c + 0.02 pmtcoa_c + 0.03 stcoa_c + 0.015 tdcoa_c --> coa_c + 0.01 epistest_SC_c
#  lower: 0.0, upper: 999999.0
# EPISTESTH_SC : 0.01 epistest_SC_c + h2o_c --> 0.01 epist_c + h_c + 0.02 hdca_c + 0.655 hdcea_c + 0.01 hexc_c + 0.03 ocdca_c + 0.27 ocdcea_c + 0.015 ttdca_c
#  lower: 0.0, upper: 999999.0
# EPISTESTH_SCe : 0.01 epistest_SC_e + h2o_e --> 0.01 epist_e + h_e + 0.02 hdca_e + 0.655 hdcea_e + 0.01 hexc_e + 0.03 ocdca_e + 0.27 ocdcea_e + 0.015 ttdca_e
#  lower: 0.0, upper: 999999.0
# EPISTt : epist_e <=> epist_c
#  lower: -999999.0, upper: 999999.0
# EPMGH : epm_c + h2o_c <=> gal_c + man_c
#  lower: -999999.0, upper: 999999.0
# ERGSTAT_SC : 0.01 ergst_c + 0.655 hdcoa_c + 0.01 hexccoa_c + 0.27 odecoa_c + 0.02 pmtcoa_c + 0.03 stcoa_c + 0.015 tdcoa_c --> coa_c + 0.01 ergstest_SC_c
#  lower: 0.0, upper: 999999.0
# ERGSTESTH_SC : 0.01 ergstest_SC_c + h2o_c --> 0.01 ergst_c + h_c + 0.02 hdca_c + 0.655 hdcea_c + 0.01 hexc_c + 0.03 ocdca_c + 0.27 ocdcea_c + 0.015 ttdca_c
#  lower: 0.0, upper: 999999.0
# ERGSTESTH_SCe : 0.01 ergstest_SC_e + h2o_e --> 0.01 ergst_e + h_e + 0.02 hdca_e + 0.655 hdcea_e + 0.01 hexc_e + 0.03 ocdca_e + 0.27 ocdcea_e + 0.015 ttdca_e
#  lower: 0.0, upper: 999999.0
# ERGSTGLCT : ergst_c + udpg_c --> ergst3glc_c + h_c + udp_c
#  lower: 0.0, upper: 999999.0
# ERGSTt : ergst_e <=> ergst_c
#  lower: -999999.0, upper: 999999.0
# ERGSTter : ergst_r <=> ergst_c
#  lower: -999999.0, upper: 999999.0
# ERGTETROLter : ergtetrol_c <=> ergtetrol_r
#  lower: -999999.0, upper: 999999.0
# ETHAK : atp_c + etha_c --> adp_c + ethamp_c + h_c
#  lower: 0.0, upper: 999999.0
# ETHAPT_SC : 0.01 12dgr_SC_c + cdpea_c <=> cmp_c + h_c + 0.01 pe_SC_c
#  lower: -999999.0, upper: 999999.0
# ETHAt : etha_e <=> etha_c
#  lower: -999999.0, upper: 999999.0
# ETOHt : etoh_e <=> etoh_c
#  lower: -999999.0, upper: 999999.0
# ETOHtm : etoh_c <=> etoh_m
#  lower: -999999.0, upper: 999999.0
# EX_13BDglcn_e : 13BDglcn_e -->
#  lower: 0.0, upper: 999999.0
# EX_2hb_e : 2hb_e -->
#  lower: 0.0, upper: 999999.0
# EX_2mbac_e : 2mbac_e -->
#  lower: 0.0, upper: 999999.0
# EX_2mbald_e : 2mbald_e -->
#  lower: 0.0, upper: 999999.0
# EX_2mbtoh_e : 2mbtoh_e -->
#  lower: 0.0, upper: 999999.0
# EX_2mppal_e : 2mppal_e -->
#  lower: 0.0, upper: 999999.0
# EX_2phetoh_e : 2phetoh_e -->
#  lower: 0.0, upper: 999999.0
# EX_3c3hmp_e : 3c3hmp_e -->
#  lower: 0.0, upper: 999999.0
# EX_3mbald_e : 3mbald_e -->
#  lower: 0.0, upper: 999999.0
# EX_3mop_e : 3mop_e -->
#  lower: 0.0, upper: 999999.0
# EX_4abut_e : 4abut_e -->
#  lower: 0.0, upper: 999999.0
# EX_4abz_e : 4abz_e -->
#  lower: 0.0, upper: 999999.0
# EX_5aop_e : 5aop_e -->
#  lower: 0.0, upper: 999999.0
# EX_8aonn_e : 8aonn_e -->
#  lower: 0.0, upper: 999999.0
# EX_Nbfortyr_e : Nbfortyr_e -->
#  lower: 0.0, upper: 999999.0
# EX_abt_e : abt_e -->
#  lower: 0.0, upper: 999999.0
# EX_ac_e : ac_e -->
#  lower: 0.0, upper: 999999.0
# EX_acald_e : acald_e -->
#  lower: 0.0, upper: 999999.0
# EX_aces_e : aces_e -->
#  lower: 0.0, upper: 999999.0
# EX_ade_e : ade_e -->
#  lower: 0.0, upper: 999999.0
# EX_adn_e : adn_e -->
#  lower: 0.0, upper: 999999.0
# EX_akg_e : akg_e -->
#  lower: 0.0, upper: 999999.0
# EX_ala__L_e : ala__L_e -->
#  lower: 0.0, upper: 999999.0
# EX_alltn_e : alltn_e -->
#  lower: 0.0, upper: 999999.0
# EX_alltt_e : alltt_e -->
#  lower: 0.0, upper: 999999.0
# EX_amet_e : amet_e -->
#  lower: 0.0, upper: 999999.0
# EX_arab__D_e : arab__D_e -->
#  lower: 0.0, upper: 999999.0
# EX_arab__L_e : arab__L_e -->
#  lower: 0.0, upper: 999999.0
# EX_arg__L_e : arg__L_e -->
#  lower: 0.0, upper: 999999.0
# EX_asn__L_e : asn__L_e -->
#  lower: 0.0, upper: 999999.0
# EX_asp__L_e : asp__L_e -->
#  lower: 0.0, upper: 999999.0
# EX_btd_RR_e : btd_RR_e -->
#  lower: 0.0, upper: 999999.0
# EX_btn_e : btn_e -->
#  lower: 0.0, upper: 999999.0
# EX_chol_e : chol_e -->
#  lower: 0.0, upper: 999999.0
# EX_cit_e : cit_e -->
#  lower: 0.0, upper: 999999.0
# EX_co2_e : co2_e -->
#  lower: 0.0, upper: 999999.0
# EX_crn_e : crn_e -->
#  lower: 0.0, upper: 999999.0
# EX_csn_e : csn_e -->
#  lower: 0.0, upper: 999999.0
# EX_cys__L_e : cys__L_e -->
#  lower: 0.0, upper: 999999.0
# EX_cytd_e : cytd_e -->
#  lower: 0.0, upper: 999999.0
# EX_dad_2_e : dad_2_e -->
#  lower: 0.0, upper: 999999.0
# EX_dann_e : dann_e -->
#  lower: 0.0, upper: 999999.0
# EX_dca_e : dca_e -->
#  lower: 0.0, upper: 999999.0
# EX_dcyt_e : dcyt_e -->
#  lower: 0.0, upper: 999999.0
# EX_ddca_e : ddca_e -->
#  lower: 0.0, upper: 999999.0
# EX_dgsn_e : dgsn_e -->
#  lower: 0.0, upper: 999999.0
# EX_din_e : din_e -->
#  lower: 0.0, upper: 999999.0
# EX_dttp_e : dttp_e -->
#  lower: 0.0, upper: 999999.0
# EX_duri_e : duri_e -->
#  lower: 0.0, upper: 999999.0
# EX_epist_e : epist_e -->
#  lower: 0.0, upper: 999999.0
# EX_epistest_SC_e : epistest_SC_e -->
#  lower: 0.0, upper: 999999.0
# EX_ergst_e : ergst_e -->
#  lower: 0.0, upper: 999999.0
# EX_ergstest_SC_e : ergstest_SC_e -->
#  lower: 0.0, upper: 999999.0
# EX_etha_e : etha_e -->
#  lower: 0.0, upper: 999999.0
# EX_etoh_e : etoh_e -->
#  lower: 0.0, upper: 999999.0
# EX_fe2_e : fe2_e <=>
#  lower: -999999.0, upper: 999999.0
# EX_fecost_e : fecost_e -->
#  lower: 0.0, upper: 999999.0
# EX_fecostest_SC_e : fecostest_SC_e -->
#  lower: 0.0, upper: 999999.0
# EX_fmn_e : fmn_e -->
#  lower: 0.0, upper: 999999.0
# EX_for_e : for_e -->
#  lower: 0.0, upper: 999999.0
# EX_fru_e : fru_e -->
#  lower: 0.0, upper: 999999.0
# EX_fum_e : fum_e -->
#  lower: 0.0, upper: 999999.0
# EX_g3pc_e : g3pc_e -->
#  lower: 0.0, upper: 999999.0
# EX_g3pi_e : g3pi_e -->
#  lower: 0.0, upper: 999999.0
# EX_gal_e : gal_e -->
#  lower: 0.0, upper: 999999.0
# EX_galur_e : galur_e -->
#  lower: 0.0, upper: 999999.0
# EX_gam6p_e : gam6p_e -->
#  lower: 0.0, upper: 999999.0
# EX_gcald_e : gcald_e -->
#  lower: 0.0, upper: 999999.0
# EX_glc__D_e : glc__D_e <=>
#  lower: -10.0, upper: 999999.0
# EX_gln__L_e : gln__L_e -->
#  lower: 0.0, upper: 999999.0
# EX_glu__L_e : glu__L_e -->
#  lower: 0.0, upper: 999999.0
# EX_glx_e : glx_e -->
#  lower: 0.0, upper: 999999.0
# EX_gly_e : gly_e -->
#  lower: 0.0, upper: 999999.0
# EX_glyc_e : glyc_e -->
#  lower: 0.0, upper: 999999.0
# EX_gsn_e : gsn_e -->
#  lower: 0.0, upper: 999999.0
# EX_gthox_e : gthox_e -->
#  lower: 0.0, upper: 999999.0
# EX_gthrd_e : gthrd_e -->
#  lower: 0.0, upper: 999999.0
# EX_gua_e : gua_e -->
#  lower: 0.0, upper: 999999.0
# EX_h2o_e : h2o_e <=>
#  lower: -999999.0, upper: 999999.0
# EX_h_e : h_e <=>
#  lower: -999999.0, upper: 999999.0
# EX_hdca_e : hdca_e -->
#  lower: 0.0, upper: 999999.0
# EX_hdcea_e : hdcea_e -->
#  lower: 0.0, upper: 999999.0
# EX_hexc_e : hexc_e -->
#  lower: 0.0, upper: 999999.0
# EX_his__L_e : his__L_e -->
#  lower: 0.0, upper: 999999.0
# EX_hxan_e : hxan_e -->
#  lower: 0.0, upper: 999999.0
# EX_iamac_e : iamac_e -->
#  lower: 0.0, upper: 999999.0
# EX_iamoh_e : iamoh_e -->
#  lower: 0.0, upper: 999999.0
# EX_ibutac_e : ibutac_e -->
#  lower: 0.0, upper: 999999.0
# EX_ibutoh_e : ibutoh_e -->
#  lower: 0.0, upper: 999999.0
# EX_id3acald_e : id3acald_e -->
#  lower: 0.0, upper: 999999.0
# EX_ile__L_e : ile__L_e -->
#  lower: 0.0, upper: 999999.0
# EX_ind3eth_e : ind3eth_e -->
#  lower: 0.0, upper: 999999.0
# EX_inost_e : inost_e -->
#  lower: 0.0, upper: 999999.0
# EX_ins_e : ins_e -->
#  lower: 0.0, upper: 999999.0
# EX_k_e : k_e <=>
#  lower: -999999.0, upper: 999999.0
# EX_lac__D_e : lac__D_e -->
#  lower: 0.0, upper: 999999.0
# EX_lac__L_e : lac__L_e -->
#  lower: 0.0, upper: 999999.0
# EX_lanost_e : lanost_e -->
#  lower: 0.0, upper: 999999.0
# EX_lanostest_SC_e : lanostest_SC_e -->
#  lower: 0.0, upper: 999999.0
# EX_leu__L_e : leu__L_e -->
#  lower: 0.0, upper: 999999.0
# EX_lys__L_e : lys__L_e -->
#  lower: 0.0, upper: 999999.0
# EX_mal__L_e : mal__L_e -->
#  lower: 0.0, upper: 999999.0
# EX_malt_e : malt_e -->
#  lower: 0.0, upper: 999999.0
# EX_man_e : man_e -->
#  lower: 0.0, upper: 999999.0
# EX_melib_e : melib_e -->
#  lower: 0.0, upper: 999999.0
# EX_met__L_e : met__L_e -->
#  lower: 0.0, upper: 999999.0
# EX_mmet_e : mmet_e -->
#  lower: 0.0, upper: 999999.0
# EX_na1_e : na1_e <=>
#  lower: -999999.0, upper: 999999.0
# EX_nac_e : nac_e -->
#  lower: 0.0, upper: 999999.0
# EX_nadp_e : nadp_e -->
#  lower: 0.0, upper: 999999.0
# EX_nh4_e : nh4_e <=>
#  lower: -999999.0, upper: 999999.0
# EX_nmn_e : nmn_e -->
#  lower: 0.0, upper: 999999.0
# EX_o2_e : o2_e <=>
#  lower: -2.0, upper: 999999.0
# EX_oaa_e : oaa_e -->
#  lower: 0.0, upper: 999999.0
# EX_ocdca_e : ocdca_e -->
#  lower: 0.0, upper: 999999.0
# EX_ocdcea_e : ocdcea_e -->
#  lower: 0.0, upper: 999999.0
# EX_ocdcya_e : ocdcya_e -->
#  lower: 0.0, upper: 999999.0
# EX_orn_e : orn_e -->
#  lower: 0.0, upper: 999999.0
# EX_pacald_e : pacald_e -->
#  lower: 0.0, upper: 999999.0
# EX_pap_e : pap_e -->
#  lower: 0.0, upper: 999999.0
# EX_pc_SC_e : pc_SC_e -->
#  lower: 0.0, upper: 999999.0
# EX_pectin_e : pectin_e -->
#  lower: 0.0, upper: 999999.0
# EX_pepd_e : pepd_e -->
#  lower: 0.0, upper: 999999.0
# EX_phe__L_e : phe__L_e -->
#  lower: 0.0, upper: 999999.0
# EX_pheac_e : pheac_e -->
#  lower: 0.0, upper: 999999.0
# EX_pi_e : pi_e <=>
#  lower: -999999.0, upper: 999999.0
# EX_pnto__R_e : pnto__R_e -->
#  lower: 0.0, upper: 999999.0
# EX_pro__L_e : pro__L_e -->
#  lower: 0.0, upper: 999999.0
# EX_ptd1ino_SC_e : ptd1ino_SC_e -->
#  lower: 0.0, upper: 999999.0
# EX_ptrc_e : ptrc_e -->
#  lower: 0.0, upper: 999999.0
# EX_pyr_e : pyr_e -->
#  lower: 0.0, upper: 999999.0
# EX_rib__D_e : rib__D_e -->
#  lower: 0.0, upper: 999999.0
# EX_ribflv_e : ribflv_e -->
#  lower: 0.0, upper: 999999.0
# EX_sbt__D_e : sbt__D_e -->
#  lower: 0.0, upper: 999999.0
# EX_sbt__L_e : sbt__L_e -->
#  lower: 0.0, upper: 999999.0
# EX_ser__L_e : ser__L_e -->
#  lower: 0.0, upper: 999999.0
# EX_so3_e : so3_e -->
#  lower: 0.0, upper: 999999.0
# EX_so4_e : so4_e <=>
#  lower: -999999.0, upper: 999999.0
# EX_spmd_e : spmd_e -->
#  lower: 0.0, upper: 999999.0
# EX_sprm_e : sprm_e -->
#  lower: 0.0, upper: 999999.0
# EX_srb__L_e : srb__L_e -->
#  lower: 0.0, upper: 999999.0
# EX_succ_e : succ_e -->
#  lower: 0.0, upper: 999999.0
# EX_sucr_e : sucr_e -->
#  lower: 0.0, upper: 999999.0
# EX_taur_e : taur_e -->
#  lower: 0.0, upper: 999999.0
# EX_thm_e : thm_e -->
#  lower: 0.0, upper: 999999.0
# EX_thmmp_e : thmmp_e -->
#  lower: 0.0, upper: 999999.0
# EX_thmpp_e : thmpp_e -->
#  lower: 0.0, upper: 999999.0
# EX_thr__L_e : thr__L_e -->
#  lower: 0.0, upper: 999999.0
# EX_thym_e : thym_e -->
#  lower: 0.0, upper: 999999.0
# EX_thymd_e : thymd_e -->
#  lower: 0.0, upper: 999999.0
# EX_tre_e : tre_e -->
#  lower: 0.0, upper: 999999.0
# EX_trp__L_e : trp__L_e -->
#  lower: 0.0, upper: 999999.0
# EX_ttdca_e : ttdca_e -->
#  lower: 0.0, upper: 999999.0
# EX_tyr__L_e : tyr__L_e -->
#  lower: 0.0, upper: 999999.0
# EX_ura_e : ura_e -->
#  lower: 0.0, upper: 999999.0
# EX_urea_e : urea_e -->
#  lower: 0.0, upper: 999999.0
# EX_uri_e : uri_e -->
#  lower: 0.0, upper: 999999.0
# EX_val__L_e : val__L_e -->
#  lower: 0.0, upper: 999999.0
# EX_xan_e : xan_e -->
#  lower: 0.0, upper: 999999.0
# EX_xtsn_e : xtsn_e -->
# ...
#  lower: 0.0, upper: 999999.0
# RNDR4 : trdrd_c + udp_c --> dudp_c + h2o_c + trdox_c
#  lower: 0.0, upper: 999999.0
# RNDR4n : trdrd_n + udp_n --> dudp_n + h2o_n + trdox_n
#  lower: 0.0, upper: 999999.0
# RNMK : atp_c + rnam_c --> adp_c + h_c + nmn_c
#  lower: 0.0, upper: 999999.0
# RNTR1 : atp_c + trdrd_c --> datp_c + h2o_c + trdox_c
#  lower: 0.0, upper: 999999.0
# RNTR2 : gtp_c + trdrd_c --> dgtp_c + h2o_c + trdox_c
#  lower: 0.0, upper: 999999.0
# RNTR3 : ctp_c + trdrd_c --> dctp_c + h2o_c + trdox_c
#  lower: 0.0, upper: 999999.0
# RNTR4 : trdrd_c + utp_c --> dutp_c + h2o_c + trdox_c
#  lower: 0.0, upper: 999999.0
# RPE : ru5p__D_c <=> xu5p__D_c
#  lower: -999999.0, upper: 999999.0
# RPI : r5p_c <=> ru5p__D_c
#  lower: -999999.0, upper: 999999.0
# SACCD1 : L2aadp6sa_c + glu__L_c + h_c + nadph_c <=> h2o_c + nadp_c + saccrp__L_c
#  lower: -999999.0, upper: 999999.0
# SACCD2 : h2o_c + nad_c + saccrp__L_c <=> akg_c + h_c + lys__L_c + nadh_c
#  lower: -999999.0, upper: 999999.0
# SADT : atp_c + h_c + so4_c --> aps_c + ppi_c
#  lower: 0.0, upper: 999999.0
# SAM24MT : amet_c + zymst_c --> ahcys_c + fecost_c + h_c
#  lower: 0.0, upper: 999999.0
# SBPP1er : h2o_r + sph1p_r --> pi_r + sphgn_r
#  lower: 0.0, upper: 999999.0
# SBPP2er : h2o_r + psph1p_r --> pi_r + psphings_r
#  lower: 0.0, upper: 999999.0
# SBTD_D2 : nad_c + sbt__D_c --> fru_c + h_c + nadh_c
#  lower: 0.0, upper: 999999.0
# SBTD_L : nad_c + sbt__L_c --> h_c + nadh_c + srb__L_c
#  lower: 0.0, upper: 999999.0
# SBTR : glc__D_c + h_c + nadph_c --> nadp_c + sbt__D_c
#  lower: 0.0, upper: 999999.0
# SBT_Dt : sbt__D_e <=> sbt__D_c
#  lower: -999999.0, upper: 999999.0
# SBT_Lt : sbt__L_e <=> sbt__L_c
#  lower: -999999.0, upper: 999999.0
# SERAT : accoa_c + ser__L_c --> acser_c + coa_c
#  lower: 0.0, upper: 999999.0
# SERD_L : ser__L_c --> nh4_c + pyr_c
#  lower: 0.0, upper: 999999.0
# SERPT : h_c + pmtcoa_c + ser__L_c --> 3dsphgn_c + co2_c + coa_c
#  lower: 0.0, upper: 999999.0
# SERTRS : atp_c + ser__L_c + trnaser_c --> amp_c + ppi_c + sertrna_c
#  lower: 0.0, upper: 999999.0
# SERt2m : h_c + ser__L_c <=> h_m + ser__L_m
#  lower: -999999.0, upper: 999999.0
# SERt2r : h_e + ser__L_e <=> h_c + ser__L_c
#  lower: -999999.0, upper: 999999.0
# SFGTHi : Sfglutth_c + h2o_c <=> for_c + gthrd_c + h_c
#  lower: -999999.0, upper: 999999.0
# SHCHD : dscl_c + nadp_c --> h_c + nadph_c + scl_c
#  lower: 0.0, upper: 999999.0
# SHCHF : fe2_c + scl_c --> 3.0 h_c + sheme_c
#  lower: 0.0, upper: 999999.0
# SHK3Dr : 3dhsk_c + h_c + nadph_c --> nadp_c + skm_c
#  lower: 0.0, upper: 999999.0
# SHKK : atp_c + skm_c --> adp_c + h_c + skm5p_c
#  lower: 0.0, upper: 999999.0
# SHSL1 : cys__L_c + suchms_c --> cyst__L_c + h_c + succ_c
#  lower: 0.0, upper: 999999.0
# SHSL4r : h2o_c + suchms_c <=> 2obut_c + h_c + nh4_c + succ_c
#  lower: -999999.0, upper: 999999.0
# SLCBK1 : atp_c + sphgn_c --> adp_c + h_c + sph1p_c
#  lower: 0.0, upper: 999999.0
# SLCBK2 : atp_c + psphings_c --> adp_c + h_c + psph1p_c
#  lower: 0.0, upper: 999999.0
# SLFAT : adp_c + h_c + so4_c <=> aps_c + pi_c
#  lower: -999999.0, upper: 999999.0
# SO3ti : so3_c --> so3_e
#  lower: 0.0, upper: 999999.0
# SO4ti : so4_e --> so4_c
#  lower: 0.0, upper: 999999.0
# SPH1Pter : sph1p_c --> sph1p_r
#  lower: 0.0, upper: 999999.0
# SPHPL : sph1p_c --> ethamp_c + hxdcal_c
#  lower: 0.0, upper: 999999.0
# SPMDAT1 : accoa_c + spmd_c --> N1aspmd_c + coa_c + h_c
#  lower: 0.0, upper: 999999.0
# SPMDt3i : h_c + spmd_e --> h_e + spmd_c
#  lower: 0.0, upper: 999999.0
# SPMDtex2 : spmd_c --> spmd_e
#  lower: 0.0, upper: 999999.0
# SPMS : ametam_c + ptrc_c --> 5mta_c + h_c + spmd_c
#  lower: 0.0, upper: 999999.0
# SPRMS : ametam_c + spmd_c --> 5mta_c + h_c + sprm_c
#  lower: 0.0, upper: 999999.0
# SPRMt2i : h_c + sprm_e --> h_e + sprm_c
#  lower: 0.0, upper: 999999.0
# SQ23EPXter : Ssq23epx_r <=> Ssq23epx_c
#  lower: -999999.0, upper: 999999.0
# SQLEr : h_r + nadph_r + o2_r + sql_r --> Ssq23epx_r + h2o_r + nadp_r
#  lower: 0.0, upper: 999999.0
# SQLErx : h_r + nadh_r + o2_r + sql_r --> Ssq23epx_r + h2o_r + nad_r
#  lower: 0.0, upper: 999999.0
# SQLS : 2.0 frdp_c + h_c + nadph_c --> nadp_c + 2.0 ppi_c + sql_c
#  lower: 0.0, upper: 999999.0
# SQLter : sql_c <=> sql_r
#  lower: -999999.0, upper: 999999.0
# SRB_Lt : srb__L_e <=> srb__L_c
#  lower: -999999.0, upper: 999999.0
# SSALy : h2o_c + nadp_c + sucsal_c --> 2.0 h_c + nadph_c + succ_c
#  lower: 0.0, upper: 999999.0
# SUCCt2r : h_e + succ_e <=> h_c + succ_c
#  lower: -999999.0, upper: 999999.0
# SUCCtm : pi_m + succ_c --> pi_c + succ_m
#  lower: 0.0, upper: 999999.0
# SUCD1m : fad_m + succ_m <=> fadh2_m + fum_m
#  lower: -999999.0, upper: 999999.0
# SUCD2_u6m : q6_m + succ_m <=> fum_m + q6h2_m
#  lower: -999999.0, upper: 999999.0
# SUCD3_u6m : fadh2_m + q6_m <=> fad_m + q6h2_m
#  lower: -999999.0, upper: 999999.0
# SUCFUMtm : fum_m + succ_c --> fum_c + succ_m
#  lower: 0.0, upper: 999999.0
# SUCOASm : atp_m + coa_m + succ_m <=> adp_m + pi_m + succoa_m
#  lower: -999999.0, upper: 999999.0
# SUCRe : h2o_e + sucr_e --> fru_e + glc__D_e
#  lower: 0.0, upper: 999999.0
# SUCRt2 : h_e + sucr_e --> h_c + sucr_c
#  lower: 0.0, upper: 999999.0
# SULR : 5.0 h_c + 3.0 nadph_c + so3_c <=> 3.0 h2o_c + h2s_c + 3.0 nadp_c
#  lower: -999999.0, upper: 999999.0
# T4HCINNMFM : 34hpl_m --> T4hcinnm_m + h2o_m
#  lower: 0.0, upper: 999999.0
# TAGL_SC : h2o_c + 0.01 triglyc_SC_c --> 0.01 12dgr_SC_c + 0.02 dca_c + 0.06 ddca_c + h_c + 0.27 hdca_c + 0.17 hdcea_c + 0.05 ocdca_c + 0.24 ocdcea_c + 0.09 ocdcya_c + 0.1 ttdca_c
#  lower: 0.0, upper: 999999.0
# TALA : g3p_c + s7p_c <=> e4p_c + f6p_c
#  lower: -999999.0, upper: 999999.0
# TAUDO : akg_c + o2_c + taur_c --> aacald_c + co2_c + h_c + so3_c + succ_c
#  lower: 0.0, upper: 999999.0
# TAURt : taur_c <=> taur_e
#  lower: -999999.0, upper: 999999.0
# TCHOLAabcv : atp_v + h2o_v + tchola_c --> adp_v + h_v + pi_v + tchola_v
#  lower: 0.0, upper: 999999.0
# THFATm : h2o_m + methf_m --> 5fthf_m + h_m
#  lower: 0.0, upper: 999999.0
# THFGLUS : atp_c + glu__L_c + thf_c <=> adp_c + h_c + pi_c + thfglu_c
#  lower: -999999.0, upper: 999999.0
# THIORDXi : h2o2_c + trdrd_c --> 2.0 h2o_c + trdox_c
#  lower: 0.0, upper: 999999.0
# THIORDXm : h2o2_m + trdrd_m <=> 2.0 h2o_m + trdox_m
#  lower: -999999.0, upper: 999999.0
# THIORDXni : h2o2_n + trdrd_n --> 2.0 h2o_n + trdox_n
#  lower: 0.0, upper: 999999.0
# THIORDXp : h2o2_x + trdrd_x <=> 2.0 h2o_x + trdox_x
#  lower: -999999.0, upper: 999999.0
# THMDPe : 2.0 h2o_e + thmpp_e --> h_e + 2.0 pi_e + thm_e
#  lower: 0.0, upper: 999999.0
# THMDt2 : h_e + thymd_e --> h_c + thymd_c
#  lower: 0.0, upper: 999999.0
# THMP : h2o_c + thmmp_c --> pi_c + thm_c
#  lower: 0.0, upper: 999999.0
# THMPPt2m : thmpp_c --> thmpp_m
#  lower: 0.0, upper: 999999.0
# THMPe : h2o_e + thmmp_e --> pi_e + thm_e
#  lower: 0.0, upper: 999999.0
# THMt2 : h_e + thm_e --> h_c + thm_c
#  lower: 0.0, upper: 999999.0
# THRA2 : athr__L_c --> acald_c + gly_c
#  lower: 0.0, upper: 999999.0
# THRA : thr__L_c --> acald_c + gly_c
#  lower: 0.0, upper: 999999.0
# THRD_L : thr__L_c --> 2obut_c + nh4_c
#  lower: 0.0, upper: 999999.0
# THRD_Lm : thr__L_m --> 2obut_m + nh4_m
#  lower: 0.0, upper: 999999.0
# THRS : h2o_c + phom_c --> pi_c + thr__L_c
#  lower: 0.0, upper: 999999.0
# THRTRS : atp_c + thr__L_c + trnathr_c --> amp_c + ppi_c + thrtrna_c
#  lower: 0.0, upper: 999999.0
# THRTRSm : atp_m + thr__L_m + trnathr_m --> amp_m + ppi_m + thrtrna_m
#  lower: 0.0, upper: 999999.0
# THRt2m : h_c + thr__L_c <=> h_m + thr__L_m
#  lower: -999999.0, upper: 999999.0
# THRt2r : h_e + thr__L_e <=> h_c + thr__L_c
#  lower: -999999.0, upper: 999999.0
# THYMt3r : h_e + thym_c <=> h_c + thym_e
#  lower: -999999.0, upper: 999999.0
# THZPSN1_SC : achms_c + cys__L_c + gly_c + h_c + xu5p__D_c --> 4abut_c + 4mpetz_c + ac_c + co2_c + 3.0 h2o_c + nh4_c + pyr_c
#  lower: 0.0, upper: 999999.0
# THZPSN2_SC : achms_c + cys__L_c + gly_c + h_c + r5p_c --> 4abut_c + 4mpetz_c + ac_c + co2_c + 3.0 h2o_c + nh4_c + pyr_c
#  lower: 0.0, upper: 999999.0
# TKT1 : r5p_c + xu5p__D_c <=> g3p_c + s7p_c
#  lower: -999999.0, upper: 999999.0
# TKT2 : e4p_c + xu5p__D_c <=> f6p_c + g3p_c
#  lower: -999999.0, upper: 999999.0
# TMDK1 : atp_c + thymd_c --> adp_c + dtmp_c + h_c
#  lower: 0.0, upper: 999999.0
# TMDPK : atp_c + thm_c --> amp_c + h_c + thmpp_c
#  lower: 0.0, upper: 999999.0
# TMDPP : pi_c + thymd_c <=> 2dr1p_c + thym_c
#  lower: -999999.0, upper: 999999.0
# TMDPPK : atp_c + thmpp_c --> adp_c + thmtp_c
#  lower: 0.0, upper: 999999.0
# TMDS : dump_c + mlthf_c --> dhf_c + dtmp_c
#  lower: 0.0, upper: 999999.0
# TMN : h2o_c + thm_c --> 4ahmmp_c + 4mhetz_c + h_c
#  lower: 0.0, upper: 999999.0
# TMPK : atp_c + thmmp_c <=> adp_c + thmpp_c
#  lower: -999999.0, upper: 999999.0
# TMPPP : 2mahmp_c + 4mpetz_c + h_c --> ppi_c + thmmp_c
#  lower: 0.0, upper: 999999.0
# TPI : dhap_c <=> g3p_c
#  lower: -999999.0, upper: 999999.0
# TRDOXtp : trdox_c <=> trdox_x
#  lower: -999999.0, upper: 999999.0
# TRDR : h_c + nadph_c + trdox_c --> nadp_c + trdrd_c
#  lower: 0.0, upper: 999999.0
# TRDRDtp : trdrd_c <=> trdrd_x
#  lower: -999999.0, upper: 999999.0
# TRDRm : h_m + nadph_m + trdox_m --> nadp_m + trdrd_m
#  lower: 0.0, upper: 999999.0
# TRE6PP : h2o_c + tre6p_c --> pi_c + tre_c
#  lower: 0.0, upper: 999999.0
# TRE6PS : g6p_c + udpg_c --> h_c + tre6p_c + udp_c
#  lower: 0.0, upper: 999999.0
# TREH : h2o_c + tre_c --> 2.0 glc__D_c
#  lower: 0.0, upper: 999999.0
# TREHv : h2o_v + tre_v --> 2.0 glc__D_v
#  lower: 0.0, upper: 999999.0
# TREt2 : h_e + tre_e --> h_c + tre_c
#  lower: 0.0, upper: 999999.0
# TREt2v : h_c + tre_c <=> h_v + tre_v
#  lower: -999999.0, upper: 999999.0
# TRIGS_SC : 0.01 12dgr_SC_c + 0.02 dcacoa_c + 0.06 ddcacoa_c + 0.17 hdcoa_c + 0.09 ocdycacoa_c + 0.24 odecoa_c + 0.27 pmtcoa_c + 0.05 stcoa_c + 0.1 tdcoa_c --> coa_c + 0.01 triglyc_SC_c
#  lower: 0.0, upper: 999999.0
# TRPO2 : o2_c + trp__L_c --> Lfmkynr_c
#  lower: 0.0, upper: 999999.0
# TRPS1 : 3ig3p_c + ser__L_c --> g3p_c + h2o_c + trp__L_c
#  lower: 0.0, upper: 999999.0
# TRPTA : akg_c + trp__L_c <=> glu__L_c + indpyr_c
#  lower: -999999.0, upper: 999999.0
# TRPTRS : atp_c + trnatrp_c + trp__L_c --> amp_c + ppi_c + trptrna_c
#  lower: 0.0, upper: 999999.0
# TRPTRSm : atp_m + trnatrp_m + trp__L_m --> amp_m + ppi_m + trptrna_m
#  lower: 0.0, upper: 999999.0
# TRPt2m : h_c + trp__L_c <=> h_m + trp__L_m
#  lower: -999999.0, upper: 999999.0
# TRPt2r : h_e + trp__L_e <=> h_c + trp__L_c
#  lower: -999999.0, upper: 999999.0
# TTCCOAtx : ttccoa_c <=> ttccoa_x
#  lower: -999999.0, upper: 999999.0
# TTDCAtr : ttdca_e <=> ttdca_c
#  lower: -999999.0, upper: 999999.0
# TYRNFT : 10fthf_c + tyr__L_c --> Nfortyr_c + h_c + thf_c
#  lower: 0.0, upper: 999999.0
# TYRTAi : 34hpp_c + glu__L_c --> akg_c + tyr__L_c
#  lower: 0.0, upper: 999999.0
# TYRTAim : 34hpp_m + glu__L_m --> akg_m + tyr__L_m
#  lower: 0.0, upper: 999999.0
# TYRTAip : 34hpp_x + glu__L_x --> akg_x + tyr__L_x
#  lower: 0.0, upper: 999999.0
# TYRTRS : atp_c + trnatyr_c + tyr__L_c --> amp_c + ppi_c + tyrtrna_c
#  lower: 0.0, upper: 999999.0
# TYRTRSm : atp_m + trnatyr_m + tyr__L_m --> amp_m + ppi_m + tyrtrna_m
#  lower: 0.0, upper: 999999.0
# TYRt2m : h_c + tyr__L_c <=> h_m + tyr__L_m
#  lower: -999999.0, upper: 999999.0
# TYRt2p : h_c + tyr__L_c <=> h_x + tyr__L_x
#  lower: -999999.0, upper: 999999.0
# TYRt2r : h_e + tyr__L_e <=> h_c + tyr__L_c
#  lower: -999999.0, upper: 999999.0
# TYRt6 : h_v + tyr__L_c --> h_c + tyr__L_v
#  lower: 0.0, upper: 999999.0
# TYRt7 : h_v + tyr__L_v --> h_c + tyr__L_c
#  lower: 0.0, upper: 999999.0
# UDPACGLP : acgam1p_c + h_c + utp_c <=> ppi_c + udpacgal_c
#  lower: -999999.0, upper: 999999.0
# UDPG4E : udpg_c <=> udpgal_c
#  lower: -999999.0, upper: 999999.0
# UDPGALt2g : udpgal_c --> udpgal_g
#  lower: 0.0, upper: 999999.0
# UGLT : gal1p_c + udpg_c <=> g1p_c + udpgal_c
#  lower: -999999.0, upper: 999999.0
# UGLYCH : h2o_c + 2.0 h_c + urdglyc_c <=> co2_c + glx_c + 2.0 nh4_c
#  lower: -999999.0, upper: 999999.0
# UMPK : atp_c + ump_c <=> adp_c + udp_c
#  lower: -999999.0, upper: 999999.0
# UMPKn : atp_n + ump_n <=> adp_n + udp_n
#  lower: -999999.0, upper: 999999.0
# UMPtn : ump_c <=> ump_n
#  lower: -999999.0, upper: 999999.0
# UNK3 : 2kmb_c + glu__L_c --> akg_c + met__L_c
#  lower: 0.0, upper: 999999.0
# UPP3MT : 2.0 amet_c + uppg3_c --> 2.0 ahcys_c + dscl_c + h_c
#  lower: 0.0, upper: 999999.0
# UPP3S : hmbil_c --> h2o_c + uppg3_c
#  lower: 0.0, upper: 999999.0
# UPPDC1 : 4.0 h_c + uppg3_c --> 4.0 co2_c + cpppg3_c
#  lower: 0.0, upper: 999999.0
# UPPRT : prpp_c + ura_c --> ppi_c + ump_c
#  lower: 0.0, upper: 999999.0
# URAt2 : h_e + ura_e --> h_c + ura_c
#  lower: 0.0, upper: 999999.0
# UREA2t2 : 2.0 h_e + urea_e <=> 2.0 h_c + urea_c
#  lower: -999999.0, upper: 999999.0
# UREASE : atp_c + hco3_c + urea_c <=> adp_c + allphn_c + h_c + pi_c
#  lower: -999999.0, upper: 999999.0
# URIDK2r : atp_c + dump_c <=> adp_c + dudp_c
#  lower: -999999.0, upper: 999999.0
# URIDK2rn : atp_n + dump_n <=> adp_n + dudp_n
#  lower: -999999.0, upper: 999999.0
# URIK1 : atp_c + uri_c --> adp_c + h_c + ump_c
#  lower: 0.0, upper: 999999.0
# URIK2 : gtp_c + uri_c --> gdp_c + h_c + ump_c
#  lower: 0.0, upper: 999999.0
# URIt2 : h_e + uri_e --> h_c + uri_c
#  lower: 0.0, upper: 999999.0
# UTPH1 : 2.0 h2o_c + utp_c --> 2.0 h_c + 2.0 pi_c + ump_c
#  lower: 0.0, upper: 999999.0
# UTPtm : 2.0 h_c + ump_m + utp_c --> 2.0 h_m + ump_c + utp_m
#  lower: 0.0, upper: 999999.0
# VALTA : akg_c + val__L_c <=> 3mob_c + glu__L_c
#  lower: -999999.0, upper: 999999.0
# VALTAim : akg_m + val__L_m --> 3mob_m + glu__L_m
#  lower: 0.0, upper: 999999.0
# VALTRS : atp_c + trnaval_c + val__L_c --> amp_c + ppi_c + valtrna_c
#  lower: 0.0, upper: 999999.0
# VALTRSm : atp_m + trnaval_m + val__L_m --> amp_m + ppi_m + valtrna_m
#  lower: 0.0, upper: 999999.0
# VALt2m : h_c + val__L_c <=> h_m + val__L_m
#  lower: -999999.0, upper: 999999.0
# VALt2r : h_e + val__L_e <=> h_c + val__L_c
#  lower: -999999.0, upper: 999999.0
# XANt : xan_e <=> xan_c
#  lower: -999999.0, upper: 999999.0
# XPPT : prpp_c + xan_c --> ppi_c + xmp_c
#  lower: 0.0, upper: 999999.0
# XTSNt2 : h_e + xtsn_e --> h_c + xtsn_c
#  lower: 0.0, upper: 999999.0
# XYLK : atp_c + xylu__D_c --> adp_c + h_c + xu5p__D_c
#  lower: 0.0, upper: 999999.0
# XYLR : h_c + nadph_c + xyl__D_c --> nadp_c + xylt_c
#  lower: 0.0, upper: 999999.0
# XYLTD_D : nad_c + xylt_c --> h_c + nadh_c + xylu__D_c
#  lower: 0.0, upper: 999999.0
# XYLTt : xylt_e <=> xylt_c
#  lower: -999999.0, upper: 999999.0
# XYLt : xyl__D_e <=> xyl__D_c
#  lower: -999999.0, upper: 999999.0
# YUMPS : r5p_c + ura_c <=> h2o_c + psd5p_c
#  lower: -999999.0, upper: 999999.0
# ZYMSTAT_SC : 0.655 hdcoa_c + 0.01 hexccoa_c + 0.27 odecoa_c + 0.02 pmtcoa_c + 0.03 stcoa_c + 0.015 tdcoa_c + 0.01 zymst_c --> coa_c + 0.01 zymstest_SC_c
#  lower: 0.0, upper: 999999.0
# ZYMSTESTH_SC : h2o_c + 0.01 zymstest_SC_c --> h_c + 0.02 hdca_c + 0.655 hdcea_c + 0.01 hexc_c + 0.03 ocdca_c + 0.27 ocdcea_c + 0.015 ttdca_c + 0.01 zymst_c
#  lower: 0.0, upper: 999999.0
# ZYMSTESTH_SCe : h2o_e + 0.01 zymstest_SC_e --> h_e + 0.02 hdca_e + 0.655 hdcea_e + 0.01 hexc_e + 0.03 ocdca_e + 0.27 ocdcea_e + 0.015 ttdca_e + 0.01 zymst_e
#  lower: 0.0, upper: 999999.0
# ZYMSTt : zymst_e <=> zymst_c
#  lower: -999999.0, upper: 999999.0
# BIOMASS_SC5_notrace : 1.1348 13BDglcn_c + 0.4588 ala__L_c + 0.046 amp_c + 0.1607 arg__L_c + 0.1017 asn__L_c + 0.2975 asp__L_c + 59.276 atp_c + 0.0447 cmp_c + 0.0066 cys__L_c + 0.0036 damp_c + 0.0024 dcmp_c + 0.0024 dgmp_c + 0.0036 dtmp_c + 0.0007 ergst_c + 0.1054 gln__L_c + 0.3018 glu__L_c + 0.2904 gly_c + 0.5185 glycogen_c + 0.046 gmp_c + 59.276 h2o_c + 0.0663 his__L_c + 0.1927 ile__L_c + 0.2964 leu__L_c + 0.2862 lys__L_c + 0.8079 mannan_c + 0.0507 met__L_c + 6e-06 pa_SC_c + 6e-05 pc_SC_c + 4.5e-05 pe_SC_c + 0.1339 phe__L_c + 0.1647 pro__L_c + 1.7e-05 ps_SC_c + 5.3e-05 ptd1ino_SC_c + 0.00099 ribflv_c + 0.1854 ser__L_c + 0.02 so4_c + 0.1914 thr__L_c + 0.0234 tre_c + 6.6e-05 triglyc_SC_c + 0.0284 trp__L_c + 0.102 tyr__L_c + 0.0599 ump_c + 0.2646 val__L_c + 0.0015 zymst_c --> 59.276 adp_c + 58.70001 h_c + 59.305 pi_c
#  lower: 0.0, upper: 999999.0
# ACACT1b : 2.0 accoa_c <=> aacoa_c + coa_c
#  lower: -1000, upper: 1000
# AACOARb : aacoa_c + h_c + nadph_c <=> 3hbcoa_c + nadp_c
#  lower: -1000, upper: 1000
# HBCOAhydb : 3hbcoa_c <=> b2coa_c + h2o_c
#  lower: -1000, upper: 1000
# ACOAD1b : b2coa_c + h_c + nadh_c <=> btcoa_c + nad_c
#  lower: -1000, upper: 1000
# BCOAhydb : btcoa_c + h2o_c <=> but_c + coa_c + h_c
#  lower: -1000, upper: 1000

# %%
print("Genes")
print("-----")
for x in cerevisiae.genes:
    associated_ids = (i.id for i in x.reactions)
    print("%s is associated with reactions: %s" %
          (x.name, "{" + ", ".join(associated_ids) + "}"))
# Out:
# Genes
# -----
# BGL2 is associated with reactions: {13BGH}
# SPR1 is associated with reactions: {13BGHe}
# EXG1 is associated with reactions: {13BGHe}
# EXG2 is associated with reactions: {13BGHe}
# FKS3 is associated with reactions: {13GS}
# FKS1 is associated with reactions: {13GS}
# GAS3 is associated with reactions: {13GS}
# GAS1 is associated with reactions: {13GS}
# ELO2 is associated with reactions: {13GS, FAS260, FAS240_L}
# GAS4 is associated with reactions: {13GS}
# GAS5 is associated with reactions: {13GS}
# GSC2 is associated with reactions: {13GS}
# GAS2 is associated with reactions: {13GS}
# SKN1 is associated with reactions: {16GS}
# KRE6 is associated with reactions: {16GS}
# CPD1 is associated with reactions: {23CAPPD}
# DOG2 is associated with reactions: {2DOXG6PP}
# DOG1 is associated with reactions: {2DOXG6PP}
# CAT5 is associated with reactions: {2HPMMBQMOm, 2HPMBQMTm, 3DH5HPBMTm, 2HP6MPMOm, 2HMHMBQMTm}
# COQ9 is associated with reactions: {2HPMMBQMOm, 2HPMBQMTm, 3DH5HPBMTm, 2HP6MPMOm, 2HMHMBQMTm}
# COQ4 is associated with reactions: {2HPMMBQMOm, 2HPMBQMTm, 3DH5HPBMTm, 2HP6MPMOm, 2HMHMBQMTm}
# COQ5 is associated with reactions: {2HPMMBQMOm, 2HPMBQMTm, 3DH5HPBMTm, 2HP6MPMOm, 2HMHMBQMTm}
# COQ6 is associated with reactions: {2HPMMBQMOm, 2HPMBQMTm, 3DH5HPBMTm, 2HP6MPMOm, 2HMHMBQMTm}
# COQ3 is associated with reactions: {2HPMMBQMOm, 2HPMBQMTm, 3DH5HPBMTm, 2HP6MPMOm, 2HMHMBQMTm}
# COQ8 is associated with reactions: {2HPMMBQMOm, 2HPMBQMTm, 3DH5HPBMTm, 2HP6MPMOm, 2HMHMBQMTm}
# TSC10 is associated with reactions: {3DSPHR}
# BNA1 is associated with reactions: {3HAO}
# TMT1 is associated with reactions: {ACON3MT, 3IPM3MT}
# PDC6 is associated with reactions: {ACALDCD, 3MOBDC, 3MOPDC, PPYRDC, PYRDC, INDPYRD, PYRDC2}
# PDC5 is associated with reactions: {ACALDCD, 3MOBDC, 3MOPDC, PPYRDC, PYRDC, INDPYRD, PYRDC2}
# PDC1 is associated with reactions: {ACALDCD, 3MOBDC, 3MOPDC, PPYRDC, PYRDC, INDPYRD, PYRDC2}
# ARO10 is associated with reactions: {INDPYRD, PPYRDC, 4MOPDC, 3MOPDC}
# THI3 is associated with reactions: {4MOPDC, 3MOPDC}
# PUT2 is associated with reactions: {HPROxm, HPROym, 4HGLSDm, PHCDm, PYR5CDm}
# THR4 is associated with reactions: {THRS, 4HTHRS}
# UGA4 is associated with reactions: {5AOPt2, ABUTt2r}
# BIO5 is associated with reactions: {8AONNt2}
# LYS5 is associated with reactions: {AASAD1, AASAD2}
# LYS2 is associated with reactions: {AASAD1, AASAD2}
# UGA1 is associated with reactions: {ABTA}
# ALD5 is associated with reactions: {ALDD2ym, ABUTDm, ALDD20ym}
# ALD4 is associated with reactions: {ALDD2xm, ALDD20xm, ALDD20ym, ALDD2ym, ABUTDm}
# PUT4 is associated with reactions: {ALAt2r, ABUTt2r, GLYt2r, PROt2r}
# ERG10 is associated with reactions: {ACACT1r, ACACT1m}
# POT1 is associated with reactions: {ACACT8p, FAO240p, FAO80p, ACACT9p, FAO141p_even, ACACT4p, ACACT5p, FAO141p_odd, FAO161p_even, FAO161p_odd, FAO181p_even, FAO181p_odd, ACACT6p, FAO182p_eveneven, FAO182p_evenodd, ACACT7p, FAO182p_oddodd}
# ACC1 is associated with reactions: {FAS160, FAS120, FAS160COA, FAS120COA, FAS80COA_L, FAS100COA, FAS140, FAS180, FAS80_L, FAS100, FAS180COA, ACCOAC, FAS140COA}
# HFA1 is associated with reactions: {ACCOACrm}
# GNA1 is associated with reactions: {ACGAM6PS}
# PCM1 is associated with reactions: {ACGAMPM, PGAMT}
# ARG5,6 is associated with reactions: {ACGKm, AGPRim}
# ARG2 is associated with reactions: {ACGSm}
# ARG7 is associated with reactions: {ORNTACim, ACGSm}
# ILV6 is associated with reactions: {ACLSm, ACHBSm}
# ILV2 is associated with reactions: {ACLSm, ACHBSm}
# IAH1 is associated with reactions: {ACHLE2, ACHLE3, ACHLE1}
# ACH1 is associated with reactions: {ACOAHim}
# POX1 is associated with reactions: {FAO240p, ACOAO6p, FAO80p, ACOAO7p, FAO141p_even, ACOAO8p, ACOAO9p, FAO141p_odd, FAO161p_even, ACOAO4p, FAO161p_odd, ACOAO5p, FAO181p_even, FAO181p_odd, FAO182p_eveneven, FAO182p_evenodd, FAO182p_oddodd}
# FAS1 is associated with reactions: {FAS160, FAS120, FA161ACPHi, FAS100, FA182ACPH, FAS180COA, FA141ACPHi, MCOATA, ACOATA, FAS120COA, FA180ACPH, FAS80COA_L, FAS100COA, FAS140, FAS180, FAS80_L, FA120ACPHi, FA160ACPHi, FA140ACPHi, FAS160COA, FAS140COA, FA181ACPH}
# FAS2 is associated with reactions: {FAS160, FAS120, FA161ACPHi, FAS100, FA182ACPH, FAS180COA, FA141ACPHi, MCOATA, ACOATA, FAS120COA, FA180ACPH, FAS80COA_L, FAS100COA, FAS140, FAS180, FAS80_L, FA120ACPHi, FA160ACPHi, FA140ACPHi, FAS160COA, FAS140COA, FA181ACPH}
# ETR1 is associated with reactions: {FAS120ACPm, FAS80ACPm_L, FAS181ACPm, FAS161ACPm, MCOATAm, FAS182ACPm, FAS140ACPm, ACOATAm, FAS180ACPm, FAS100ACPm, FAS160ACPm, FAS141ACPm}
# ACP1 is associated with reactions: {FAS120ACPm, FAS80ACPm_L, FAS181ACPm, FAS161ACPm, MCOATAm, FAS182ACPm, FAS140ACPm, ACOATAm, FAS180ACPm, FAS100ACPm, NADH2_u6m, FAS160ACPm, FAS141ACPm}
# HTD2 is associated with reactions: {FAS120ACPm, FAS80ACPm_L, FAS181ACPm, FAS161ACPm, MCOATAm, FAS182ACPm, FAS140ACPm, ACOATAm, FAS180ACPm, FAS100ACPm, FAS160ACPm, FAS141ACPm}
# CEM1 is associated with reactions: {FAS120ACPm, FAS80ACPm_L, FAS181ACPm, FAS161ACPm, MCOATAm, FAS182ACPm, FAS140ACPm, ACOATAm, FAS180ACPm, FAS100ACPm, FAS160ACPm, FAS141ACPm}
# OAR1 is associated with reactions: {FAS120ACPm, FAS80ACPm_L, FAS181ACPm, FAS161ACPm, MCOATAm, FAS182ACPm, FAS140ACPm, ACOATAm, FAS180ACPm, FAS100ACPm, FAS160ACPm, FAS141ACPm}
# MCT1 is associated with reactions: {FAS120ACPm, FAS80ACPm_L, FAS181ACPm, FAS161ACPm, MCOATAm, FAS182ACPm, FAS140ACPm, ACOATAm, FAS180ACPm, FAS100ACPm, FAS160ACPm, FAS141ACPm}
# ACO1 is associated with reactions: {ACONT, ACONTm}
# PDH1 is associated with reactions: {ACONT3m}
# ACO2 is associated with reactions: {ACONTm}
# ARG8 is associated with reactions: {ACOTAim}
# PHO11 is associated with reactions: {ACP1e}
# PHO5 is associated with reactions: {ACP1e}
# PPT2 is associated with reactions: {ACPSm}
# ACS2 is associated with reactions: {ACS}
# ACS1 is associated with reactions: {ACSm, ACSp}
# BPH1 is associated with reactions: {ACt2r}
# ADY2 is associated with reactions: {ACtr}
# AAH1 is associated with reactions: {ADA, ADD, DADA}
# ABZ2 is associated with reactions: {ADCL}
# ABZ1 is associated with reactions: {ADCS}
# FCY21 is associated with reactions: {GUAt2r, ADEt2, CSNt2}
# FCY2 is associated with reactions: {GUAt2r, ADEt2, CSNt2}
# TPN1 is associated with reactions: {GUAt2r, ADEt2, CSNt2}
# AYR1 is associated with reactions: {ADHAPR_SC}
# ADK1 is associated with reactions: {ADK4, ADK1, ADK3}
# ADK2 is associated with reactions: {ADK4m, ADK3m, ADK1m}
# SPE2 is associated with reactions: {ADMDC}
# CYR1 is associated with reactions: {ADNCYC}
# ADO1 is associated with reactions: {ADNK1}
# URH1 is associated with reactions: {GNNUC, ADNUC}
# FUN26 is associated with reactions: {CYTDt2, ADNt2, URIt2}
# APT1 is associated with reactions: {ADPT}
# APT2 is associated with reactions: {ADPT}
# MET14 is associated with reactions: {ADSK}
# ADE13 is associated with reactions: {ADSL2r, ADSL1r}
# ADE12 is associated with reactions: {ADSS}
#  is associated with reactions: {AGAT_SC, CITtam}
# SLC1 is associated with reactions: {AGAT_SC}
# AGX1 is associated with reactions: {AGTi}
# SAH1 is associated with reactions: {AHCi}
# MET17 is associated with reactions: {AHSERL, AHSERL2}
# ADE17 is associated with reactions: {AICART, IMPC}
# ADE16 is associated with reactions: {AICART, IMPC}
# ADE2 is associated with reactions: {AIRCr}
# KGD1 is associated with reactions: {AKGDam, AKGDbm, GCC2cm_copy2}
# KGD2 is associated with reactions: {AKGDam, AKGDbm, GCC2cm_copy2}
# LPD1 is associated with reactions: {GCC2bim, GLYCLm, GCC2cm_copy1, GCCam, GCCbim, PDHm, AKGDbm, GCCcm, GCC2cm_copy2, AKGDam, GCC2am}
# PHO8 is associated with reactions: {AKP1}
# HEM1 is associated with reactions: {ALASm}
# ALT2 is associated with reactions: {ALATA_L}
# ALT1 is associated with reactions: {ALATA_Lm}
# ALA1 is associated with reactions: {ALATRS}
# AGP1 is associated with reactions: {GLNt2r, PHEt2r, SERt2r, VALt2r, ALAt2r, TYRt2r, THRt2r, ASNt2r, GLUt2r, ILEt2r, HISt2r, METt2r, LEUt2r}
# TAT2 is associated with reactions: {PHEt2r, CYSt2r, ALAt2r, TYRt2r, GLYt2r, TRPt2r}
# GAP1 is associated with reactions: {GLNt2r, ASPt2r, VALt2r, TRPt2r, THRt2r, ILEt2r, HISt2r, GLYt2r, LEUt2r, ARGt2r, PHEt2r, ORNt2r, PROt2r, SERt2r, ALAt2r, TYRt2r, CYSt2r, ASNt2r, GLUt2r, METt2r, LYSt2r}
# DIP5 is associated with reactions: {GLNt2r, ASPt2r, ASNt2r, GLUt2r, SERt2r, ALAt2r, GLYt2r}
# GRE3 is associated with reactions: {ARABR, XYLR, LALDO3, ALCD19y, SBTR}
# YPR1 is associated with reactions: {ALCD19y, ALCD22yi}
# ADH5 is associated with reactions: {ALCD26xi, ALCD24xi, ALCD22xi, ALCD23xi, ALCD2ir, ALCD25xi}
# ADH4 is associated with reactions: {ALCD26xi, ALCD24xi, ALCD22xi, ALCD23xi, ALCD2ir, ALCD25xi}
# SFA1 is associated with reactions: {ALCD26xi, ALCD24xi, ALCD22xi, FALDH, ALCD23xi, ALCD25xi, ALCD2x_copy2}
# ADH2 is associated with reactions: {ALCD26xi, ALCD24xi, ALCD22xi, ALCD2x_copy1, ALCD23xi, ALCD25xi}
# ADH1 is associated with reactions: {ALCD26xi, ALCD24xi, ALCD22xi, ALCD23xi, ALCD2ir, ALCD25xi}
# ADH3 is associated with reactions: {ALCD22xim, ALCD24xim, ALCD2irm, ALCD25xim, ALCD23xim, ALCD26xim}
# CSG2 is associated with reactions: {ALCD24yi, ALCD22yi, MIPCS126_SC, MIPCS224_SC, ALCD25yi, ALCD23yi, MIPCS226_SC, MIPCS324_SC, MIPCS326_SC, MIPCS124_SC}
# ADH6 is associated with reactions: {ALCD25yi, ALCD23yi, ALCD24yi, ALCD22yi}
# ALD2 is associated with reactions: {ALDD22x, ALDD19xr}
# ALD3 is associated with reactions: {ALDD22x, ALDD19xr}
# ALD6 is associated with reactions: {ALDD2y, ALDD20y}
# DAL2 is associated with reactions: {ALLTAHr}
# DAL1 is associated with reactions: {ALLTN}
# DAL4 is associated with reactions: {ALLTNti}
# DAL5 is associated with reactions: {ALLTTti}
# DUR1,2 is associated with reactions: {UREASE, ALPHNH}
# BIO3 is associated with reactions: {AMAOTr}
# SAM3 is associated with reactions: {AMETt2}
# PET8 is associated with reactions: {AMETtm}
# AMD2 is associated with reactions: {AMID, AMID3, AMID2}
# HER2 is associated with reactions: {AMID}
# AMD1 is associated with reactions: {AMPN, AMPDA}
#  is associated with reactions: {AMPN}
#  is associated with reactions: {AMPN}
# TRP4 is associated with reactions: {ANPRT}
# TRP3 is associated with reactions: {IGPS, ANS}
# TRP2 is associated with reactions: {ANS}
# HNT2 is associated with reactions: {AP4AH}
# ALO1 is associated with reactions: {ARAB14LO}
# ARA1 is associated with reactions: {ARAB1D2}
# CAR1 is associated with reactions: {ARGN}
# ARG4 is associated with reactions: {ARGSL}
# ARG1 is associated with reactions: {ARGSS}
#  is associated with reactions: {ARGTRS}
# MSR1 is associated with reactions: {ARGTRSm}
# CAN1 is associated with reactions: {ORNt2r, ARGt2r}
# ALP1 is associated with reactions: {ARGt2r}
# VBA2 is associated with reactions: {TYRt6, LYSt6, ARGt6, HISt6}
# HMT1 is associated with reactions: {ARMT}
# HOM2 is associated with reactions: {ASAD}
# ASP1 is associated with reactions: {ASNN}
# ASP3-1 is associated with reactions: {ASNNe}
# ASP3-4 is associated with reactions: {ASNNe}
# ASP3-3 is associated with reactions: {ASNNe}
# ASP3-2 is associated with reactions: {ASNNe}
# ASN2 is associated with reactions: {ASNS1}
#  is associated with reactions: {ASNS1}
# ASN1 is associated with reactions: {ASNS1}
# DED81 is associated with reactions: {ASNTRS}
# SLM5 is associated with reactions: {ASNTRSm}
# GNP1 is associated with reactions: {GLNt2r, CYSt2r, ASNt2r, SERt2r, METt2r, LEUt2r, THRt2r}
# AVT1 is associated with reactions: {TYRt6, GLNt6, LEUt6, ASNt6, ILEt6}
# AVT3 is associated with reactions: {ILEt7, TYRt7, GLNt7, ASNt7, LEUt7}
# AVT4 is associated with reactions: {ILEt7, TYRt7, GLNt7, ASNt7, LEUt7}
# URA2 is associated with reactions: {ASPCT, CBPS, DHORTS}
# AGC1 is associated with reactions: {GLUt7m, ASPGLU2m}
# HOM3 is associated with reactions: {ASPK}
# AAT2 is associated with reactions: {ASPTAp, TYRTAip, ASPTA, EHGLAT, EHGLATp, TYRTAi}
# AAT1 is associated with reactions: {TYRTAim, ASPTAm, EHGLATm}
# DPS1 is associated with reactions: {ASPTRS}
# MSD1 is associated with reactions: {ASPTRSm}
# AGP3 is associated with reactions: {SERt2r, ASPt2r, GLUt2r}
# AVT6 is associated with reactions: {ASPt7, GLUt7}
#  is associated with reactions: {ATHRDHr, LSERDHr}
# ANT1 is associated with reactions: {ATPtp_H, ATP2tp_H}
# APA2 is associated with reactions: {ATPATF1}
# APA1 is associated with reactions: {ATPATF3, ATPATF2, SLFAT}
# YND1 is associated with reactions: {NDP7, UTPH1, NDP3, ATPH1, NDP1, GTPH1}
# HIS1 is associated with reactions: {ATPPRT}
# PMA2 is associated with reactions: {ATPS}
# PMA1 is associated with reactions: {ATPS}
# VMA13 is associated with reactions: {ATPS3g, ATPS3v}
# VMA5 is associated with reactions: {ATPS3g, ATPS3v}
# VMA4 is associated with reactions: {ATPS3g, ATPS3v}
# VMA1 is associated with reactions: {ATPS3g, ATPS3v}
# VMA11 is associated with reactions: {ATPS3g, ATPS3v}
# VMA8 is associated with reactions: {ATPS3g, ATPS3v}
# VMA3 is associated with reactions: {ATPS3g, ATPS3v}
# VMA7 is associated with reactions: {ATPS3g, ATPS3v}
# STV1 is associated with reactions: {ATPS3g}
# VMA16 is associated with reactions: {ATPS3g, ATPS3v}
# VMA2 is associated with reactions: {ATPS3g, ATPS3v}
# VMA6 is associated with reactions: {ATPS3g, ATPS3v}
# ATP3 is associated with reactions: {ATPS3m}
# ATP16 is associated with reactions: {ATPS3m}
# ATP7 is associated with reactions: {ATPS3m}
# ATP15 is associated with reactions: {ATPS3m}
# ATP5 is associated with reactions: {ATPS3m}
# ATP4 is associated with reactions: {ATPS3m}
# ATP6 is associated with reactions: {ATPS3m}
# OLI1 is associated with reactions: {ATPS3m}
# ATP1 is associated with reactions: {ATPS3m}
# ATP17 is associated with reactions: {ATPS3m}
# ATP14 is associated with reactions: {ATPS3m}
# ATP20 is associated with reactions: {ATPS3m}
# ATP2 is associated with reactions: {ATPS3m}
# ATP8 is associated with reactions: {ATPS3m}
# INH1 is associated with reactions: {ATPS3m}
# VPH1 is associated with reactions: {ATPS3v}
# AAC3 is associated with reactions: {ATPtm_H}
# AAC1 is associated with reactions: {ATPtm_H}
# PET9 is associated with reactions: {ATPtm_H}
# BPL1 is associated with reactions: {BACCL}
# MET22 is associated with reactions: {BPNT}
# BDH1 is associated with reactions: {BTDD_RR}
# VHT1 is associated with reactions: {BTNt2i}
# BIO2 is associated with reactions: {BTSr}
# ERG24 is associated with reactions: {C14STR}
# ERG5 is associated with reactions: {C22STDSx, C22STDS}
# NCP1 is associated with reactions: {NFTYROX, C22STDS, SQLEr, LNS14DM}
# CBR1 is associated with reactions: {C22STDSx, LNS14DMx, SQLErx}
# MCR1 is associated with reactions: {C22STDSx, LNS14DMx, SQLErx}
# CYB5 is associated with reactions: {C22STDSx, LNS14DMx, SQLErx}
# ERG4 is associated with reactions: {C24STRer}
# ERG26 is associated with reactions: {C3STDH2, C3STDH1}
# ERG27 is associated with reactions: {C3STKR1, C3STKR2}
# ERG25 is associated with reactions: {C4STMO1, C4STMO2}
# ERG3 is associated with reactions: {C5STDS}
# ERG2 is associated with reactions: {C8STI}
# CTT1 is associated with reactions: {CAT}
# CTA1 is associated with reactions: {CATp}
# CPA2 is associated with reactions: {CBPS}
# CPA1 is associated with reactions: {CBPS}
# CCP1 is associated with reactions: {CCP2m}
# CYC7 is associated with reactions: {D_LACDm, D_LACDcm, L_LACD2cm, CCP2m, CYOOm, CYOR_u6m}
# CYC1 is associated with reactions: {D_LACDm, D_LACDcm, L_LACD2cm, CCP2m, CYOOm, CYOR_u6m}
# PGS1 is associated with reactions: {CDPDGPm_SC}
# YDC1 is associated with reactions: {CERS124er, CERASE126er, CERASE226er, CERASE224er, CERS126er, CERASE124er}
# YPC1 is associated with reactions: {CERS226er, CERASE226er, CERASE224er, CERS224er}
# SUR2 is associated with reactions: {PSPHS, CERH126_copy1, CERH124_copy1}
# LAC1 is associated with reactions: {CERS124er, CERS126, CERS124, CERS126er, CERS224, CERS226er, CERS224er, CERS226}
# LAG1 is associated with reactions: {CERS124er, CERS126, CERS124, CERS126er, CERS224, CERS226er, CERS224er, CERS226}
# SCS7 is associated with reactions: {CERH126_copy2, CERS324, CERS326, CERH124_copy2}
# PCT1 is associated with reactions: {CHLPCTD}
# HNM1 is associated with reactions: {CHLt2}
# CKI1 is associated with reactions: {CHOLK}
# ARO7 is associated with reactions: {CHORM}
# ARO2 is associated with reactions: {CHORS}
# CDA1 is associated with reactions: {CHTNDA}
# CDA2 is associated with reactions: {CHTNDA}
# CHS3 is associated with reactions: {CHTNS}
# CHS1 is associated with reactions: {CHTNS}
# CHS2 is associated with reactions: {CHTNS}
# CTP1 is associated with reactions: {CITtcm, CITtbm, CITtam}
# CRD1 is associated with reactions: {CLPNSm_SC}
# PCD1 is associated with reactions: {COAHLp}
# LEU5 is associated with reactions: {COAtim}
# HEM13 is associated with reactions: {CPPPGO}
# CRC1 is associated with reactions: {CRNCARtm}
# AGP2 is associated with reactions: {CRNt}
# CAT2 is associated with reactions: {CSNATm, CSNATp}
# YAT1 is associated with reactions: {CSNATr}
# YAT2 is associated with reactions: {CSNATr}
# FCY1 is associated with reactions: {CSND}
# CIT1 is associated with reactions: {CSm}
# CIT3 is associated with reactions: {CSm, MCITSm}
# CIT2 is associated with reactions: {CSp}
# URA7 is associated with reactions: {CTPS2, CTPS1}
# URA8 is associated with reactions: {CTPS2, CTPS1}
# RIM2 is associated with reactions: {UTPtm, CTPtm}
# COX4 is associated with reactions: {CYOOm}
# COX12 is associated with reactions: {CYOOm}
# COX7 is associated with reactions: {CYOOm}
# COX9 is associated with reactions: {CYOOm}
# COX5A is associated with reactions: {CYOOm}
# COX5B is associated with reactions: {CYOOm}
# COX2 is associated with reactions: {CYOOm}
# COX13 is associated with reactions: {CYOOm}
# COX3 is associated with reactions: {CYOOm}
# COX1 is associated with reactions: {CYOOm}
# COX6 is associated with reactions: {CYOOm}
# COX8 is associated with reactions: {CYOOm}
# RIP1 is associated with reactions: {CYOR_u6m}
# QCR8 is associated with reactions: {CYOR_u6m}
# QCR6 is associated with reactions: {CYOR_u6m}
# COB is associated with reactions: {CYOR_u6m}
# COR1 is associated with reactions: {CYOR_u6m}
# CYT1 is associated with reactions: {CYOR_u6m}
# QCR9 is associated with reactions: {CYOR_u6m}
# QCR7 is associated with reactions: {CYOR_u6m}
# QCR2 is associated with reactions: {CYOR_u6m}
# MCY1 is associated with reactions: {CYSS}
# CYS3 is associated with reactions: {CYSTGL}
# IRC7 is associated with reactions: {CYSTL}
# STR3 is associated with reactions: {CYSTLp}
#  is associated with reactions: {CYSTRS}
# CYS4 is associated with reactions: {CYSTS}
# BAP3 is associated with reactions: {PHEt2r, VALt2r, TYRt2r, TRPt2r, CYSt2r, ILEt2r, METt2r, LEUt2r}
# BAP2 is associated with reactions: {PHEt2r, VALt2r, TYRt2r, TRPt2r, CYSt2r, ILEt2r, METt2r, LEUt2r}
# TAT1 is associated with reactions: {VALt2r, TYRt2r, TRPt2r, THRt2r, CYSt2r, ILEt2r, HISt2r, LEUt2r}
# CDD1 is associated with reactions: {CYTD, DCYTD}
# URK1 is associated with reactions: {URIK1, CYTDK2, URIK2}
# CPT1 is associated with reactions: {DAGCPT_SC}
# EPT1 is associated with reactions: {DAGCPT_SC, ETHAPT_SC}
# DPP1 is associated with reactions: {LPP_SC, DAGPYP_SC}
# LPP1 is associated with reactions: {LPP_SC, DAGPYP_SC}
# CDS1 is associated with reactions: {DASYNm_SC, DASYN_SC}
# RIB3 is associated with reactions: {DB4PS}
# BIO4 is associated with reactions: {DBTS}
# DCD1 is associated with reactions: {DCMPDA, DCTPD}
# ARO4 is associated with reactions: {DDPA}
# ARO3 is associated with reactions: {DDPAm, DDPA}
# OLE1 is associated with reactions: {DESAT16, DESAT18}
# IMA4 is associated with reactions: {DGGH, MALT}
# GUK1 is associated with reactions: {GK1, GK2, DGK1}
# ILV3 is associated with reactions: {DHAD1m, DHAD2m}
# DAK1 is associated with reactions: {DHAK}
# DAK2 is associated with reactions: {DHAK}
# DFR1 is associated with reactions: {DHFR, DHFRim}
# FOL1 is associated with reactions: {DHPSm, HPPKm, FOLD3m, DHNPAm}
# URA1 is associated with reactions: {DHORDfum, DHORD4i, DHORDi}
# URA4 is associated with reactions: {DHORTS}
# ARO1 is associated with reactions: {SHKK, PSCVT, DHQS, SHK3Dr, DHQTi}
# DPH5 is associated with reactions: {DIPS}
# UTR4 is associated with reactions: {DKMPPD2}
# ADI1 is associated with reactions: {DKMPPD2}
# ERG20 is associated with reactions: {GRTT, DMATT}
# GET3 is associated with reactions: {DNMPPA}
# SEC59 is associated with reactions: {DOLK}
# PMT5 is associated with reactions: {DOLPMMer}
# PMT6 is associated with reactions: {DOLPMMer}
# PMT1 is associated with reactions: {DOLPMMer}
# PMT3 is associated with reactions: {DOLPMMer}
# PMT4 is associated with reactions: {DOLPMMer}
# PMT2 is associated with reactions: {DOLPMMer}
# DPM1 is associated with reactions: {DOLPMTcer}
# GPM1 is associated with reactions: {DPGM, PGM}
# MVD1 is associated with reactions: {DPMVD}
# PAN5 is associated with reactions: {DPR}
# ILV5 is associated with reactions: {DPRm, KARA2im, KARA1im}
# RBK1 is associated with reactions: {DRBK, RBK}
# RIB7 is associated with reactions: {DROPPRy}
# RIB2 is associated with reactions: {DRTPPD}
# CDC8 is associated with reactions: {DTMPK}
# PNP1 is associated with reactions: {PUNP3, PUNP1, DURIPP, PUNP7, TMDPP, PUNP3m, PUNP4, PUNP1m, PUNP5, PUNP2, PUNP6}
# DUT1 is associated with reactions: {DUTPDP}
# DYS1 is associated with reactions: {DXHPScm}
# DLD3 is associated with reactions: {D_LACDcm}
# DLD1 is associated with reactions: {D_LACDcm}
# DLD2 is associated with reactions: {D_LACDm}
# JEN1 is associated with reactions: {PYRt2, L_LACt2r, D_LACt2}
# FOX2 is associated with reactions: {HACD5p, FAO240p, HACD6p, FAO80p, HACD7p, FAO141p_even, ECOAH4p, HACD8p, ECOAH5p, ECOAH6p, ECOAH7p, FAO141p_odd, FAO161p_even, ECOAH8p, FAO161p_odd, FAO181p_even, FAO181p_odd, FAO182p_evenodd, FAO182p_eveneven, HACD10p, HACD4p, FAO182p_oddodd, ECOAH11p}
# ERR2 is associated with reactions: {ENO}
# ERR1 is associated with reactions: {ENO}
# ERR3 is associated with reactions: {ENO}
# ENO1 is associated with reactions: {ENO}
# ENO2 is associated with reactions: {ENO}
# PGU1 is associated with reactions: {EPGALURSe}
# ARE1 is associated with reactions: {TRIGS_SC, ZYMSTAT_SC, FECOSTAT_SC, LANOSTAT_SC, ERGSTAT_SC, EPISTAT_SC}
# YEH1 is associated with reactions: {ZYMSTESTH_SC, EPISTESTH_SC, LANOSTESTH_SC, ERGSTESTH_SC, FECOSTESTH_SC}
# TGL1 is associated with reactions: {ZYMSTESTH_SC, EPISTESTH_SC, LANOSTESTH_SC, ERGSTESTH_SC, FECOSTESTH_SC}
# YEH2 is associated with reactions: {ERGSTESTH_SCe, EPISTESTH_SCe, FECOSTESTH_SCe, ZYMSTESTH_SCe, LANOSTESTH_SCe}
# AUS1 is associated with reactions: {FECOSTt, ZYMSTt, LANOSTt, ERGSTt, EPISTt}
# PDR11 is associated with reactions: {FECOSTt, ZYMSTt, LANOSTt, ERGSTt, EPISTt}
#  is associated with reactions: {MELTGH, RAFGH, EPMGH, GALIGH, GALS3, GGLGH}
# ARE2 is associated with reactions: {ERGSTAT_SC, TRIGS_SC}
# ATG26 is associated with reactions: {ERGSTGLCT}
# EKI1 is associated with reactions: {ETHAK}
# PXA2 is associated with reactions: {FA140COAabcp, FA182COAabcp, FA180COAabcp, FA161COAabcp, FA160COAabcp, FA181COAabcp, FA141COAabcp}
# PXA1 is associated with reactions: {FA140COAabcp, FA182COAabcp, FA180COAabcp, FA161COAabcp, FA160COAabcp, FA181COAabcp, FA141COAabcp}
# FAT1 is associated with reactions: {FA240tp, FACOAL260p, FACOAL240p, FA260tp}
# FAA2 is associated with reactions: {FACOAL160p, FACOAL100p, FACOAL140p, FACOAL161p, FACOAL80p, FACOAL141p, FACOAL120p}
# FAA1 is associated with reactions: {FACOAL140, FACOAL182, FACOAL160, FACOAL161, FACOAL141, FACOAL181, FACOAL180}
# FAA4 is associated with reactions: {FACOAL140, FACOAL182, FACOAL160, FACOAL161, FACOAL141, FACOAL181, FACOAL180}
# FAA3 is associated with reactions: {FACOAL140, FACOAL182, FACOAL160, FACOAL161, FACOAL141, FACOAL181, FACOAL180}
# FLX1 is associated with reactions: {FADFMNtm}
# SPS19 is associated with reactions: {FAO141p_even, FAO182p_eveneven, FAO161p_even, FAO182p_evenodd, FAO181p_even}
# DCI1 is associated with reactions: {FAO141p_odd, FAO161p_even, FAO161p_odd, FAO181p_even, FAO141p_even, FAO181p_odd, FAO182p_eveneven, FAO182p_evenodd, FAO182p_oddodd}
# ECI1 is associated with reactions: {FAO141p_odd, FAO161p_even, FAO161p_odd, FAO181p_even, FAO141p_even, FAO181p_odd, FAO182p_eveneven, FAO182p_evenodd, FAO182p_oddodd}
# ACB1 is associated with reactions: {FAS160, FAS120, FAS120COA, FAS80COA_L, FAS100COA, FAS140, FAS180, FAS80_L, FAS100, FAS180COA, FAS160COA, FAS140COA}
# ELO1 is associated with reactions: {FAS181, FAS161, FAS141}
# ELO3 is associated with reactions: {FAS260, FAS240_L}
# TSC13 is associated with reactions: {FAS260, FAS240_L}
# FBA1 is associated with reactions: {FBA, FBA2, FBA3}
# FBP1 is associated with reactions: {FBP}
# FBP26 is associated with reactions: {FBP26}
# HEM15 is associated with reactions: {FCLTm}
#  is associated with reactions: {FDH}
# FDH1 is associated with reactions: {FDH}
#  is associated with reactions: {FDH}
# FET4 is associated with reactions: {FE2t}
# BNA3 is associated with reactions: {FKYNH}
# FMT1 is associated with reactions: {FMETTRSm}
# FAD1 is associated with reactions: {FMNAT}
# LOT6 is associated with reactions: {FMNRx, FMNRx2}
# FRD1 is associated with reactions: {FRDcm}
# OSM1 is associated with reactions: {FRDm}
# BTS1 is associated with reactions: {FRTT}
# HXT8 is associated with reactions: {MANt2, GLCt1, FRUt2}
# HXT9 is associated with reactions: {GALt2, MANt2, GLCt1, FRUt2}
# HXT16 is associated with reactions: {MANt2, GLCt1, FRUt2}
# HXT4 is associated with reactions: {MANt2, GLCt1, FRUt2}
# HXT5 is associated with reactions: {MANt2, GLCt1, FRUt2}
# HXT11 is associated with reactions: {GALt2, MANt2, GLCt1, FRUt2}
# HXT17 is associated with reactions: {MANt2, GLCt1, FRUt2}
# HXT13 is associated with reactions: {MANt2, GLCt1, FRUt2}
# HXT1 is associated with reactions: {MANt2, GLCt1, FRUt2}
# HXT15 is associated with reactions: {MANt2, GLCt1, FRUt2}
# HXT2 is associated with reactions: {MANt2, GLCt1, FRUt2}
# HXT6 is associated with reactions: {MANt2, GLCt1, FRUt2}
# HXT7 is associated with reactions: {MANt2, GLCt1, FRUt2}
# HXT10 is associated with reactions: {GALt2, MANt2, GLCt1, FRUt2}
# HXT3 is associated with reactions: {MANt2, GLCt1, FRUt2}
# FAU1 is associated with reactions: {FTHFCL}
# ADE3 is associated with reactions: {FTHFLi, MTHFC, MTHFD}
# MIS1 is associated with reactions: {MTHFDm, MTHFCm, FTHFLmi}
# FUM1 is associated with reactions: {FUMm, FUM}
# KTR5 is associated with reactions: {G12MT2g, G12MT1g}
# KTR3 is associated with reactions: {G12MT2g, G12MT1g}
# KTR1 is associated with reactions: {G12MT2g, G12MT1g}
# KRE2 is associated with reactions: {G12MT2g, G12MT1g}
# KTR4 is associated with reactions: {G12MT2g, G12MT1g}
# KTR6 is associated with reactions: {G12MT2g, G12MT1g}
# YUR1 is associated with reactions: {G12MT2g, G12MT1g}
# KTR2 is associated with reactions: {G12MT2g, G12MT1g}
# GIT1 is associated with reactions: {G3PIt, G3PCt}
# GPD1 is associated with reactions: {G3PD1ir}
# GPD2 is associated with reactions: {G3PD1irm}
# GUT2 is associated with reactions: {G3PDm}
# GPP2 is associated with reactions: {G3PT}
# GPP1 is associated with reactions: {G3PT}
# PRO2 is associated with reactions: {G5SD2, G5SD}
# ZWF1 is associated with reactions: {G6PDH2r}
# PGI1 is associated with reactions: {PGI, G6PI, G6PI3}
# GAL1 is associated with reactions: {GALKr}
# GAL7 is associated with reactions: {GALT, UGLT}
# UGP1 is associated with reactions: {GALUi}
#  is associated with reactions: {GALUi}
# STL1 is associated with reactions: {GLUt2r, GLCt1, GALt2}
# HXT14 is associated with reactions: {GALt2}
# GAL2 is associated with reactions: {GLCt1, GALt2}
# TDH3 is associated with reactions: {GAPD}
# TDH1 is associated with reactions: {GAPD}
# TDH2 is associated with reactions: {GAPD}
# ADE8 is associated with reactions: {GARFT}
# SCT1 is associated with reactions: {GAT2_SC, GAT1_SC}
# GPT2 is associated with reactions: {GAT2_SC, GAT1_SC}
# GLC3 is associated with reactions: {GBEZ}
# GCV1 is associated with reactions: {GCC2bim, GLYCLm, GCC2cm_copy1, THFATm, GCCam, GCCbim, GCCcm, GCC2am}
# GCV2 is associated with reactions: {GCC2bim, GLYCLm, GCC2cm_copy1, THFATm, GCCam, GCCbim, GCCcm, GCC2am}
# GCV3 is associated with reactions: {GCC2bim, GLYCLm, GCC2cm_copy1, THFATm, GCCam, GCCbim, GCCcm, GCC2am}
# VRG4 is associated with reactions: {GDPMANNtg}
#  is associated with reactions: {GF6PTA}
#  is associated with reactions: {GF6PTA}
# GFA1 is associated with reactions: {GF6PTA}
# SHM2 is associated with reactions: {GHMT2r}
# SHM1 is associated with reactions: {GHMT2rm}
# GDB1 is associated with reactions: {GLCGSD}
# SGA1 is associated with reactions: {GLCGSDv}
# GPH1 is associated with reactions: {GLCP}
# GLG1 is associated with reactions: {GLCS2, GLYGS}
# GSY2 is associated with reactions: {GLCS2, GLYGS}
# GSY1 is associated with reactions: {GLCS2, GLYGS}
# GLG2 is associated with reactions: {GLCS2, GLYGS}
# GLN1 is associated with reactions: {GLNS}
# GLN4 is associated with reactions: {GLNTRS}
# NMT1 is associated with reactions: {GLPT}
# PRO1 is associated with reactions: {GLU5K}
# GSH1 is associated with reactions: {GLUCYS}
# GAD1 is associated with reactions: {GLUDC}
# GDH2 is associated with reactions: {GLUDxi}
# GDH3 is associated with reactions: {GLUDy}
# GDH1 is associated with reactions: {GLUDy}
# GLK1 is associated with reactions: {GLUK, HEX1}
# ADE4 is associated with reactions: {GLUPRT}
# GLT1 is associated with reactions: {GLUSx}
# GUS1 is associated with reactions: {GLUTRS}
# MSE1 is associated with reactions: {GLUTRSm}
# GCY1 is associated with reactions: {GLYCDy}
# FPS1 is associated with reactions: {GLYCt}
# GUP2 is associated with reactions: {GLYCt2}
# GUP1 is associated with reactions: {GLYCt2}
# GUT1 is associated with reactions: {GLYK}
# GLO2 is associated with reactions: {GLYOX}
# GLO4 is associated with reactions: {GLYOXm}
# GRS1 is associated with reactions: {GLYTRS}
# GRS2 is associated with reactions: {GLYTRS}
# GUA1 is associated with reactions: {GMPS2}
# GND1 is associated with reactions: {GND}
# GND2 is associated with reactions: {GND}
# GDE1 is associated with reactions: {GPDDA1}
# GRX3 is associated with reactions: {GTHOr}
# GRX4 is associated with reactions: {GTHOr}
# GLR1 is associated with reactions: {GTHOr, GTHOm}
# GRX1 is associated with reactions: {GTHOr, GTHPi}
# GRX2 is associated with reactions: {GTHOr, GTHPi}
# GRX5 is associated with reactions: {GTHPm, GTHOm}
# HYR1 is associated with reactions: {GTHPi}
# GPX1 is associated with reactions: {GTHPi}
# GPX2 is associated with reactions: {GTHPi}
# YCF1 is associated with reactions: {GTHRDabcv}
# OPT1 is associated with reactions: {GTHRDt2}
# GSH2 is associated with reactions: {GTHS}
# ECM38 is associated with reactions: {GTMLT}
# FOL2 is associated with reactions: {GTPCI}
# RIB1 is associated with reactions: {GTPCII}
# GGC1 is associated with reactions: {GTPt2m}
# GUD1 is associated with reactions: {GUAD}
# HPT1 is associated with reactions: {HXPRT, GUAPRT}
# AQY2 is associated with reactions: {H2Ot}
# AQY1 is associated with reactions: {H2Ot}
# LYS4 is associated with reactions: {HACNHm}
# COQ2 is associated with reactions: {HBZOPT6m}
# LYS21 is associated with reactions: {HCITSn}
# LYS20 is associated with reactions: {HCITSn}
# SAM4 is associated with reactions: {HCYSMT}
# MHT1 is associated with reactions: {HCYSMT}
# COX15 is associated with reactions: {HEMEOMOm}
# YAH1 is associated with reactions: {HEMEOMOm}
# ARH1 is associated with reactions: {HEMEOMOm}
# COX10 is associated with reactions: {HEMEOSm}
# THI6 is associated with reactions: {TMPPP, HETZK}
# HXK1 is associated with reactions: {HEX1, HEX7, HEX4}
# HXK2 is associated with reactions: {HEX1, HEX7, HEX4}
# LYS12 is associated with reactions: {HICITDm}
# HIS4 is associated with reactions: {PRAMPC, PRATPP, HISTD}
# HIS2 is associated with reactions: {HISTP}
# HTS1 is associated with reactions: {HISTRS, HISTRSm}
# HIP1 is associated with reactions: {HISt2r}
# VBA3 is associated with reactions: {LYSt6, HISt6}
# VBA1 is associated with reactions: {LYSt6, HISt6}
# BNA5 is associated with reactions: {HKYNH, KYN}
# HEM3 is associated with reactions: {HMBS}
# HMG2 is associated with reactions: {HMGCOAR}
# HMG1 is associated with reactions: {HMGCOAR}
# ERG13 is associated with reactions: {HMGCOASm, HMGCOAS}
# THI21 is associated with reactions: {PMPK, HMPK1}
# THI20 is associated with reactions: {PMPK, HMPK1}
# THI22 is associated with reactions: {HMPK1}
# PRO3 is associated with reactions: {HPROa, HPROb, P5CR}
# HOM6 is associated with reactions: {HSDy, HSDxi}
# MET2 is associated with reactions: {HSERTA}
# THR1 is associated with reactions: {HSK}
# HIS5 is associated with reactions: {HSTPT}
# IDH2 is associated with reactions: {ICDHxm}
# IDH1 is associated with reactions: {ICDHxm}
# IDP2 is associated with reactions: {ICDHyr}
# IDP1 is associated with reactions: {ICDHym}
# IDP3 is associated with reactions: {ICDHyp}
# ICL1 is associated with reactions: {ICL}
# HIS7 is associated with reactions: {IG3PS}
# HIS3 is associated with reactions: {IGPDH}
# BAT2 is associated with reactions: {LEUTA, VALTA, ILETA, OMCDC}
# BAT1 is associated with reactions: {OMCDCm, VALTAim, ILETAm, LEUTAm}
# ILS1 is associated with reactions: {ILETRS}
# ISM1 is associated with reactions: {ILETRSm}
# IMD2 is associated with reactions: {IMPD}
# IMD3 is associated with reactions: {IMPD}
#  is associated with reactions: {IMPD}
# IMD4 is associated with reactions: {IMPD}
#  is associated with reactions: {IMPD}
# ITR2 is associated with reactions: {INSTt2}
# ITR1 is associated with reactions: {INSTt2}
# ISC1 is associated with reactions: {IPC324PLC_SC, MIPC324PLC_SC, IPC326PLC_SC, MIPC126PLC_SC, MIPC326PLC_SC, MIP2C124PLC_SC, MIP2C126PLC_SC, MIP2C224PLC_SC, MIP2C226PLC_SC, IPC124PLC_SC, IPC126PLC_SC, MIP2C324PLC_SC, MIPC124PLC_SC, MIP2C326PLC_SC, IPC224PLC_SC, MIPC224PLC_SC, IPC226PLC_SC, MIPC226PLC_SC}
# AUR1 is associated with reactions: {IPCS124_SC, IPCS226_SC, IPCS324_SC, IPCS126_SC, IPCS224_SC, IPCS326_SC}
# IDI1 is associated with reactions: {IPDDI}
# LEU2 is associated with reactions: {IPMD}
# LEU1 is associated with reactions: {IPPMIa, IPPMIb}
# LEU4 is associated with reactions: {IPPS, IPPSm}
# LEU9 is associated with reactions: {IPPS}
# LSC1 is associated with reactions: {ITCOALm, SUCOASm}
# LSC2 is associated with reactions: {ITCOALm, SUCOASm}
# BNA4 is associated with reactions: {KYN3OX}
# GRE2 is associated with reactions: {LALDO3}
# ERS1 is associated with reactions: {LCYSTintv}
# CDC60 is associated with reactions: {LEUTRS}
# NAM2 is associated with reactions: {LEUTRSm}
# GLO1 is associated with reactions: {LGTHL}
# ERG11 is associated with reactions: {LNS14DMx, LNS14DM}
# ERG7 is associated with reactions: {LNSTLS}
# TAZ1 is associated with reactions: {LPCAT_SC}
# KRS1 is associated with reactions: {LYSTRS}
# MSK1 is associated with reactions: {LYSTRSm}
# LYP1 is associated with reactions: {LYSt2r}
# CYB2 is associated with reactions: {L_LACD2cm}
# DAL7 is associated with reactions: {MALS, MALSp}
# MLS1 is associated with reactions: {MALS, MALSp}
# MAL32 is associated with reactions: {MALT}
# MAL12 is associated with reactions: {MALT}
# IMA5 is associated with reactions: {MALT}
# IMA1 is associated with reactions: {MALT}
# IMA3 is associated with reactions: {MALT}
# MAL11 is associated with reactions: {MALTt2}
# MPH3 is associated with reactions: {MALTt2}
# MPH2 is associated with reactions: {MALTt2}
# MAL31 is associated with reactions: {MALTt2}
# DIC1 is associated with reactions: {MALtm, SUCCtm, SUCFUMtm}
# PSA1 is associated with reactions: {MAN1PT}
# PMI40 is associated with reactions: {MAN6PI}
# ICL2 is associated with reactions: {MCITL2m}
# MDH2 is associated with reactions: {MDH}
# MDH1 is associated with reactions: {MDHm}
# MDH3 is associated with reactions: {MDHp}
# MAE1 is associated with reactions: {ME2m, ME1m}
# SAM2 is associated with reactions: {METAT}
# SAM1 is associated with reactions: {METAT}
# STR2 is associated with reactions: {METB1}
# MET6 is associated with reactions: {METS, MHPGLUT}
# MES1 is associated with reactions: {METTRS}
# MSM1 is associated with reactions: {METTRSm}
# MUP1 is associated with reactions: {METt2r}
# MUP3 is associated with reactions: {METt2r}
# ERG12 is associated with reactions: {MEVK2, MEVK1, MEVK4, MEVK3}
# OPI3 is associated with reactions: {PMETM_SC, MFAPS_SC}
# IPK1 is associated with reactions: {MI13456PKn}
# ARG82 is associated with reactions: {MI1345PKn, MI1456PKn, MI145PKn, MI145P6Kn}
# INM1 is associated with reactions: {MI1PP}
# INO1 is associated with reactions: {MI1PS}
# IPT1 is associated with reactions: {MIP2CS124_SC, MIP2CS126_SC, MIP2CS324_SC, MIP2CS224_SC, MIP2CS326_SC, MIP2CS226_SC}
# SUR1 is associated with reactions: {MIPCS324_SC, MIPCS326_SC, MIPCS124_SC, MIPCS126_SC, MIPCS224_SC, MIPCS226_SC}
# CSH1 is associated with reactions: {MIPCS324_SC, MIPCS326_SC, MIPCS124_SC, MIPCS126_SC, MIPCS224_SC, MIPCS226_SC}
# MMP1 is associated with reactions: {MMETt2}
# ECM31 is associated with reactions: {MOHMT}
# MEU1 is associated with reactions: {MTAP}
# MTD1 is associated with reactions: {MTHFD2i}
# MET13 is associated with reactions: {MTHFR3}
# MET12 is associated with reactions: {MTHFR3}
# TNA1 is associated with reactions: {NACt}
# NPY1 is associated with reactions: {NADDPp}
# NDE1 is associated with reactions: {NADH2_u6cm}
# NDE2 is associated with reactions: {NADH2_u6cm}
# NDI1 is associated with reactions: {NADH2_u6m}
# YEF1 is associated with reactions: {NADKm, NADK}
# POS5 is associated with reactions: {NADKm, NADK}
# UTR1 is associated with reactions: {NADKm, NADK}
# QNS1 is associated with reactions: {NADS1, NADS1n}
# NPT1 is associated with reactions: {NAPRT, NAPRTm}
# NHA1 is associated with reactions: {NAt3_1}
# GDA1 is associated with reactions: {NDP3g}
# YNK1 is associated with reactions: {NDPK6, NDPK7, NDPK3, NDPK8, NDPK4, NDPK9, NDPK1, NDPK5, NDPK2}
# DTR1 is associated with reactions: {NFORTYRt}
# DIT2 is associated with reactions: {NFTYROX}
# MEP1 is associated with reactions: {NH4t}
# MEP2 is associated with reactions: {NH4t}
# MEP3 is associated with reactions: {NH4t}
# ATO3 is associated with reactions: {NH4ti}
# NMA2 is associated with reactions: {NMNAT}
# NMA1 is associated with reactions: {NNATr, NNATm, NMNATm}
# PNC1 is associated with reactions: {NNAM, NNAMrm}
# BNA6 is associated with reactions: {NNDPRm, NNDPR}
# NNT1 is associated with reactions: {NNMT}
# ISN1 is associated with reactions: {NTD11}
# SDT1 is associated with reactions: {NTD2, NTD4}
# NIT2 is associated with reactions: {NTRLASE, NTRLASE3, NTRLASE2}
# NIT3 is associated with reactions: {NTRLASE, NTRLASE3, NTRLASE2}
# NIT1 is associated with reactions: {NTRLASE, NTRLASE3, NTRLASE2}
# OAC1 is associated with reactions: {OAAt2m}
# ARG3 is associated with reactions: {OCBT}
# ATF1 is associated with reactions: {OHACT4, OHACT2, OHACT5, OHACT1, OHACT3}
# ATF2 is associated with reactions: {OHACT4, OHACT2, OHACT5, OHACT1, OHACT3}
# SER1 is associated with reactions: {PSERT, OHPBAT}
# URA3 is associated with reactions: {OMPDC}
# SPE1 is associated with reactions: {ORNDC}
# CAR2 is associated with reactions: {ORNTA}
# ORT1 is associated with reactions: {ORNt3m}
# URA5 is associated with reactions: {ORPT}
# URA10 is associated with reactions: {ORPT}
# ODC2 is associated with reactions: {OXO2Ctm}
# ODC1 is associated with reactions: {OXO2Ctm}
# PAN6 is associated with reactions: {PANTS}
# TRX2 is associated with reactions: {RNDR3n, TRDR, RNDR4, PAPSR, RNDR4n, THIORDXni, THIORDXp, RNTR1, RNTR2, RNTR3, THIORDXi, RNTR4, RNDR1, RNDR1n, RNDR2, RNDR2n, RNDR3}
# MET16 is associated with reactions: {PAPSR}
# TRX1 is associated with reactions: {RNDR3n, TRDR, RNDR4, PAPSR, RNDR4n, THIORDXni, THIORDXp, RNTR1, RNTR2, RNTR3, THIORDXi, RNTR4, RNDR1, RNDR1n, RNDR2, RNDR2n, RNDR3}
# PYC2 is associated with reactions: {PC}
# PYC1 is associated with reactions: {PC}
# LRO1 is associated with reactions: {PCDAGAT}
# PDE1 is associated with reactions: {PDE1}
# PDE2 is associated with reactions: {PDE5, PDE1, PDE2, PDE4, PDE3}
# PDB1 is associated with reactions: {PDHm, THFATm}
# LAT1 is associated with reactions: {PDHm}
# PDX1 is associated with reactions: {PDHm}
# PDA1 is associated with reactions: {PDHm, THFATm}
# PDX3 is associated with reactions: {PYAM5PO, PYDXO, PYDXNO, PDX5POi}
# NAT1 is associated with reactions: {PEPAT}
# NAT2 is associated with reactions: {PEPAT}
# PTR2 is associated with reactions: {PEPDt3}
# ECT1 is associated with reactions: {PETHCT}
# CHO2 is associated with reactions: {PETOHM_SC}
# PFK2 is associated with reactions: {PFK, PFK_2, PFK_3}
# PFK1 is associated with reactions: {PFK, PFK_2, PFK_3}
# PFK27 is associated with reactions: {PFK26}
# PFK26 is associated with reactions: {PFK26}
# SER3 is associated with reactions: {PGCD}
# SER33 is associated with reactions: {PGCD}
# PGK1 is associated with reactions: {PGK}
# SOL4 is associated with reactions: {PGL}
# SOL1 is associated with reactions: {PGL}
# SOL3 is associated with reactions: {PGL}
# GPM3 is associated with reactions: {PGM}
# GPM2 is associated with reactions: {PGM}
# PGM2 is associated with reactions: {PPM, PGMT}
# PGM1 is associated with reactions: {PPM, PGMT}
# ARO8 is associated with reactions: {TRPTA, PHETA1, TYRTAi}
# ARO9 is associated with reactions: {TRPTA, PHETA1, TYRTAi}
# FRS2 is associated with reactions: {PHETRS}
# FRS1 is associated with reactions: {PHETRS}
# MSF1 is associated with reactions: {PHETRSm}
# SAC1 is associated with reactions: {PI35BP5P_SC}
# INP52 is associated with reactions: {PI35BP5P_SC, PI45BP5P_SC}
# INP53 is associated with reactions: {PI35BP5P_SC, PI45BP5P_SC}
# FAB1 is associated with reactions: {PI3P5K_SC}
# INP54 is associated with reactions: {PI45BP5P_SC}
# INP51 is associated with reactions: {PI45BP5P_SC}
# PLC1 is associated with reactions: {PI45BPP_SC}
# MSS4 is associated with reactions: {PI4P5K_SC}
# TOR2 is associated with reactions: {PIN3K_SC}
# TOR1 is associated with reactions: {PIN3K_SC}
# VPS34 is associated with reactions: {PIN3K_SC}
# PIK1 is associated with reactions: {PIN4K_SC, PIN4Kn_SC}
# STT4 is associated with reactions: {PIN4K_SC}
# PIS1 is associated with reactions: {PINOS_SC}
# MIR1 is associated with reactions: {PIt2m}
# PHO90 is associated with reactions: {PIt2r}
# PHO87 is associated with reactions: {PIt2r}
# PHO89 is associated with reactions: {PIt2r}
# PHO91 is associated with reactions: {PIt2r}
# PHO84 is associated with reactions: {PIt2r}
# PIC2 is associated with reactions: {PIt5m}
# PLB1 is associated with reactions: {PLBP1I_SCe, PLBPC_SCe}
# PLB2 is associated with reactions: {PLBP1I_SCe, PLBPC_SCe}
# PLB3 is associated with reactions: {PLBP1I_SCe}
# NTE1 is associated with reactions: {PLBPC_SC}
# SPO14 is associated with reactions: {PLD_SC}
# SEC53 is associated with reactions: {PMANM}
# ERG8 is associated with reactions: {PMEVK}
# DDP1 is associated with reactions: {PMI1346PH, PMI12346PH}
# KCS1 is associated with reactions: {PMI1346PS, PMI12346PS}
# CAB1 is associated with reactions: {PNTK}
# FEN2 is associated with reactions: {PNTOt2}
# FMS1 is associated with reactions: {POLYAO3, POLYAO, POLYAO2}
# IPP1 is associated with reactions: {PPA}
# PPA2 is associated with reactions: {PPAm}
# HEM2 is associated with reactions: {PPBNGS}
# PCK1 is associated with reactions: {PPCK}
# TYR1 is associated with reactions: {PPND2}
# PHA2 is associated with reactions: {PPNDH}
# HEM14 is associated with reactions: {PPPGOm}
# COQ1 is associated with reactions: {PPTTm}
# ADE5,7 is associated with reactions: {PRAGSr, PRAIS}
# TRP1 is associated with reactions: {PRAIi}
# ADE1 is associated with reactions: {PRASCSi}
# ADE6 is associated with reactions: {PRFGS}
# HIS6 is associated with reactions: {PRMICI}
# PUT1 is associated with reactions: {PRO1xm}
#  is associated with reactions: {PROTRS}
# AIM10 is associated with reactions: {PROTRS}
# PRS3 is associated with reactions: {PRPPS}
# PRS4 is associated with reactions: {PRPPS}
# PRS2 is associated with reactions: {PRPPS}
# PRS5 is associated with reactions: {PRPPS}
# PRS1 is associated with reactions: {PRPPS}
# PSD2 is associated with reactions: {PSERDg_SC, PSERDv_SC}
# PSD1 is associated with reactions: {PSERDm_SC}
# CHO1 is associated with reactions: {PSERS_SC, PSERSm_SC}
# DPL1 is associated with reactions: {PSPHPL, SPHPL}
# SER2 is associated with reactions: {PSP_L}
# TES1 is associated with reactions: {PTE12x, PTE8x, PTE10x, PTE2x, PTE9x, PTE11x, PTE7x}
# TPO4 is associated with reactions: {PTRCt3i, SPMDt3i, SPRMt2i}
# TPO1 is associated with reactions: {PTRCt3i, SPMDt3i, SPRMt2i}
# TPO5 is associated with reactions: {SPMDtex2, PTRCtex2}
# CDC19 is associated with reactions: {PYK}
# PYK2 is associated with reactions: {PYK}
# FMN1 is associated with reactions: {RBFKm, RBFK}
# RIB4 is associated with reactions: {RBFSa}
# RIB5 is associated with reactions: {RBFSb}
# RNR2 is associated with reactions: {RNDR2, RNDR4, RNDR1, RNDR3}
# RNR1 is associated with reactions: {RNDR3n, RNDR1, RNDR4, RNDR4n, RNDR1n, RNDR2, RNDR2n, RNDR3}
# RNR3 is associated with reactions: {RNDR1n, RNDR1}
# RNR4 is associated with reactions: {RNDR4n, RNDR1n, RNDR3n, RNDR2n}
# NRK1 is associated with reactions: {RNMK}
# RPE1 is associated with reactions: {RPE}
# RKI1 is associated with reactions: {RPI}
# LYS9 is associated with reactions: {SACCD1}
# LYS1 is associated with reactions: {SACCD2}
# MET3 is associated with reactions: {SADT}
# ERG6 is associated with reactions: {SAM24MT}
# YSR3 is associated with reactions: {SBPP1er, SBPP2er}
# LCB3 is associated with reactions: {SBPP1er, SBPP2er}
# SOR1 is associated with reactions: {SBTD_L, SBTD_D2}
# SDL1 is associated with reactions: {SERD_L}
# CHA1 is associated with reactions: {THRD_L, SERD_L}
# LCB1 is associated with reactions: {SERPT}
# LCB2 is associated with reactions: {SERPT}
# SES1 is associated with reactions: {SERTRS}
# DIA4 is associated with reactions: {SERTRS}
#  is associated with reactions: {SFGTHi}
# MET8 is associated with reactions: {SHCHD, SHCHF}
#  is associated with reactions: {SHSL4r}
# LCB5 is associated with reactions: {SLCBK2, SLCBK1}
# LCB4 is associated with reactions: {SLCBK2, SLCBK1}
# SSU1 is associated with reactions: {SO3ti}
#  is associated with reactions: {SO4ti}
# SUL1 is associated with reactions: {SO4ti}
# SUL2 is associated with reactions: {SO4ti}
# SPE3 is associated with reactions: {SPMS}
# SPE4 is associated with reactions: {SPRMS}
# TPO2 is associated with reactions: {SPRMt2i}
# TPO3 is associated with reactions: {SPRMt2i}
# ERG1 is associated with reactions: {SQLErx, SQLEr}
# ERG9 is associated with reactions: {SQLS}
# UGA2 is associated with reactions: {SSALy}
# SHH3 is associated with reactions: {SUCD3_u6m, SUCD2_u6m, SUCD1m}
# SDH4 is associated with reactions: {SUCD3_u6m, SUCD2_u6m, SUCD1m}
# SDH2 is associated with reactions: {SUCD3_u6m, SUCD2_u6m, SUCD1m}
# SDH1 is associated with reactions: {SUCD3_u6m, SUCD2_u6m, SUCD1m}
# SDH3 is associated with reactions: {SUCD3_u6m, SUCD2_u6m, SUCD1m}
# SHH4 is associated with reactions: {SUCD3_u6m, SUCD2_u6m, SUCD1m}
#  is associated with reactions: {SUCD3_u6m, SUCD2_u6m, SUCD1m}
# SFC1 is associated with reactions: {SUCFUMtm}
# SUC2 is associated with reactions: {SUCRe}
# MET5 is associated with reactions: {SULR}
# MET10 is associated with reactions: {SULR}
# TGL2 is associated with reactions: {TAGL_SC}
# TGL3 is associated with reactions: {TAGL_SC}
# TAL1 is associated with reactions: {TALA}
# NQM1 is associated with reactions: {TALA}
# JLP1 is associated with reactions: {TAUDO}
# YBT1 is associated with reactions: {TCHOLAabcv}
# RMA1 is associated with reactions: {THFGLUS}
# MET7 is associated with reactions: {THFGLUS}
# FOL3 is associated with reactions: {THFGLUS}
# TSA2 is associated with reactions: {THIORDXi}
# TRX3 is associated with reactions: {TRDRm, THIORDXm}
# PRX1 is associated with reactions: {THIORDXm}
# DOT5 is associated with reactions: {THIORDXni}
# AHP1 is associated with reactions: {THIORDXp}
# PHO3 is associated with reactions: {THMDPe, THMPe}
# TPC1 is associated with reactions: {THMPPt2m}
# THI7 is associated with reactions: {THMt2}
# NRT1 is associated with reactions: {THMt2}
# THI72 is associated with reactions: {THMt2}
# GLY1 is associated with reactions: {THRA, THRA2}
# SRY1 is associated with reactions: {THRD_L}
# ILV1 is associated with reactions: {THRD_Lm}
# THS1 is associated with reactions: {THRTRS}
# MST1 is associated with reactions: {THRTRSm}
# TKL2 is associated with reactions: {TKT1, TKT2}
# TKL1 is associated with reactions: {TKT1, TKT2}
# THI80 is associated with reactions: {TMDPPK, TMDPK}
# CDC21 is associated with reactions: {TMDS}
# TPI1 is associated with reactions: {TPI}
# TRR1 is associated with reactions: {TRDR}
# TRR2 is associated with reactions: {TRDRm}
# TPS3 is associated with reactions: {TRE6PS, TRE6PP}
# TPS1 is associated with reactions: {TRE6PS, TRE6PP}
# TPS2 is associated with reactions: {TRE6PS, TRE6PP}
# TSL1 is associated with reactions: {TRE6PS, TRE6PP}
# NTH1 is associated with reactions: {TREH}
# NTH2 is associated with reactions: {TREH}
# ATH1 is associated with reactions: {TREHv}
# DGA1 is associated with reactions: {TRIGS_SC}
# BNA2 is associated with reactions: {TRPO2}
# TRP5 is associated with reactions: {TRPS1}
# WRS1 is associated with reactions: {TRPTRS}
# MSW1 is associated with reactions: {TRPTRSm}
# DIT1 is associated with reactions: {TYRNFT}
# TYS1 is associated with reactions: {TYRTRS}
# MSY1 is associated with reactions: {TYRTRSm}
# QRI1 is associated with reactions: {UDPACGLP}
# GAL10 is associated with reactions: {UDPG4E}
# HUT1 is associated with reactions: {UDPGALt2g}
# DAL3 is associated with reactions: {UGLYCH}
# URA6 is associated with reactions: {UMPK, URIDK2rn, UMPKn, URIDK2r}
# MET1 is associated with reactions: {UPP3MT}
# HEM4 is associated with reactions: {UPP3S}
# HEM12 is associated with reactions: {UPPDC1}
# FUR1 is associated with reactions: {UPPRT}
# FUR4 is associated with reactions: {URAt2}
# DUR3 is associated with reactions: {UREA2t2}
# FUI1 is associated with reactions: {URIt2}
# VAS1 is associated with reactions: {VALTRS, VALTRSm}
# XPT1 is associated with reactions: {XPPT}
# XKS1 is associated with reactions: {XYLK}
# XYL2 is associated with reactions: {XYLTD_D}
# DEG1 is associated with reactions: {YUMPS}
# PUS1 is associated with reactions: {YUMPS}
# PUS2 is associated with reactions: {YUMPS}
# PUS4 is associated with reactions: {YUMPS}
# FCY22 is associated with reactions: {GUAt2r, ADEt2, CSNt2}
# PMP2 is associated with reactions: {ATPS}
# PMP1 is associated with reactions: {ATPS}
# VMA10 is associated with reactions: {ATPS3g, ATPS3v}
# ATP18 is associated with reactions: {ATPS3m}
# ATP19 is associated with reactions: {ATPS3m}
# TIM11 is associated with reactions: {ATPS3m}
# QCR10 is associated with reactions: {CYOR_u6m}
# SOL2 is associated with reactions: {PGL}
# TSC3 is associated with reactions: {SERPT}
# phaA is associated with reactions: {ACACT1b}
# phaB is associated with reactions: {AACOARb}
# phaJ is associated with reactions: {HBCOAhydb}
# Ter is associated with reactions: {ACOAD1b}
# TesB is associated with reactions: {BCOAhydb}

# %%
print("Metabolites")
print("-----------")
for x in cerevisiae.metabolites:
    print('%9s : %s' % (x.id, x.formula))
# Out:
# Metabolites
# -----------
#  10fthf_c : C20H21N7O7
#  10fthf_m : C20H21N7O7
# 12dgr_SC_c : C3540H6644O500
# 13BDglcn_c : C6H10O5
# 13BDglcn_e : C6H10O5
# 13dampp_c : C3H12N2
#   13dpg_c : C3H4O10P2
#  14glun_c : C6H12O6
# 16BDglcn_c : C6H10O5
#  1Dgali_c : C12H22O11
# 1ag3p_SC_c : C1920H3622O700P100
# 1agly3p_SC_c : C1920H3422O700P100
# 1agpc_SC_c : C2420H4922N100O700P100
#  1mncam_c : C7H9N2O
#  1p3h5c_c : C5H6NO3
#  1p3h5c_m : C5H6NO3
#  1pyr5c_c : C5H6NO2
#  1pyr5c_m : C5H6NO2
#  23camp_c : C10H11N5O6P
#  23dhmb_m : C5H9O4
#  23dhmp_m : C6H11O4
#   23dpg_c : C3H3O10P2
#  25aics_c : C13H15N4O12P
#  25dhpp_c : C9H14N5O8P
# 25dthpp_c : C9H16N5O8P
#  2ahbut_m : C6H9O4
#  2ahhmd_m : C7H8N5O8P2
#  2ahhmp_m : C7H9N5O2
#   2amsa_c : C3H5NO3
#  2aobut_c : C4H7NO3
#  2cpr5p_c : C12H13NO9P
#  2dda7p_c : C7H10O10P
#  2dda7p_m : C7H10O10P
#   2dglc_c : C6H12O5
#    2dhp_c : C6H9O4
#    2dhp_m : C6H9O4
# 2doxg6p_c : C6H11O8P
#   2dr1p_c : C5H9O7P
#   2dr5p_c : C5H9O7P
#     2hb_c : C4H7O3
#     2hb_e : C4H7O3
# 2hhxdal_c : C16H32O2
# 2hp6mbq_m : C37H54O3
#  2hp6mp_m : C37H56O2
# 2hpmhmbq_m : C38H56O4
# 2hpmmbq_m : C38H56O3
#   2ippm_c : C7H8O4
#    2kmb_c : C5H7O3S
#  2mahmp_c : C6H8N3O7P2
#   2mbac_c : C7H14O2
#   2mbac_e : C7H14O2
#  2mbald_c : C5H10O
#  2mbald_e : C5H10O
#  2mbald_m : C5H10O
#  2mbtoh_c : C5H12O
#  2mbtoh_e : C5H12O
#  2mbtoh_m : C5H12O
#   2mcit_m : C7H7O7
#  2mppal_c : C4H8O
#  2mppal_e : C4H8O
#  2mppal_m : C4H8O
#   2obut_c : C4H5O3
#   2obut_m : C4H5O3
# 2oxoadp_c : C6H6O5
# 2oxoadp_m : C6H6O5
#     2pg_c : C3H4O7P
# 2phetoh_c : C8H10O
# 2phetoh_e : C8H10O
# 2phetoh_m : C8H10O
#   34hpl_m : C9H9O4
#   34hpp_c : C9H7O4
#   34hpp_m : C9H7O4
#   34hpp_x : C9H7O4
#  35ccmp_c : C9H11N3O7P
# 35cdamp_c : C10H11N5O5P
#  35cgmp_c : C10H11N5O7P
#  35cimp_c : C10H10N4O7P
#  3c2hmp_c : C7H10O5
#  3c3hmp_c : C7H10O5
#  3c3hmp_e : C7H10O5
#  3c3hmp_m : C7H10O5
#  3c4mop_c : C7H8O5
#  3c4mop_m : C7H8O5
# 3dh5hpb_c : C37H53O4
# 3dh5hpb_m : C37H53O4
#    3dhq_c : C7H9O6
#   3dhsk_c : C7H7O5
# 3dsphgn_c : C18H38NO2
# 3hanthrn_c : C7H7NO3
#  3hdcoa_x : C31H50N7O18P3S
# 3hddcoa_x : C33H54N7O18P3S
# 3hhdcoa_x : C37H62N7O18P3S
# 3hodcoa_x : C39H66N7O18P3S
# 3hph5mb_m : C38H55O4
# 3htdcoa_x : C35H58N7O18P3S
# 3hxccoa_x : C47H82N7O18P3S
#   3ig3p_c : C11H12NO6P
# 3ipmmest_c : C8H13O5
#  3mbald_c : C5H10O
#  3mbald_e : C5H10O
#  3mbald_m : C5H10O
#    3mob_c : C5H7O3
#    3mob_m : C5H7O3
#    3mop_c : C6H9O3
#    3mop_e : C6H9O3
#    3mop_m : C6H9O3
#  3odcoa_x : C31H48N7O18P3S
# 3oddcoa_x : C33H52N7O18P3S
# 3ohdcoa_x : C37H60N7O18P3S
# 3ohodcoa_x : C39H64N7O18P3S
# 3ohxccoa_x : C47H80N7O18P3S
# 3ophb_5_c : C37H53O3
# 3ophb_5_m : C37H53O3
# 3otdcoa_x : C35H56N7O18P3S
#     3pg_c : C3H4O7P
#    3php_c : C3H2O7P
#   3psme_c : C10H9O10P
#  44mctr_c : C29H46O
#  44mzym_c : C29H48O
# 4aabutn_c : C6H10NO3
#   4abut_c : C4H9NO2
#   4abut_e : C4H9NO2
#   4abut_m : C4H9NO2
#  4abutn_c : C4H10NO
#  4abutn_m : C4H10NO
#    4abz_c : C7H6NO2
#    4abz_e : C7H6NO2
#    4abz_m : C7H6NO2
#  4adcho_c : C10H10NO5
#  4ahmmp_c : C6H9N3O
#   4ampm_c : C6H8N3O4P
# 4fumacac_c : C8H6O6
#  4gudbd_c : C5H13N4O
# 4gudbutn_c : C5H11N3O2
# 4h2oglt_c : C5H4O6
# 4h2oglt_m : C5H4O6
# 4h2oglt_x : C5H4O6
#    4hbz_c : C7H5O3
#    4hbz_m : C7H5O3
# 4hbzcoa_m : C28H36N7O18P3S
# 4hglusa_m : C5H9NO4
# 4hpro_LT_c : C5H9NO3
# 4hpro_LT_m : C5H9NO3
#   4hthr_c : C4H9NO4
#  4mhetz_c : C6H9NOS
# 4mlacac_c : C8H6O6
#    4mop_c : C6H9O3
#    4mop_m : C6H9O3
#  4mpetz_c : C6H8NO4PS
#   4mzym_c : C28H46O
# 4mzym_int1_c : C29H46O3
# 4mzym_int2_c : C28H44O
#   4pasp_c : C4H6NO7P
#   4ppan_c : C9H15NO8P
#  4ppcys_c : C12H20N2O9PS
#   4r5au_c : C9H16N4O6
#   5aizc_c : C9H11N3O9P
#    5aop_c : C5H9NO3
#    5aop_e : C5H9NO3
#    5aop_m : C5H9NO3
#  5aprbu_c : C9H15N4O9P
#  5dpmev_c : C6H10O10P2
#   5fthf_c : C20H21N7O7
#   5fthf_m : C20H21N7O7
#  5mdr1p_c : C6H11O7PS
# 5mdru1p_c : C6H11O7PS
#    5mta_c : C11H15N5O3S
#   5mthf_c : C20H24N7O6
#   5pmev_c : C6H10O7P
#     6dg_c : C12H22O11
#    6pgc_c : C6H10O10P
#    6pgl_c : C6H9O9P
#    6pgl_r : C6H9O9P
#   8aonn_c : C9H17NO3
#   8aonn_e : C9H17NO3
#     ACP_c : C11H21N2O7PRS
#     ACP_m : C11H21N2O7PRS
# Dara14lac_c : C5H8O5
# L2aadp6sa_c : C6H11NO3
#  L2aadp_c : C6H10NO4
# cysi__L_c : C6H12N2O4S2
# cysi__L_v : C6H12N2O4S2
# Lfmkynr_c : C11H12N2O4
#   Lkynr_c : C10H12N2O3
# N1aspmd_c : C9H23N3O
#  N1sprm_c : C12H31N4O
# NPmehis_c : C7H11N3O2
# Nbfortyr_c : C20H22N2O8
# Nbfortyr_e : C20H22N2O8
# Nfortyr_c : C10H10NO4
# Sfglutth_c : C11H16N3O7S
# Ssq23epx_c : C30H50O
# Ssq23epx_r : C30H50O
# T4hcinnm_m : C9H7O3
#  aacald_c : C2H6NO
#   aacoa_c : C25H36N7O18P3S
#   aacoa_m : C25H36N7O18P3S
#    aact_c : C3H8NO
#     abt_c : C5H12O5
#     abt_e : C5H12O5
#   acACP_c : C13H23N2O8PRS
#   acACP_m : C13H23N2O8PRS
#      ac_c : C2H3O2
#      ac_e : C2H3O2
#      ac_m : C2H3O2
#      ac_x : C2H3O2
#    acac_c : C4H5O3
#   acald_c : C2H4O
#   acald_e : C2H4O
#   acald_m : C2H4O
#   accoa_c : C23H34N7O17P3S
#   accoa_m : C23H34N7O17P3S
#   accoa_n : C23H34N7O17P3S
#   accoa_x : C23H34N7O17P3S
#    aces_c : C4H8O2
#    aces_e : C4H8O2
#   acg5p_m : C7H9NO8P
#  acg5sa_m : C7H10NO4
# acgam1p_c : C8H14NO9P
# acgam6p_c : C8H14NO9P
#   acglu_m : C7H9NO5
#   achms_c : C6H11NO4
#  acon5m_c : C7H6O6
#  acon_T_c : C6H3O6
#   acorn_m : C7H14N2O3
#    acrn_c : C9H17NO4
#    acrn_m : C9H17NO4
#    acrn_x : C9H17NO4
#   acser_c : C5H9NO4
# actn__R_c : C4H8O2
#  acybut_c : C5H8N2O2
#     ade_c : C5H5N5
#     ade_e : C5H5N5
#     ade_m : C5H5N5
#     adn_c : C10H13N5O4
#     adn_e : C10H13N5O4
#     adn_m : C10H13N5O4
#     adp_c : C10H12N5O10P2
#     adp_g : C10H12N5O10P2
#     adp_m : C10H12N5O10P2
#     adp_n : C10H12N5O10P2
#     adp_v : C10H12N5O10P2
#     adp_x : C10H12N5O10P2
#  adprib_c : C15H21N5O14P2
#  adprib_m : C15H21N5O14P2
#   ahcys_c : C14H20N6O5S
#   ahcys_m : C14H20N6O5S
#    ahdt_c : C9H12N5O13P3
#   aicar_c : C9H13N4O8P
#     air_c : C8H12N3O7P
#     akg_c : C5H4O5
#     akg_e : C5H4O5
#     akg_m : C5H4O5
#     akg_n : C5H4O5
#     akg_x : C5H4O5
#   ala_B_c : C3H7NO2
#  ala__L_c : C3H7NO2
#  ala__L_e : C3H7NO2
#  ala__L_m : C3H7NO2
# alac__S_m : C5H7O4
# alatrna_c : C3H6NOR
#  allphn_c : C2H3N2O3
#   alltn_c : C4H6N4O3
#   alltn_e : C4H6N4O3
#   alltt_c : C4H7N4O4
#   alltt_e : C4H7N4O4
#   alpam_m : C9H21N2OS2
#   alpro_m : CH6NS2X
#    amet_c : C15H23N6O5S
#    amet_e : C15H23N6O5S
#    amet_m : C15H23N6O5S
#  ametam_c : C14H24N6O3S
#    amob_c : C15H19N5O6S
#   amp2p_c : C10H14N5O7P
#     amp_c : C10H12N5O7P
#     amp_m : C10H12N5O7P
#     amp_n : C10H12N5O7P
#     amp_x : C10H12N5O7P
#    anth_c : C7H6NO2
#    ap4a_c : C20H24N10O19P4
#    ap4g_c : C20H24N10O20P4
#    apep_c : C6H7N2O4R2
#   aproa_c : C3H8NO
#   aprop_c : C3H7N2
#   aprut_c : C6H15N2O
#     aps_c : C10H12N5O10PS
# arab__D_c : C5H10O5
# arab__D_e : C5H10O5
# arab__L_c : C5H10O5
# arab__L_e : C5H10O5
#  arg__L_c : C6H15N4O2
#  arg__L_e : C6H15N4O2
#  arg__L_m : C6H15N4O2
#  arg__L_v : C6H15N4O2
#  argsuc_c : C10H17N4O6
# argtrna_c : C6H14N4OR
# argtrna_m : C6H14N4OR
#  asn__L_c : C4H8N2O3
#  asn__L_e : C4H8N2O3
#  asn__L_m : C4H8N2O3
#  asn__L_v : C4H8N2O3
# asntrna_c : C14H23N2O12PR2
# asntrna_m : C14H23N2O12PR2
#  asp__L_c : C4H6NO4
#  asp__L_e : C4H6NO4
#  asp__L_m : C4H6NO4
#  asp__L_n : C4H6NO4
#  asp__L_v : C4H6NO4
#  asp__L_x : C4H6NO4
#   aspsa_c : C4H7NO3
# asptrna_c : C4H5NO3R
# asptrna_m : C4H5NO3R
# athr__L_c : C4H9NO3
#     atp_c : C10H12N5O13P3
#     atp_g : C10H12N5O13P3
#     atp_m : C10H12N5O13P3
#     atp_n : C10H12N5O13P3
#     atp_v : C10H12N5O13P3
#     atp_x : C10H12N5O13P3
#  b124tc_m : C7H5O6
#   btamp_c : C20H27N7O9PS
#  btd_RR_c : C4H10O2
#  btd_RR_e : C4H10O2
#     btn_c : C10H15N2O3S
#     btn_e : C10H15N2O3S
#    camp_c : C10H11N5O6P
#  caphis_c : C10H16N4O4
#   cbasp_c : C5H6N2O5
#   cbasp_n : C5H6N2O5
#     cbp_c : CH2NO5P
#     cbp_n : CH2NO5P
#     cdp_c : C9H12N3O11P2
#     cdp_n : C9H12N3O11P2
# cdpchol_c : C14H25N4O11P2
# cdpdag_SC_c : C4440H7744N300O1500P200
# cdpdag_SC_m : C4440H7744N300O1500P200
#   cdpea_c : C11H19N4O11P2
# cer1_24_c : C42H85NO3
# cer1_24_r : C42H85NO3
# cer1_26_c : C44H89NO3
# cer1_26_r : C44H89NO3
# cer2_24_c : C42H85NO4
# cer2_24_r : C42H85NO4
# cer2_26_c : C44H89NO4
# cer2_26_r : C44H89NO4
# cer3_24_c : C42H85NO5
# cer3_26_c : C44H89NO5
#    cgly_c : C5H10N2O3S
#    ch4s_c : CH4S
#  chitin_c : C8H13NO5
#  chitos_c : C6H11NO4
#    chol_c : C5H14NO
#    chol_e : C5H14NO
#   cholp_c : C5H13NO4P
#    chor_c : C10H8O6
#     cit_c : C6H5O7
#     cit_e : C6H5O7
#     cit_m : C6H5O7
#     cit_x : C6H5O7
# citr__L_c : C6H13N3O3
# clpn_SC_m : C7380H13688O1700P200
# cmaphis_c : C11H18N4O4
#     cmp_c : C9H12N3O8P
#     cmp_m : C9H12N3O8P
#   cmusa_c : C7H6NO5
#     co2_c : CO2
#     co2_e : CO2
#     co2_g : CO2
#     co2_m : CO2
#     co2_n : CO2
#     co2_v : CO2
#     co2_x : CO2
#     coa_c : C21H32N7O16P3S
#     coa_m : C21H32N7O16P3S
#     coa_n : C21H32N7O16P3S
#     coa_r : C21H32N7O16P3S
#     coa_x : C21H32N7O16P3S
#  coucoa_m : C30H38N7O18P3S1
#  cpppg3_c : C36H40N4O8
#     crn_c : C7H15NO3
#     crn_e : C7H15NO3
#     crn_m : C7H15NO3
#     crn_x : C7H15NO3
#     csn_c : C4H5N3O
#     csn_e : C4H5N3O
#     ctp_c : C9H12N3O14P3
#     ctp_m : C9H12N3O14P3
#  cys__L_c : C3H7NO2S
#  cys__L_e : C3H7NO2S
# cyst__L_c : C7H14N2O4S
# cyst__L_x : C7H14N2O4S
# cystrna_c : C3H6NOSR
#    cytd_c : C9H13N3O5
#    cytd_e : C9H13N3O5
#   dad_2_c : C10H13N5O3
#   dad_2_e : C10H13N5O3
#    dadp_c : C10H12N5O9P2
#    dadp_n : C10H12N5O9P2
# dagpy_SC_c : C3540H6544O1100P200
#    damp_c : C10H12N5O6P
#    dann_c : C9H21N2O2
#    dann_e : C9H21N2O2
#    datp_c : C10H12N5O12P3
#    db4p_c : C4H7O6P
#  dc2coa_x : C31H48N7O17P3S
#  dcaACP_m : C21H39N2O8PRS
#     dca_c : C10H19O2
#     dca_e : C10H19O2
#     dca_x : C10H19O2
#  dcacoa_c : C31H50N7O17P3S
#  dcacoa_x : C31H50N7O17P3S
#   dcamp_c : C14H14N5O11P
#    dcdp_c : C9H12N3O10P2
#    dcdp_n : C9H12N3O10P2
#    dcmp_c : C9H12N3O7P
#    dctp_c : C9H12N3O13P3
#    dcyt_c : C9H13N3O4
#    dcyt_e : C9H13N3O4
#  dd2coa_x : C33H52N7O17P3S
# ddcaACP_c : C23H43N2O8PRS
# ddcaACP_m : C23H43N2O8PRS
#    ddca_c : C12H23O2
#    ddca_e : C12H23O2
#    ddca_x : C12H23O2
# ddcacoa_c : C33H54N7O17P3S
# ddcacoa_x : C33H54N7O17P3S
#    dgdp_c : C10H12N5O10P2
#    dgdp_n : C10H12N5O10P2
#    dgmp_c : C10H12N5O7P
#    dgsn_c : C10H13N5O4
#    dgsn_e : C10H13N5O4
#    dgtp_c : C10H12N5O13P3
#     dha_c : C3H6O3
#    dhap_c : C3H5O6P
#    dhap_m : C3H5O6P
#     dhf_c : C19H19N7O6
#     dhf_m : C19H19N7O6
#   dhlam_m : C8H17NOS2
#  dhlpro_m : H2S2X
#   dhnpt_c : C9H13N5O4
#   dhnpt_m : C9H13N5O4
# dhor__S_c : C5H5N2O4
#   dhpmp_c : C9H12N5O7P
#    dhpt_c : C14H13N6O3
#    dhpt_m : C14H13N6O3
#     din_c : C10H12N4O4
#     din_e : C10H12N4O4
#   dkmpp_c : C6H9O6PS
#    dmlz_c : C13H18N4O6
#    dmpp_c : C5H9O7P2
#    dnad_c : C21H24N6O15P2
#    dnad_m : C21H24N6O15P2
#    dnad_n : C21H24N6O15P2
# dolichol_c : C15H28O
# dolmanp_r : C21H38O9P
#    dolp_c : C15H27O4P
#    dolp_r : C15H27O4P
#   dpcoa_c : C21H33N7O13P2S
#   dpcoa_m : C21H33N7O13P2S
#    drib_c : C5H10O4
#    dscl_c : C42H41N4O16
#    dtbt_c : C10H17N2O3
#    dtdp_c : C10H13N2O11P2
#    dtmp_c : C10H13N2O8P
#    dttp_c : C10H13N2O14P3
#    dttp_e : C10H13N2O14P3
#    dudp_c : C9H11N2O11P2
#    dudp_n : C9H11N2O11P2
#    dump_c : C9H11N2O8P
#    dump_n : C9H11N2O8P
#    duri_c : C9H12N2O5
#    duri_e : C9H12N2O5
#    dutp_c : C9H11N2O14P3
#  e4hglu_c : C5H8NO5
#  e4hglu_m : C5H8NO5
#  e4hglu_x : C5H8NO5
#     e4p_c : C4H7O7P
#     e4p_m : C4H7O7P
#   eig3p_c : C6H9N2O6P
#   epist_c : C28H46O
#   epist_e : C28H46O
# epistest_SC_c : C1695H2995O101
# epistest_SC_e : C1695H2995O101
#     epm_c : C12H22O11
# ergst3glc_c : C34H54O6
#   ergst_c : C28H44O
#   ergst_e : C28H44O
#   ergst_r : C28H44O
# ergstest_SC_c : C1695H2993O101
# ergstest_SC_e : C1695H2993O101
# ergtetrol_c : C28H42O
# ergtetrol_r : C28H42O
# ergtrol_c : C28H44O
# ertascb__D_c : C5H6O5
#    etha_c : C2H8NO
#    etha_e : C2H8NO
#  ethamp_c : C2H7NO4P
#    etoh_c : C2H6O
#    etoh_e : C2H6O
#    etoh_m : C2H6O
#     f1p_c : C6H11O9P
#   f26bp_c : C6H10O12P2
#     f6p_c : C6H11O9P
#     fad_c : C27H31N9O15P2
#     fad_m : C27H31N9O15P2
#   fadh2_m : C27H33N9O15P2
#    fald_c : CH2O
#     fdp_c : C6H10O12P2
#     fe2_c : None
#     fe2_e : None
#     fe2_m : None
#  fecost_c : C28H46O
#  fecost_e : C28H46O
# fecostest_SC_c : C1695H2995O101
# fecostest_SC_e : C1695H2995O101
#    fgam_c : C8H13N2O9P
#  ficytc_m : None
# fmettrna_m : C6H9NO2SR
#     fmn_c : C17H19N4O9P
#     fmn_e : C17H19N4O9P
#     fmn_m : C17H19N4O9P
#   fmnh2_c : C17H21N4O9P
#  focytc_m : None
#     for_c : CH1O2
#     for_e : CH1O2
#     for_m : CH1O2
#   fpram_c : C8H15N3O8P
#  fprica_c : C10H13N4O9P
#    frdp_c : C15H25O7P2
#    frdp_m : C15H25O7P2
#     fru_c : C6H12O6
#     fru_e : C6H12O6
#     fum_c : C4H2O4
#     fum_e : C4H2O4
#     fum_m : C4H2O4
#     g1p_c : C6H11O9P
#     g3p_c : C3H5O6P
#    g3pc_c : C8H20NO6P
#    g3pc_e : C8H20NO6P
#    g3pi_c : C9H18O11P
#    g3pi_e : C9H18O11P
#   g6p_B_c : C6H11O9P
#     g6p_c : C6H11O9P
#     g6p_r : C6H11O9P
#   gal1p_c : C6H11O9P
#     gal_c : C6H12O6
#     gal_e : C6H12O6
#   galur_e : C6H9O7
#   gam1p_c : C6H13NO8P
#   gam6p_c : C6H13NO8P
#   gam6p_e : C6H13NO8P
#     gar_c : C7H14N2O8P
#   gcald_c : C2H4O2
#   gcald_e : C2H4O2
#   gcald_m : C2H4O2
#     gdp_c : C10H12N5O11P2
#     gdp_g : C10H12N5O11P2
#     gdp_m : C10H12N5O11P2
#     gdp_n : C10H12N5O11P2
# gdpmann_c : C16H23N5O16P2
# gdpmann_g : C16H23N5O16P2
#    ggdp_c : C20H33O7P2
#     ggl_c : C9H18O8
#  glc__D_c : C6H12O6
#  glc__D_e : C6H12O6
#  glc__D_v : C6H12O6
#  gln__L_c : C5H10N2O3
#  gln__L_e : C5H10N2O3
#  gln__L_n : C5H10N2O3
#  gln__L_v : C5H10N2O3
# glntrna_c : C5H9N2O2R
#     glp_c : C4H7N2O3R
#   glu5p_c : C5H8NO7P
#  glu5sa_c : C5H9NO3
#  glu5sa_m : C5H9NO3
#  glu__L_c : C5H8NO4
#  glu__L_e : C5H8NO4
#  glu__L_m : C5H8NO4
#  glu__L_n : C5H8NO4
#  glu__L_v : C5H8NO4
#  glu__L_x : C5H8NO4
#  gluala_c : C8H13N2O5
#  glucys_c : C8H13N2O5S
# glutrna_c : C5H7NO3R
# glutrna_m : C5H7NO3R
#     glx_c : C2H1O3
#     glx_e : C2H1O3
#     glx_x : C2H1O3
#     gly_c : C2H5NO2
#     gly_e : C2H5NO2
#     gly_m : C2H5NO2
#  glyald_c : C3H6O3
#  glyc3p_c : C3H7O6P
#  glyc3p_m : C3H7O6P
#    glyc_c : C3H8O3
#    glyc_e : C3H8O3
# glycogen_c : C6H10O5
# glycogen_v : C6H10O5
# glytrna_c : C2H4NOR
#     gmp_c : C10H12N5O8P
#     gmp_g : C10H12N5O8P
#    gp4g_c : C20H24N10O21P4
#    grdp_c : C10H17O7P2
#     gsn_c : C10H13N5O5
#     gsn_e : C10H13N5O5
#     gsn_m : C10H13N5O5
#   gthox_c : C20H30N6O12S2
#   gthox_e : C20H30N6O12S2
#   gthox_m : C20H30N6O12S2
#   gthrd_c : C10H16N3O6S
#   gthrd_e : C10H16N3O6S
#   gthrd_m : C10H16N3O6S
#   gthrd_v : C10H16N3O6S
#     gtp_c : C10H12N5O14P3
#     gtp_m : C10H12N5O14P3
#     gua_c : C5H5N5O
#     gua_e : C5H5N5O
#     gua_m : C5H5N5O
#    h2o2_c : H2O2
#    h2o2_m : H2O2
#    h2o2_n : H2O2
#    h2o2_x : H2O2
#     h2o_c : H2O
#     h2o_e : H2O
#     h2o_g : H2O
#     h2o_m : H2O
#     h2o_n : H2O
#     h2o_r : H2O
#     h2o_v : H2O
#     h2o_x : H2O
#     h2s_c : H2S
#  hLkynr_c : C10H12N2O4
#       h_c : H
#       h_e : H
#       h_g : H
#       h_m : H
#       h_n : H
#       h_r : H
#       h_v : H
#       h_x : H
#    hcit_m : C7H7O7
#    hcit_n : C7H7O7
#    hco3_c : CHO3
#    hco3_m : CHO3
#    hco3_n : CHO3
# hcys__L_c : C4H9NO2S
# hcys__L_x : C4H9NO2S
#    hdca_c : C16H31O2
#    hdca_e : C16H31O2
#    hdca_x : C16H31O2
#   hdcea_c : C16H29O2
#   hdcea_e : C16H29O2
#   hdcea_x : C16H29O2
#   hdcoa_c : C37H60N7O17P3S
#   hdcoa_x : C37H60N7O17P3S
# hdd2coa_x : C37H60N7O17P3S
#  hdeACP_c : C27H49N2O8PRS
#  hdeACP_m : C27H49N2O8PRS
#   hemeA_m : None
#   hemeO_m : None
#    hexc_c : C26H51O2
#    hexc_e : C26H51O2
#    hexc_x : C26H51O2
# hexccoa_c : C47H82N7O17P3S
# hexccoa_r : C47H82N7O17P3S
# hexccoa_x : C47H82N7O17P3S
#   hexdp_c : C30H49O7P2
#   hexdp_m : C30H49O7P2
# hgentis_c : C8H7O4
#   hicit_m : C7H7O7
#  his__L_c : C6H9N3O2
#  his__L_e : C6H9N3O2
#  his__L_m : C6H9N3O2
#  his__L_v : C6H9N3O2
#    hisp_c : C6H11N3O4P
#   histd_c : C6H12N3O
# histrna_c : C6H8N3OR
# histrna_m : C6H8N3OR
#   hmbil_c : C40H38N4O17
#  hmgcoa_c : C27H39N7O20P3S
#  hmgcoa_m : C27H39N7O20P3S
#  hom__L_c : C4H9NO3
#   hpglu_c : C24H34N8O12
#    hxan_c : C5H4N4O
#    hxan_e : C5H4N4O
# hxc2coa_x : C47H80N7O17P3S
#  hxdcal_c : C16H32O
#     iad_c : C10H10N2O
#   iamac_c : C7H14O2
#   iamac_e : C7H14O2
#   iamoh_c : C5H12O
#   iamoh_e : C5H12O
#   iamoh_m : C5H12O
#    iasp_c : C4H3NO4
#  ibutac_c : C6H12O2
#  ibutac_e : C6H12O2
#  ibutoh_c : C4H10O
#  ibutoh_e : C4H10O
#  ibutoh_m : C4H10O
#    icit_c : C6H5O7
#    icit_m : C6H5O7
#    icit_x : C6H5O7
# id3acald_c : C10H9NO
# id3acald_e : C10H9NO
# id3acald_m : C10H9NO
#     idp_c : C10H11N4O11P2
#     idp_m : C10H11N4O11P2
#  ile__L_c : C6H13NO2
#  ile__L_e : C6H13NO2
#  ile__L_m : C6H13NO2
#  ile__L_v : C6H13NO2
# iletrna_c : C6H12NOR
# iletrna_m : C6H12NOR
#   imacp_c : C6H7N2O5P
#     imp_c : C10H11N4O8P
#  ind3ac_c : C10H8NO2
#  ind3ac_m : C10H8NO2
# ind3acnl_c : C10H8N2
# ind3eth_c : C10H11NO
# ind3eth_e : C10H11NO
# ind3eth_m : C10H11NO
#  indpyr_c : C11H8NO3
#   inost_c : C6H12O6
#   inost_e : C6H12O6
#     ins_c : C10H12N4O5
#     ins_e : C10H12N4O5
# ipc124_SC_c : C4800H9500N100O1100P100
# ipc126_SC_c : C5000H9900N100O1100P100
# ipc224_SC_c : C4800H9500N100O1200P100
# ipc226_SC_c : C5000H9900N100O1200P100
# ipc324_SC_c : C4800H9500N100O1300P100
# ipc326_SC_c : C5000H9900N100O1300P100
#    ipdp_c : C5H9O7P2
#    ipdp_m : C5H9O7P2
# itaccoa_m : C26H35N7O19P3S
#  itacon_m : C5H4O4
#     itp_c : C10H11N4O14P3
#     itp_m : C10H11N4O14P3
#       k_c : K
#       k_e : K
#  lac__D_c : C3H5O3
#  lac__D_e : C3H5O3
#  lac__D_m : C3H5O3
#  lac__L_c : C3H5O3
#  lac__L_e : C3H5O3
#  lac__L_m : C3H5O3
# lald__L_c : C3H6O2
#  lanost_c : C30H50O
#  lanost_e : C30H50O
# lanostest_SC_c : C1697H2999O101
# lanostest_SC_e : C1697H2999O101
#  leu__L_c : C6H13NO2
#  leu__L_e : C6H13NO2
#  leu__L_m : C6H13NO2
#  leu__L_v : C6H13NO2
# leutrna_c : C6H12NOR
# leutrna_m : C6H12NOR
#  lgt__S_c : C13H20N3O8S
#  lgt__S_m : C13H20N3O8S
#    lpam_m : C8H15NOS2
#    lpro_m : S2X
#  lys__L_c : C6H15N2O2
#  lys__L_e : C6H15N2O2
#  lys__L_m : C6H15N2O2
#  lys__L_v : C6H15N2O2
# lystrna_c : C6H14N2OR
# lystrna_m : C6H14N2OR
# m1macchitppdol_g : C43H74N2O27P2
# m2macchitppdol_g : C49H84N2O32P2
# m3macchitppdol_g : C55H94N2O37P2
# m4macchitppdol_g : C61H104N2O42P2
# macchitppdol_g : C37H64N2O22P2
#  malACP_c : C14H22N2O10PRS
#  malACP_m : C14H22N2O10PRS
#  mal__L_c : C4H4O5
#  mal__L_e : C4H4O5
#  mal__L_m : C4H4O5
#  mal__L_x : C4H4O5
#  malcoa_c : C24H33N7O19P3S
#  malcoa_m : C24H33N7O19P3S
#    malt_c : C12H22O11
#    malt_e : C12H22O11
#   man1p_c : C6H11O9P
# man2mi1p__D_c : C18H31O22P2
#   man6p_c : C6H11O9P
#     man_c : C6H12O6
#     man_e : C6H12O6
# manmi1p__D_c : C12H21O14P1
#  mannan_c : C6H10O5
#  mannan_r : C6H10O5
#   melib_c : C12H22O11
#   melib_e : C12H22O11
#    melt_c : C12H24O11
#  met__L_c : C5H11NO2S
#  met__L_e : C5H11NO2S
#  met__L_m : C5H11NO2S
#   methf_c : C20H20N7O6
#   methf_m : C20H20N7O6
# mettrna_c : C5H10NOSR
# mettrna_m : C5H10NOSR
#  mev__R_c : C6H11O4
#  mhpglu_c : C25H36N8O12
# mi13456p_c : C6H7O21P5
# mi13456p_n : C6H7O21P5
# mi1345p_n : C6H8O18P4
# mi1456p_n : C6H8O18P4
#  mi145p_c : C6H9O15P3
#  mi145p_n : C6H9O15P3
# mi1p__D_c : C6H11O9P
#   micit_m : C7H7O7
#  minohp_c : C6H6O24P6
#  minohp_n : C6H6O24P6
# mip2c124_SC_c : C6000H11500N100O2400P200
# mip2c126_SC_c : C6200H11900N100O2400P200
# mip2c224_SC_c : C6000H11500N100O2500P200
# mip2c226_SC_c : C6200H11900N100O2500P200
# mip2c324_SC_c : C6000H11500N100O2600P200
# mip2c326_SC_c : C6200H11900N100O2600P200
# mipc124_SC_c : C5400H10500N100O1600P100
# mipc126_SC_c : C5600H10900N100O1600P100
# mipc224_SC_c : C5400H10500N100O1700P100
# mipc226_SC_c : C5600H10900N100O1700P100
# mipc324_SC_c : C5400H10500N100O1800P100
# mipc326_SC_c : C5600H10900N100O1800P100
#   mlthf_c : C20H21N7O6
#   mlthf_m : C20H21N7O6
#    mmet_c : C6H14NO2S
#    mmet_e : C6H14NO2S
#  mthgxl_c : C3H4O2
# myrsACP_c : C25H47N2O8PRS
# myrsACP_m : C25H47N2O8PRS
# n4abutn_c : C6H11NO2
#     na1_c : None
#     na1_e : None
#     nac_c : C6H4NO2
#     nac_e : C6H4NO2
#     nac_m : C6H4NO2
#     nad_c : C21H26N7O14P2
#     nad_m : C21H26N7O14P2
#     nad_n : C21H26N7O14P2
#     nad_r : C21H26N7O14P2
#     nad_x : C21H26N7O14P2
#    nadh_c : C21H27N7O14P2
#    nadh_m : C21H27N7O14P2
#    nadh_r : C21H27N7O14P2
#    nadh_x : C21H27N7O14P2
#    nadp_c : C21H25N7O17P3
#    nadp_e : C21H25N7O17P3
#    nadp_m : C21H25N7O17P3
#    nadp_r : C21H25N7O17P3
#    nadp_x : C21H25N7O17P3
#   nadph_c : C21H26N7O17P3
#   nadph_m : C21H26N7O17P3
#   nadph_r : C21H26N7O17P3
#   nadph_x : C21H26N7O17P3
#    ncam_c : C6H6N2O
#    ncam_m : C6H6N2O
#     nh4_c : H4N
#     nh4_e : H4N
#     nh4_m : H4N
#     nh4_n : H4N
#     nh4_x : H4N
#  nicrnt_c : C11H12NO9P
#  nicrnt_m : C11H12NO9P
#     nmn_c : C11H14N2O8P
#     nmn_e : C11H14N2O8P
#     nmn_m : C11H14N2O8P
#     nmn_x : C11H14N2O8P
#      o2_c : O2
#      o2_e : O2
#      o2_m : O2
#      o2_r : O2
#      o2_x : O2
#     oaa_c : C4H2O5
#     oaa_e : C4H2O5
#     oaa_m : C4H2O5
#     oaa_x : C4H2O5
#   ocACP_m : C19H35N2O8PRS
#   occoa_c : C29H46N7O17P3S
#   occoa_x : C29H46N7O17P3S
# ocdcaACP_c : C29H55N2O8PRS
# ocdcaACP_m : C29H55N2O8PRS
#   ocdca_c : C18H35O2
#   ocdca_e : C18H35O2
#   ocdca_x : C18H35O2
#  ocdcea_c : C18H33O2
#  ocdcea_e : C18H33O2
# ocdcyaACP_c : C29H51N2O8PRS
# ocdcyaACP_m : C29H51N2O8PRS
#  ocdcya_c : C18H31O2
#  ocdcya_e : C18H31O2
# ocdycacoa_c : C39H62N7O17P3S
# ocdycacoa_x : C39H62N7O17P3S
#    octa_c : C8H15O2
#    octa_x : C8H15O2
# octeACP_c : C29H53N2O8PRS
# octeACP_m : C29H53N2O8PRS
#  od2coa_x : C39H64N7O17P3S
#  odecoa_c : C39H64N7O17P3S
#  odecoa_x : C39H64N7O17P3S
#     oh1_c : HO
#     oh1_m : HO
#    ohpb_c : C4H4O8P
#     orn_c : C5H13N2O2
#     orn_e : C5H13N2O2
#     orn_m : C5H13N2O2
#  orot5p_c : C10H10N2O11P
#    orot_c : C5H3N2O4
#    oxag_c : C7H5O7
#    oxag_m : C7H5O7
#   pa_SC_c : C3540H6544O800P100
#   pa_SC_m : C3540H6544O800P100
#     pac_c : C8H7O2
#  pacald_c : C8H8O
#  pacald_e : C8H8O
#  pacald_m : C8H8O
#     pad_c : C8H9NO
# palmACP_c : C27H51N2O8PRS
# palmACP_m : C27H51N2O8PRS
#   pan4p_c : C11H21N2O7PS
#   pan4p_m : C11H21N2O7PS
#   pan4p_x : C11H21N2O7PS
# pant__R_c : C6H11O4
# pant__R_m : C6H11O4
#     pap_c : C10H11N5O10P2
#     pap_e : C10H11N5O10P2
#     pap_m : C10H11N5O10P2
#     pap_x : C10H11N5O10P2
#    paps_c : C10H11N5O13P2S
#   pc_SC_c : C4040H7844N100O800P100
#   pc_SC_e : C4040H7844N100O800P100
#   pdx5p_c : C8H10NO6P
#   pe_SC_c : C3740H7244N100O800P100
#   pe_SC_g : C3740H7244N100O800P100
#   pe_SC_m : C3740H7244N100O800P100
#   pe_SC_v : C3740H7244N100O800P100
#  pectin_e : C6H7O6
#   pendp_c : C25H41O7P2
#   pendp_m : C25H41O7P2
#     pep_c : C3H2O6P
#     pep_m : C3H2O6P
#    pepd_c : C2H4NO2RC2H2NOR
#    pepd_e : C2H4NO2RC2H2NOR
#   pg_SC_m : C3840H7244O1000P100
#  pgp_SC_m : C3840H7144O1300P200
#  phe__L_c : C9H11NO2
#  phe__L_e : C9H11NO2
#  phe__L_m : C9H11NO2
#   pheac_c : C10H12O2
#   pheac_e : C10H12O2
#   pheme_m : None
# phetrna_c : C9H10NOR
# phetrna_m : C9H10NOR
#    phom_c : C4H8NO6P
#   phpyr_c : C9H7O3
#   phthr_c : C4H8NO7P
#      pi_c : HO4P
#      pi_e : HO4P
#      pi_g : HO4P
#      pi_m : HO4P
#      pi_n : HO4P
#      pi_r : HO4P
#      pi_v : HO4P
#      pi_x : HO4P
#  pmtcoa_c : C37H62N7O17P3S
#  pmtcoa_x : C37H62N7O17P3S
# pnto__R_c : C9H16NO5
# pnto__R_e : C9H16NO5
#   ppbng_c : C10H13N2O4
#   ppcoa_m : C24H36N7O17P3S
#    pphn_c : C10H8O6
#     ppi_c : HO7P2
#     ppi_m : HO7P2
#     ppi_n : HO7P2
#     ppi_x : HO7P2
# ppmi12346p_c : C6H6O27P7
# ppmi1346p_c : C6H7O24P6
#    ppp9_m : C34H32N4O4
#   pppg9_c : C34H38N4O4
#   pppg9_m : C34H38N4O4
#    pram_c : C5H11NO7P
#    pran_c : C12H13NO9P
#  prbamp_c : C15H19N5O14P2
#  prbatp_c : C15H19N5O20P4
#    prfp_c : C15H21N5O15P2
#    prlp_c : C15H21N5O15P2
#  pro__L_c : C5H9NO2
#  pro__L_e : C5H9NO2
#  pro__L_m : C5H9NO2
# protrna_c : C5H8NOR
#    prpp_c : C5H8O14P3
#    prpp_m : C5H8O14P3
#   ps_SC_c : C3840H7144N100O1000P100
#   ps_SC_g : C3840H7144N100O1000P100
#   ps_SC_m : C3840H7144N100O1000P100
#   ps_SC_v : C3840H7144N100O1000P100
#   psd5p_c : C9H11N2O9P
# pser__L_c : C3H6NO6P
#  psph1p_c : C18H39NO6P
#  psph1p_r : C18H39NO6P
# psphings_c : C18H40NO3
# psphings_r : C18H40NO3
# ptd134bp_SC_c : C4140H7444O1900P300
# ptd135bp_SC_c : C4140H7444O1900P300
# ptd145bp_SC_c : C4140H7444O1900P300
# ptd1ino_SC_c : C4140H7644O1300P100
# ptd1ino_SC_e : C4140H7644O1300P100
# ptd1ino_SC_n : C4140H7644O1300P100
# ptd2meeta_SC_c : C3940H7644N100O800P100
# ptd3ino_SC_c : C4140H7544O1600P200
# ptd4ino_SC_c : C4140H7544O1600P200
# ptd4ino_SC_n : C4140H7544O1600P200
# ptdmeeta_SC_c : C3840H7444N100O800P100
#    ptrc_c : C4H14N2
#    ptrc_e : C4H14N2
#  pyam5p_c : C8H12N2O5P
#   pydam_c : C8H13N2O2
#  pydx5p_c : C8H8NO6P
#    pydx_c : C8H9NO3
#   pydxn_c : C8H11NO3
#     pyr_c : C3H3O3
#     pyr_e : C3H3O3
#     pyr_m : C3H3O3
#     pyr_x : C3H3O3
#      q6_m : C39H58O4
#    q6h2_m : C39H60O4
#    quln_c : C7H3NO4
#    quln_m : C7H3NO4
#     r1p_c : C5H9O8P
#     r1p_m : C5H9O8P
#     r5p_c : C5H9O8P
#  raffin_c : C18H32O16
#  rib__D_c : C5H10O5
#  rib__D_e : C5H10O5
#  ribflv_c : C17H20N4O6
#  ribflv_e : C17H20N4O6
#  ribflv_m : C17H20N4O6
#    rnam_c : C11H15N2O5
# ru5p__D_c : C5H9O8P
#   s17bp_c : C7H12O13P2
#     s7p_c : C7H13O10P
#       s_c : S
# saccrp__L_c : C11H19N2O6
#  sbt__D_c : C6H14O6
#  sbt__D_e : C6H14O6
#  sbt__L_c : C6H14O6
#  sbt__L_e : C6H14O6
#     scl_c : C42H39N4O16
#  sdhlam_m : C12H20NO4S2
#  ser__L_c : C3H7NO3
#  ser__L_e : C3H7NO3
#  ser__L_m : C3H7NO3
# sertrna_c : C3H6NO2R
#   sheme_c : None
#   skm5p_c : C7H8O8P
#     skm_c : C7H9O5
#     so3_c : O3S
#     so3_e : O3S
#     so4_c : O4S
#     so4_e : O4S
#   sph1p_c : C18H39NO5P
#   sph1p_r : C18H39NO5P
#   sphgn_c : C18H40NO2
#   sphgn_r : C18H40NO2
#    spmd_c : C7H22N3
#    spmd_e : C7H22N3
#    sprm_c : C10H30N4
#    sprm_e : C10H30N4
#     sql_c : C30H50
#     sql_r : C30H50
#  srb__L_c : C6H12O6
#  srb__L_e : C6H12O6
#   stcoa_c : C39H66N7O17P3S
#   stcoa_x : C39H66N7O17P3S
#    succ_c : C4H4O4
#    succ_e : C4H4O4
#    succ_m : C4H4O4
#  succoa_m : C25H35N7O19P3S
#  suchms_c : C8H12NO6
#    sucr_c : C12H22O11
#    sucr_e : C12H22O11
#  sucsal_c : C4H5O3
# tag6p__D_c : C6H11O9P
# tagdp__D_c : C6H10O12P2
#    taur_c : C2H7NO3S
#    taur_e : C2H7NO3S
#  tchola_c : C26H45NO7S
#  tchola_v : C26H45NO7S
#  td2coa_x : C35H56N7O17P3S
#   tdcoa_c : C35H58N7O17P3S
#   tdcoa_x : C35H58N7O17P3S
#  tdeACP_c : C25H45N2O8PRS
#  tdeACP_m : C25H45N2O8PRS
#  tdecoa_c : C35H56N7O17P3S
#  tdecoa_x : C35H56N7O17P3S
#    tglp_c : C18H32N2O4R
#     thf_c : C19H21N7O6
#     thf_m : C19H21N7O6
#  thfglu_c : C24H27N8O9
#     thm_c : C12H17N4OS
#     thm_e : C12H17N4OS
#   thmmp_c : C12H16N4O4PS
#   thmmp_e : C12H16N4O4PS
#   thmpp_c : C12H16N4O7P2S
#   thmpp_e : C12H16N4O7P2S
#   thmpp_m : C12H16N4O7P2S
#   thmtp_c : C12H16N4O10P3S
#  thr__L_c : C4H9NO3
#  thr__L_e : C4H9NO3
#  thr__L_m : C4H9NO3
# thrtrna_c : C4H8NO2R
# thrtrna_m : C4H8NO2R
#    thym_c : C5H6N2O2
#    thym_e : C5H6N2O2
#   thymd_c : C10H14N2O5
#   thymd_e : C10H14N2O5
#   trdox_c : X
#   trdox_m : X
#   trdox_n : X
#   trdox_x : X
#   trdrd_c : XH2
#   trdrd_m : XH2
#   trdrd_n : XH2
#   trdrd_x : XH2
#   tre6p_c : C12H21O14P
#     tre_c : C12H22O11
#     tre_e : C12H22O11
#     tre_v : C12H22O11
# triglyc_SC_c : C5160H9566O600
# trnaala_c : R
# trnaarg_c : R
# trnaarg_m : R
# trnaasn_c : C10H17O10PR2
# trnaasn_m : C10H17O10PR2
# trnaasp_c : R
# trnaasp_m : R
# trnacys_c : R
# trnagln_c : R
# trnaglu_c : R
# trnaglu_m : R
# trnagly_c : R
# trnahis_c : R
# trnahis_m : R
# trnaile_c : R
# trnaile_m : R
# trnaleu_c : R
# trnaleu_m : R
# trnalys_c : R
# trnalys_m : R
# trnamet_c : R
# trnamet_m : R
# trnaphe_c : R
# trnaphe_m : R
# trnapro_c : R
# trnaser_c : R
# trnathr_c : R
# trnathr_m : R
# trnatrp_c : R
# trnatrp_m : R
# trnatyr_c : R
# trnatyr_m : R
# trnaval_c : R
# trnaval_m : R
#  trp__L_c : C11H12N2O2
#  trp__L_e : C11H12N2O2
#  trp__L_m : C11H12N2O2
# trptrna_c : C11H11N2OR
# trptrna_m : C11H11N2OR
#     ttc_c : C24H47O2
#     ttc_x : C24H47O2
#  ttccoa_c : C45H78N7O17P3S
#  ttccoa_r : C45H78N7O17P3S
#  ttccoa_x : C45H78N7O17P3S
#   ttdca_c : C14H27O2
#   ttdca_e : C14H27O2
#   ttdca_x : C14H27O2
#  ttdcea_c : C14H25O2
#  ttdcea_x : C14H25O2
#  tyr__L_c : C9H11NO3
#  tyr__L_e : C9H11NO3
#  tyr__L_m : C9H11NO3
#  tyr__L_v : C9H11NO3
#  tyr__L_x : C9H11NO3
# tyrtrna_c : C9H10NO2R
# tyrtrna_m : C9H10NO2R
#     udp_c : C9H11N2O12P2
#     udp_n : C9H11N2O12P2
# udpacgal_c : C17H25N3O17P2
#    udpg_c : C15H22N2O17P2
#  udpgal_c : C15H22N2O17P2
#  udpgal_g : C15H22N2O17P2
#     ump_c : C9H11N2O9P
#     ump_m : C9H11N2O9P
#     ump_n : C9H11N2O9P
#   uppg3_c : C40H36N4O16
#     ura_c : C4H4N2O2
#     ura_e : C4H4N2O2
# urdglyc_c : C3H5N2O4
#    urea_c : CH4N2O
#    urea_e : CH4N2O
#     uri_c : C9H12N2O6
#     uri_e : C9H12N2O6
#     utp_c : C9H11N2O15P3
#     utp_m : C9H11N2O15P3
#  val__L_c : C5H11NO2
#  val__L_e : C5H11NO2
#  val__L_m : C5H11NO2
# valtrna_c : C5H10NOR
# valtrna_m : C5H10NOR
#     xan_c : C5H4N4O2
#     xan_e : C5H4N4O2
#     xmp_c : C10H11N4O9P
#    xtsn_c : C10H12N4O6
#    xtsn_e : C10H12N4O6
# xu5p__D_c : C5H9O8P
#  xyl__D_c : C5H10O5
#  xyl__D_e : C5H10O5
#    xylt_c : C5H12O5
#    xylt_e : C5H12O5
# xylu__D_c : C5H10O5
# zym_int1_c : C28H44O3
# zym_int2_c : C27H42O
#   zymst_c : C27H44O
#   zymst_e : C27H44O
# zymstest_SC_c : C1694H2993O101
# zymstest_SC_e : C1694H2993O101
#  3hbcoa_c : C25H38N7O18P3S
#   b2coa_c : C25H36N7O17P3S
#   btcoa_c : C25H38N7O17P3S
#     but_c : C4H7O2
